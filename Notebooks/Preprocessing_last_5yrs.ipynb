# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.cluster import KMeans

# %%
metro_df = pd.read_pickle('../Data/all_metro_data.pkl')

# %%
#forward fill missing values for each metro to reduce NaN values
metro_df = pd.concat([metro_df['metro_id'], metro_df.groupby('metro_id').ffill()], axis=1)

# %%
metro_df
# Out:
#        metro_id    metro_name state_id    state_name     period  year  month  \
# 0        394297  Aberdeen, SD       SD  South Dakota 2009-02-28  2009      2
# 1        394297  Aberdeen, SD       SD  South Dakota 2009-03-31  2009      3
# 2        394297  Aberdeen, SD       SD  South Dakota 2009-04-30  2009      4
# 3        394297  Aberdeen, SD       SD  South Dakota 2009-05-31  2009      5
# 4        394297  Aberdeen, SD       SD  South Dakota 2009-06-30  2009      6
# ...         ...           ...      ...           ...        ...   ...    ...
# 212452   845172  Winfield, KS       KS        Kansas 2023-11-30  2023     11
# 212453   845172  Winfield, KS       KS        Kansas 2023-12-31  2023     12
# 212454   845172  Winfield, KS       KS        Kansas 2024-01-31  2024      1
# 212455   845172  Winfield, KS       KS        Kansas 2024-02-29  2024      2
# 212456   845172  Winfield, KS       KS        Kansas 2024-03-31  2024      3
#
#         metro_for_sale_inventory      metro_hvi  metro_med_days_to_close  ...  \
# 0                            NaN  128414.895204                      NaN  ...
# 1                            NaN  128428.614787                      NaN  ...
# 2                            NaN  128232.347262                      NaN  ...
# 3                            NaN  128120.247626                      NaN  ...
# 4                            NaN  127924.063926                      NaN  ...
# ...                          ...            ...                      ...  ...
# 212452                     154.0            NaN                      NaN  ...
# 212453                     146.0            NaN                      NaN  ...
# 212454                     136.0            NaN                      NaN  ...
# 212455                     130.0            NaN                      NaN  ...
# 212456                     121.0            NaN                      NaN  ...
#
#         metro_pct_blw_list  metro_pct_w_pricecut  metro_rent      state_hvi  \
# 0                      NaN                   NaN         NaN  147638.885390
# 1                      NaN                   NaN         NaN  147559.476539
# 2                      NaN                   NaN         NaN  147229.826738
# 3                      NaN                   NaN         NaN  146863.651913
# 4                      NaN                   NaN         NaN  146483.638609
# ...                    ...                   ...         ...            ...
# 212452                 NaN              0.267385         NaN  222566.236372
# 212453                 NaN              0.215387         NaN  222324.630758
# 212454                 NaN              0.194851         NaN  222197.238452
# 212455                 NaN              0.186402         NaN  222731.307862
# 212456                 NaN              0.193936         NaN  224240.995918
#
#         state_personal_income  state_personal_income_per_capita  \
# 0                         NaN                               NaN
# 1                     31406.1                               NaN
# 2                     31406.1                               NaN
# 3                     31406.1                               NaN
# 4                     31711.7                               NaN
# ...                       ...                               ...
# 212452               189073.4                           64276.0
# 212453               190108.6                           64591.0
# 212454               190108.6                           64591.0
# 212455               190108.6                           64591.0
# 212456               190108.6                           64591.0
#
#         state_population  state_gdp_cur_dol  state_job_openings  \
# 0                    NaN                NaN                 8.0
# 1                    NaN                NaN                 7.0
# 2                    NaN                NaN                 8.0
# 3                    NaN                NaN                10.0
# 4                    NaN                NaN                 8.0
# ...                  ...                ...                 ...
# 212452         2941593.0            64276.0                83.0
# 212453         2943265.0            64591.0                77.0
# 212454         2943265.0            64591.0                77.0
# 212455         2943265.0            64591.0                77.0
# 212456         2943265.0            64591.0                77.0
#
#         state_job_openings_szn_adjd
# 0                               9.0
# 1                               7.0
# 2                               8.0
# 3                               9.0
# 4                               8.0
# ...                             ...
# 212452                         87.0
# 212453                         85.0
# 212454                         85.0
# 212455                         85.0
# 212456                         85.0
#
# [212457 rows x 23 columns]

# %%
metro_df = metro_df.dropna(subset='metro_hvi')

# %% [markdown]
# # Create lag features, normalize numeric data and split into train/test datasets

# %%
#Create lag features for trends
y_cols = ['metro_id','metro_hvi','state_hvi']
X_cols = ['metro_id', 'metro_for_sale_inventory', 'metro_hvi', 'metro_med_days_to_close', 
          'metro_new_construct', 'metro_new_listing', 'metro_pct_abv_list', 'metro_pct_blw_list', 
          'metro_pct_w_pricecut', 'metro_rent', 'state_hvi', 'state_personal_income',
          'state_personal_income_per_capita', 'state_population', 'state_gdp_cur_dol', 'state_job_openings', 'state_job_openings_szn_adjd']

def add_lag_features(df, fwrd_lag=[1,2,3,4,6,7], prev_lag=[1,2,3,6]):
    global y_new_cols
    global X_new_cols
    y_new_cols = []
    X_new_cols = []
    
    for lag in fwrd_lag:

        #Add hvi values for future periods to be used as target variable
        df = df.sort_values(by=['metro_id','state_id','period'])
        y_shifted_cols = ["frwd"+str(lag).zfill(2)+"_mon_"+col for col in y_cols]
        y_new_cols.extend(y_shifted_cols)

        df[y_shifted_cols] = df[y_cols].shift(-lag) #create forward looking columns
        df.loc[metro_df[y_cols[0]] != df[y_shifted_cols[0]],y_shifted_cols[1:3]] = np.nan #set new numeric columns as null if metro_id doesn't match
        df = df.drop(columns=[y_shifted_cols[0]]) #drop metro_id duplicate column

        #Create column with percentage change from the lag period
        for i, col in enumerate(y_shifted_cols):
            if 'metro_id' in col:
                pass
            else:
                old_col = y_cols[i]
                new_col_nm = col+"_pct_chg"
                df[new_col_nm] = (df[col] / df[old_col]) - 1
                y_new_cols.extend([new_col_nm])

    #Add incremental changes from previous periods
    for lag in prev_lag:
        X_shifted_cols = ["prev"+str(lag).zfill(2)+"_mon_"+col for col in X_cols]
        X_new_cols.extend(X_shifted_cols)

        df[X_shifted_cols] = df[X_cols].shift(lag) #create backward looking columns
        df.loc[metro_df[X_cols[0]] != df[X_shifted_cols[0]],X_shifted_cols[1:3]] = np.nan #set new numeric columns as null if metro_id doesn't match
        df = df.drop(columns=[X_shifted_cols[0]]) #drop metro_id duplicate column

        #Create column with percentage change from the lag period
        for i, col in enumerate(X_shifted_cols):
            if 'metro_id' in col:
                pass
            else:
                old_col = X_cols[i]
                new_col_nm = col+"_pct_chg"
                df[new_col_nm] = (df[old_col] / df[col]) - 1
                X_new_cols.extend([new_col_nm])
    
    y_new_cols = [col for col in y_new_cols if 'metro_id' not in col] 
    X_new_cols = [col for col in X_new_cols if 'metro_id' not in col]
    return_cols = ['metro_id', 'period'] + X_new_cols + y_new_cols
    return(df[return_cols])

# %%
scaler = MinMaxScaler()

def train_normalizer(df, scaler=scaler):
    #Seperate columns into types for reshaping of data
    orig_columns = list(df.columns)
    metro_columns = orig_columns[:4] + ['variable']
    non_numeric_features = orig_columns[:7]
    
    #reshape data so periods are each a seperate columns
    df_reshaped = pd.melt(df, id_vars=non_numeric_features)
    df_reshaped = df_reshaped.pivot(index=metro_columns,
                                    columns='period',
                                    values='value')

    #Forward fill data
    #For periods with missing data, fill with the previous value available. If no early data available, leave null.
    df_reshaped = df_reshaped.ffill(axis=1)
    
    #Normalize all numeric data to retain variance but range from 0 to 1
    scaler.fit(df_reshaped.T)

# %%
def normalize_data(df, scaler=scaler):
    #Seperate columns into types for reshaping of data
    orig_columns = list(df.columns)
    merge_columns = orig_columns[:4] + ['period']
    metro_columns = orig_columns[:4] + ['variable']
    period_columns = orig_columns[4:7]
    numeric_features = orig_columns[7:]
    non_numeric_features = orig_columns[:7]
    
    #reshape data so periods are each a seperate columns
    df_reshaped = pd.melt(df, 
                          id_vars=non_numeric_features)
    df_reshaped = df_reshaped.pivot(index=metro_columns,
                                    columns='period',
                                    values='value')

    #Forward fill data
    #For periods with missing data, fill with the previous value available. If no early data available, leave null.
    df_reshaped = df_reshaped.ffill(axis=1)
    
    #Reshape filled data back to original format
    df_unshaped = pd.melt(df_reshaped.reset_index(), 
                          id_vars=metro_columns)
    df_unshaped = df_unshaped.pivot(index=merge_columns,
                                    columns='variable',
                                    values='value')

    
    #Normalize all numeric data to retain variance but range from 0 to 1
    data_normalized = scaler.transform(df_reshaped.T)
    df_normalized = pd.DataFrame(data_normalized.T, 
                                 index=df_reshaped.index, 
                                 columns=df_reshaped.columns
                                ).reset_index()

    #Reshape back to original format with normalized data
    df_normalized = pd.melt(df_normalized,
                            id_vars=metro_columns)
    df_normalized = df_normalized.pivot(index=merge_columns,
                                        columns='variable',
                                        values='value'
                                       ).add_suffix('_normalized')
    
    #Add normalized data to original dataframe as seperate columns
    df_final = df_unshaped.merge(df_normalized, 
                                 on=merge_columns, 
                                 how='right'
                                ).reset_index()
    
    #Clean up year and month columns
    df_final.insert(5,'month',df_final['period'].dt.month)
    df_final.insert(5,'year',df_final['period'].dt.year)
    return(df_final)

# %%
#Create dataframe with lag features
metro_df_lag_features = add_lag_features(metro_df)
# Out:
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col_nm] = (df[old_col] / df[col]) - 1
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col_nm] = (df[old_col] / df[col]) - 1
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col_nm] = (df[old_col] / df[col]) - 1
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col_nm] = (df[old_col] / df[col]) - 1
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[X_shifted_cols] = df[X_cols].shift(lag) #create backward looking columns
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[X_shifted_cols] = df[X_cols].shift(lag) #create backward looking columns
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[X_shifted_cols] = df[X_cols].shift(lag) #create backward looking columns
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[X_shifted_cols] = df[X_cols].shift(lag) #create backward looking columns
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[X_shifted_cols] = df[X_cols].shift(lag) #create backward looking columns
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[X_shifted_cols] = df[X_cols].shift(lag) #create backward looking columns
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[X_shifted_cols] = df[X_cols].shift(lag) #create backward looking columns
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[X_shifted_cols] = df[X_cols].shift(lag) #create backward looking columns
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[X_shifted_cols] = df[X_cols].shift(lag) #create backward looking columns
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[X_shifted_cols] = df[X_cols].shift(lag) #create backward looking columns
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[X_shifted_cols] = df[X_cols].shift(lag) #create backward looking columns
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[X_shifted_cols] = df[X_cols].shift(lag) #create backward looking columns
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[X_shifted_cols] = df[X_cols].shift(lag) #create backward looking columns
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[X_shifted_cols] = df[X_cols].shift(lag) #create backward looking columns
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[X_shifted_cols] = df[X_cols].shift(lag) #create backward looking columns
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[X_shifted_cols] = df[X_cols].shift(lag) #create backward looking columns
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[X_shifted_cols] = df[X_cols].shift(lag) #create backward looking columns
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col_nm] = (df[old_col] / df[col]) - 1
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col_nm] = (df[old_col] / df[col]) - 1
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col_nm] = (df[old_col] / df[col]) - 1
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col_nm] = (df[old_col] / df[col]) - 1
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col_nm] = (df[old_col] / df[col]) - 1
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col_nm] = (df[old_col] / df[col]) - 1
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col_nm] = (df[old_col] / df[col]) - 1
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col_nm] = (df[old_col] / df[col]) - 1
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col_nm] = (df[old_col] / df[col]) - 1
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col_nm] = (df[old_col] / df[col]) - 1
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col_nm] = (df[old_col] / df[col]) - 1
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col_nm] = (df[old_col] / df[col]) - 1
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col_nm] = (df[old_col] / df[col]) - 1
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col_nm] = (df[old_col] / df[col]) - 1
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col_nm] = (df[old_col] / df[col]) - 1
# C:\Users\Brendan\AppData\Local\Temp\ipykernel_11164\3554373497.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col_nm] = (df[old_col] / df[col]) - 1

# %%
#Create datasets for time series split cross-validation

#Sample 1 (Train: 2018-2019.6 | Test: 2019.7 - 2020.6) 1 of 5 years (20%)
#Sample 2 (Train: 2018-2020.6 | Test: 2020.7 - 2021.6) 1 of 5 years (20%)
#Sample 3 (Train: 2018-2021.6 | Test: 2021.7 - 2022.6) 1 of 5 years (20%)
#Validation (Train: 2018-2022.6 | Test: 2022.7 - 2023) 1.5 of 5 years (30%)

sample_groups = ['metro_samp_1','metro_samp_2','metro_samp_3','metro_samp_val']
sample_train = [sample + '_train' for sample in sample_groups]
sample_test = [sample + '_test' for sample in sample_groups]
train_start_date = ['2017-12-01'] * 4
train_end_date = ['2019-07-01','2020-07-01','2021-07-01','2022-07-01']
test_start_date = train_end_date
test_end_date = ['2020-07-01','2021-07-01','2022-07-01','2024-01-01']

sample_dfs = {}
for i, df_name in enumerate(sample_groups):
    df = metro_df[(metro_df.period >= train_start_date[i]) &
                  (metro_df.period <= test_end_date[i])]

    sample_dfs[df_name] = df
    
    df_train_name = df_name + '_train'
    df_train = df[(df.period >= train_start_date[i]) &
                  (df.period <= train_end_date[i])]
    sample_dfs[df_train_name] = df_train

    df_test_name = df_name + '_test'
    df_test = df[(df.period >= test_start_date[i]) &
                 (df.period <= test_end_date[i]) &
                 (df.metro_id.isin(df_train.metro_id))] #exclude any metro id's that are not in the training dataset
    sample_dfs[df_test_name] = df_test

# %%
#Normalize all datasets and add lag features
for i, df_name in enumerate(sample_groups):
    #train normalizer
    df_train_name = df_name + '_train'
    df_train_name_normalized = df_train_name + '_normalized'
    train_normalizer(sample_dfs[df_train_name])
    
    #normalize training data
    df_train_normalized = normalize_data(sample_dfs[df_train_name])
    df_train_normalized = df_train_normalized.merge(metro_df_lag_features, on=['metro_id','period'], how='left')
    sample_dfs[df_train_name_normalized] = df_train_normalized
    
    #normalize test data
    df_test_name = df_name + '_test'
    df_test_name_normalized = df_test_name + '_normalized'
    df_test_normalized = normalize_data(sample_dfs[df_test_name])
    df_test_normalized = df_test_normalized.merge(metro_df_lag_features, on=['metro_id','period'], how='left')
    sample_dfs[df_test_name_normalized] = df_test_normalized
# Out:
# C:\Users\Brendan\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:473: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# C:\Users\Brendan\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:474: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)
# C:\Users\Brendan\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:473: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# C:\Users\Brendan\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:474: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)
# C:\Users\Brendan\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:473: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# C:\Users\Brendan\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:474: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)
# C:\Users\Brendan\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:473: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# C:\Users\Brendan\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:474: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)

# %% [markdown]
# # Cluster metro areas

# %%
#Set features for clustering
kmeans_features = ['metro_id',
                   'metro_name',
                   'period',
                   'metro_hvi',
                   'prev06_mon_metro_hvi_pct_chg',
                   'metro_new_construct',
                   'prev06_mon_metro_rent_pct_chg',
                   'state_hvi', 
                   'state_job_openings', 
                   'state_personal_income',
                   'state_population']

#Drop records with missing data
kmeans_df = sample_dfs['metro_samp_val_train_normalized'][kmeans_features].dropna().copy()
kmeans_data_clean = np.array(kmeans_df[kmeans_features[3:]])

#Standardize data to have consistent mean and variance for each feature
standardizer = StandardScaler()
standardizer.fit(kmeans_data_clean)
kmeans_data_standardized = standardizer.transform(kmeans_data_clean)

#use kmeans model to find 5 buckets for metro id's using key features identified during EDA 
kmeans = KMeans(n_clusters=5, random_state=0)
metro_clusters = kmeans.fit_predict(kmeans_data_standardized)

#create dictionary to lookup cluster for each metro_id
kmeans_df['cluster'] = metro_clusters
metro_clusters_df = kmeans_df.groupby(['metro_id','metro_name']).cluster.value_counts(normalize=True).reset_index().drop_duplicates(subset=['metro_id'])
metro_clusters_dict = metro_clusters_df.set_index('metro_id')['cluster'].to_dict()
# Out:
# C:\Users\Brendan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
#Add dummy columns for clusters from kmeans
for sample_df in sample_dfs:
    #Remove old clusters (if rerunning)
    cols = sample_dfs[sample_df].columns
    drop_cols = [col for col in cols if 'cluster' in col]
    
    #Add clusters and generate dummy columns
    sample_dfs[sample_df] = sample_dfs[sample_df].drop(columns=drop_cols)
    sample_dfs[sample_df]['cluster'] = sample_dfs[sample_df]['metro_id'].map(metro_clusters_dict).fillna(5).astype('int') #add 6th cluster for missing metros
    if sample_df == 'metro_samp_val_train_normalized':
        metro_clusters_viz_df = sample_dfs[sample_df]
    sample_dfs[sample_df] = pd.get_dummies(sample_dfs[sample_df],columns=['cluster'], drop_first=True)

# %%
metro_clusters_viz_df
# Out:
#       metro_id    metro_name state_id    state_name     period  year  month  \
# 0       394297  Aberdeen, SD       SD  South Dakota 2017-12-31  2017     12
# 1       394297  Aberdeen, SD       SD  South Dakota 2018-01-31  2018      1
# 2       394297  Aberdeen, SD       SD  South Dakota 2018-02-28  2018      2
# 3       394297  Aberdeen, SD       SD  South Dakota 2018-03-31  2018      3
# 4       394297  Aberdeen, SD       SD  South Dakota 2018-04-30  2018      4
# ...        ...           ...      ...           ...        ...   ...    ...
# 49165   753929    Zapata, TX       TX         Texas 2022-02-28  2022      2
# 49166   753929    Zapata, TX       TX         Texas 2022-03-31  2022      3
# 49167   753929    Zapata, TX       TX         Texas 2022-04-30  2022      4
# 49168   753929    Zapata, TX       TX         Texas 2022-05-31  2022      5
# 49169   753929    Zapata, TX       TX         Texas 2022-06-30  2022      6
#
#        metro_for_sale_inventory      metro_hvi  metro_med_days_to_close  ...  \
# 0                           NaN  153810.706947                      NaN  ...
# 1                           NaN  154172.905655                      NaN  ...
# 2                           NaN  154538.720740                      NaN  ...
# 3                         184.0  155225.918108                      NaN  ...
# 4                         200.0  155541.602780                      NaN  ...
# ...                         ...            ...                      ...  ...
# 49165                      38.0  141262.159358                      NaN  ...
# 49166                      43.0  140076.410995                      NaN  ...
# 49167                      43.0  138783.331739                      NaN  ...
# 49168                      42.0  138874.697512                      NaN  ...
# 49169                      41.0  140571.909572                      NaN  ...
#
#        frwd04_mon_state_hvi_pct_chg  frwd06_mon_metro_hvi  \
# 0                          0.015370         156059.954943
# 1                          0.016320         156689.276756
# 2                          0.016067         157018.337079
# 3                          0.015703         157189.033595
# 4                          0.014712         156970.670454
# ...                             ...                   ...
# 49165                      0.078459         142268.308039
# 49166                      0.065637         140343.344480
# 49167                      0.047328         138155.104481
# 49168                      0.026175         134909.927164
# 49169                      0.007089         131218.236819
#
#        frwd06_mon_state_hvi  frwd06_mon_metro_hvi_pct_chg  \
# 0             195506.959039                      0.014623
# 1             196281.525642                      0.016322
# 2             196935.204843                      0.016045
# 3             197672.695099                      0.012647
# 4             198030.479157                      0.009188
# ...                     ...                           ...
# 49165         311237.115280                      0.007123
# 49166         310567.773229                      0.001906
# 49167         309597.332425                     -0.004527
# 49168         308563.830018                     -0.028549
# 49169         307238.519665                     -0.066540
#
#        frwd06_mon_state_hvi_pct_chg  frwd07_mon_metro_hvi  \
# 0                          0.022836         156689.276756
# 1                          0.023020         157018.337079
# 2                          0.023490         157189.033595
# 3                          0.022902         156970.670454
# 4                          0.020355         157100.274302
# ...                             ...                   ...
# 49165                      0.091857         140343.344480
# 49166                      0.066487         138155.104481
# 49167                      0.041810         134909.927164
# 49168                      0.019553         131218.236819
# 49169                     -0.000584         126830.530768
#
#        frwd07_mon_state_hvi  frwd07_mon_metro_hvi_pct_chg  \
# 0             196281.525642                      0.018715
# 1             196935.204843                      0.018456
# 2             197672.695099                      0.017150
# 3             198030.479157                      0.011240
# 4             198595.616920                      0.010021
# ...                     ...                           ...
# 49165         310567.773229                     -0.006504
# 49166         309597.332425                     -0.013716
# 49167         308563.830018                     -0.027910
# 49168         307238.519665                     -0.055132
# 49169         305501.955159                     -0.097753
#
#        frwd07_mon_state_hvi_pct_chg  cluster
# 0                          0.026888        5
# 1                          0.026427        5
# 2                          0.027323        5
# 3                          0.024753        5
# 4                          0.023267        5
# ...                             ...      ...
# 49165                      0.089509        5
# 49166                      0.063155        5
# 49167                      0.038332        5
# 49168                      0.015174        5
# 49169                     -0.006232        5
#
# [49170 rows x 192 columns]

# %%
fig, ax = plt.subplots(figsize=(14,8))
x='period'
y='metro_hvi'
hue='cluster'
metro_clusters_viz_df['cluster'] = metro_clusters_viz_df['cluster'].astype('str') 
metro_clusters_viz_df = metro_clusters_viz_df.sort_values('cluster')
sns.scatterplot(data=metro_clusters_viz_df, x=x, y=y, hue=hue, s=5, alpha=.2, ax=ax, legend=False)
sns.lineplot(data=metro_clusters_viz_df.groupby([x,hue]).agg({y:'median'}), x=x, y=y, hue=hue, linewidth=4, ax=ax)
plt.title('Metro HVIs change over time (median by category)')
plt.show()

# %%
metro_clusters_viz_df.groupby('cluster')['metro_id'].agg(['nunique'])
# Out:
#          nunique
# cluster
# 0            124
# 1             37
# 2             13
# 3             17
# 4              4
# 5            699

# %% [markdown]
# # Additional EDA on normalized data

# %%
df = sample_dfs['metro_samp_val_train_normalized'].info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49170 entries, 0 to 49169
# Data columns (total 196 columns):
#  #    Column                                               Dtype
# ---   ------                                               -----
#  0    metro_id                                             object
#  1    metro_name                                           object
#  2    state_id                                             object
#  3    state_name                                           object
#  4    period                                               datetime64[ns]
#  5    year                                                 int32
#  6    month                                                int32
#  7    metro_for_sale_inventory                             float64
#  8    metro_hvi                                            float64
#  9    metro_med_days_to_close                              float64
#  10   metro_new_construct                                  float64
#  11   metro_new_listing                                    float64
#  12   metro_pct_abv_list                                   float64
#  13   metro_pct_blw_list                                   float64
#  14   metro_pct_w_pricecut                                 float64
#  15   metro_rent                                           float64
#  16   state_gdp_cur_dol                                    float64
#  17   state_hvi                                            float64
#  18   state_job_openings                                   float64
#  19   state_job_openings_szn_adjd                          float64
#  20   state_personal_income                                float64
#  21   state_personal_income_per_capita                     float64
#  22   state_population                                     float64
#  23   metro_for_sale_inventory_normalized                  float64
#  24   metro_hvi_normalized                                 float64
#  25   metro_med_days_to_close_normalized                   float64
#  26   metro_new_construct_normalized                       float64
#  27   metro_new_listing_normalized                         float64
#  28   metro_pct_abv_list_normalized                        float64
#  29   metro_pct_blw_list_normalized                        float64
#  30   metro_pct_w_pricecut_normalized                      float64
#  31   metro_rent_normalized                                float64
#  32   state_gdp_cur_dol_normalized                         float64
#  33   state_hvi_normalized                                 float64
#  34   state_job_openings_normalized                        float64
#  35   state_job_openings_szn_adjd_normalized               float64
#  36   state_personal_income_normalized                     float64
#  37   state_personal_income_per_capita_normalized          float64
#  38   state_population_normalized                          float64
#  39   prev01_mon_metro_for_sale_inventory                  float64
#  40   prev01_mon_metro_hvi                                 float64
#  41   prev01_mon_metro_med_days_to_close                   float64
#  42   prev01_mon_metro_new_construct                       float64
#  43   prev01_mon_metro_new_listing                         float64
#  44   prev01_mon_metro_pct_abv_list                        float64
#  45   prev01_mon_metro_pct_blw_list                        float64
#  46   prev01_mon_metro_pct_w_pricecut                      float64
#  47   prev01_mon_metro_rent                                float64
#  48   prev01_mon_state_hvi                                 float64
#  49   prev01_mon_state_personal_income                     float64
#  50   prev01_mon_state_personal_income_per_capita          float64
#  51   prev01_mon_state_population                          float64
#  52   prev01_mon_state_gdp_cur_dol                         float64
#  53   prev01_mon_state_job_openings                        float64
#  54   prev01_mon_state_job_openings_szn_adjd               float64
#  55   prev01_mon_metro_for_sale_inventory_pct_chg          float64
#  56   prev01_mon_metro_hvi_pct_chg                         float64
#  57   prev01_mon_metro_med_days_to_close_pct_chg           float64
#  58   prev01_mon_metro_new_construct_pct_chg               float64
#  59   prev01_mon_metro_new_listing_pct_chg                 float64
#  60   prev01_mon_metro_pct_abv_list_pct_chg                float64
#  61   prev01_mon_metro_pct_blw_list_pct_chg                float64
#  62   prev01_mon_metro_pct_w_pricecut_pct_chg              float64
#  63   prev01_mon_metro_rent_pct_chg                        float64
#  64   prev01_mon_state_hvi_pct_chg                         float64
#  65   prev01_mon_state_personal_income_pct_chg             float64
#  66   prev01_mon_state_personal_income_per_capita_pct_chg  float64
#  67   prev01_mon_state_population_pct_chg                  float64
#  68   prev01_mon_state_gdp_cur_dol_pct_chg                 float64
#  69   prev01_mon_state_job_openings_pct_chg                float64
#  70   prev01_mon_state_job_openings_szn_adjd_pct_chg       float64
#  71   prev02_mon_metro_for_sale_inventory                  float64
#  72   prev02_mon_metro_hvi                                 float64
#  73   prev02_mon_metro_med_days_to_close                   float64
#  74   prev02_mon_metro_new_construct                       float64
#  75   prev02_mon_metro_new_listing                         float64
#  76   prev02_mon_metro_pct_abv_list                        float64
#  77   prev02_mon_metro_pct_blw_list                        float64
#  78   prev02_mon_metro_pct_w_pricecut                      float64
#  79   prev02_mon_metro_rent                                float64
#  80   prev02_mon_state_hvi                                 float64
#  81   prev02_mon_state_personal_income                     float64
#  82   prev02_mon_state_personal_income_per_capita          float64
#  83   prev02_mon_state_population                          float64
#  84   prev02_mon_state_gdp_cur_dol                         float64
#  85   prev02_mon_state_job_openings                        float64
#  86   prev02_mon_state_job_openings_szn_adjd               float64
#  87   prev02_mon_metro_for_sale_inventory_pct_chg          float64
#  88   prev02_mon_metro_hvi_pct_chg                         float64
#  89   prev02_mon_metro_med_days_to_close_pct_chg           float64
#  90   prev02_mon_metro_new_construct_pct_chg               float64
#  91   prev02_mon_metro_new_listing_pct_chg                 float64
#  92   prev02_mon_metro_pct_abv_list_pct_chg                float64
#  93   prev02_mon_metro_pct_blw_list_pct_chg                float64
#  94   prev02_mon_metro_pct_w_pricecut_pct_chg              float64
#  95   prev02_mon_metro_rent_pct_chg                        float64
#  96   prev02_mon_state_hvi_pct_chg                         float64
#  97   prev02_mon_state_personal_income_pct_chg             float64
#  98   prev02_mon_state_personal_income_per_capita_pct_chg  float64
#  99   prev02_mon_state_population_pct_chg                  float64
#  100  prev02_mon_state_gdp_cur_dol_pct_chg                 float64
#  101  prev02_mon_state_job_openings_pct_chg                float64
#  102  prev02_mon_state_job_openings_szn_adjd_pct_chg       float64
#  103  prev03_mon_metro_for_sale_inventory                  float64
#  104  prev03_mon_metro_hvi                                 float64
#  105  prev03_mon_metro_med_days_to_close                   float64
#  106  prev03_mon_metro_new_construct                       float64
#  107  prev03_mon_metro_new_listing                         float64
#  108  prev03_mon_metro_pct_abv_list                        float64
#  109  prev03_mon_metro_pct_blw_list                        float64
#  110  prev03_mon_metro_pct_w_pricecut                      float64
#  111  prev03_mon_metro_rent                                float64
#  112  prev03_mon_state_hvi                                 float64
#  113  prev03_mon_state_personal_income                     float64
#  114  prev03_mon_state_personal_income_per_capita          float64
#  115  prev03_mon_state_population                          float64
#  116  prev03_mon_state_gdp_cur_dol                         float64
#  117  prev03_mon_state_job_openings                        float64
#  118  prev03_mon_state_job_openings_szn_adjd               float64
#  119  prev03_mon_metro_for_sale_inventory_pct_chg          float64
#  120  prev03_mon_metro_hvi_pct_chg                         float64
#  121  prev03_mon_metro_med_days_to_close_pct_chg           float64
#  122  prev03_mon_metro_new_construct_pct_chg               float64
#  123  prev03_mon_metro_new_listing_pct_chg                 float64
#  124  prev03_mon_metro_pct_abv_list_pct_chg                float64
#  125  prev03_mon_metro_pct_blw_list_pct_chg                float64
#  126  prev03_mon_metro_pct_w_pricecut_pct_chg              float64
#  127  prev03_mon_metro_rent_pct_chg                        float64
#  128  prev03_mon_state_hvi_pct_chg                         float64
#  129  prev03_mon_state_personal_income_pct_chg             float64
#  130  prev03_mon_state_personal_income_per_capita_pct_chg  float64
#  131  prev03_mon_state_population_pct_chg                  float64
#  132  prev03_mon_state_gdp_cur_dol_pct_chg                 float64
#  133  prev03_mon_state_job_openings_pct_chg                float64
#  134  prev03_mon_state_job_openings_szn_adjd_pct_chg       float64
#  135  prev06_mon_metro_for_sale_inventory                  float64
#  136  prev06_mon_metro_hvi                                 float64
#  137  prev06_mon_metro_med_days_to_close                   float64
#  138  prev06_mon_metro_new_construct                       float64
#  139  prev06_mon_metro_new_listing                         float64
#  140  prev06_mon_metro_pct_abv_list                        float64
#  141  prev06_mon_metro_pct_blw_list                        float64
#  142  prev06_mon_metro_pct_w_pricecut                      float64
#  143  prev06_mon_metro_rent                                float64
#  144  prev06_mon_state_hvi                                 float64
#  145  prev06_mon_state_personal_income                     float64
#  146  prev06_mon_state_personal_income_per_capita          float64
#  147  prev06_mon_state_population                          float64
#  148  prev06_mon_state_gdp_cur_dol                         float64
#  149  prev06_mon_state_job_openings                        float64
#  150  prev06_mon_state_job_openings_szn_adjd               float64
#  151  prev06_mon_metro_for_sale_inventory_pct_chg          float64
#  152  prev06_mon_metro_hvi_pct_chg                         float64
#  153  prev06_mon_metro_med_days_to_close_pct_chg           float64
#  154  prev06_mon_metro_new_construct_pct_chg               float64
#  155  prev06_mon_metro_new_listing_pct_chg                 float64
#  156  prev06_mon_metro_pct_abv_list_pct_chg                float64
#  157  prev06_mon_metro_pct_blw_list_pct_chg                float64
#  158  prev06_mon_metro_pct_w_pricecut_pct_chg              float64
#  159  prev06_mon_metro_rent_pct_chg                        float64
#  160  prev06_mon_state_hvi_pct_chg                         float64
#  161  prev06_mon_state_personal_income_pct_chg             float64
#  162  prev06_mon_state_personal_income_per_capita_pct_chg  float64
#  163  prev06_mon_state_population_pct_chg                  float64
#  164  prev06_mon_state_gdp_cur_dol_pct_chg                 float64
#  165  prev06_mon_state_job_openings_pct_chg                float64
#  166  prev06_mon_state_job_openings_szn_adjd_pct_chg       float64
#  167  frwd01_mon_metro_hvi                                 float64
#  168  frwd01_mon_state_hvi                                 float64
#  169  frwd01_mon_metro_hvi_pct_chg                         float64
#  170  frwd01_mon_state_hvi_pct_chg                         float64
#  171  frwd02_mon_metro_hvi                                 float64
#  172  frwd02_mon_state_hvi                                 float64
#  173  frwd02_mon_metro_hvi_pct_chg                         float64
#  174  frwd02_mon_state_hvi_pct_chg                         float64
#  175  frwd03_mon_metro_hvi                                 float64
#  176  frwd03_mon_state_hvi                                 float64
#  177  frwd03_mon_metro_hvi_pct_chg                         float64
#  178  frwd03_mon_state_hvi_pct_chg                         float64
#  179  frwd04_mon_metro_hvi                                 float64
#  180  frwd04_mon_state_hvi                                 float64
#  181  frwd04_mon_metro_hvi_pct_chg                         float64
#  182  frwd04_mon_state_hvi_pct_chg                         float64
#  183  frwd06_mon_metro_hvi                                 float64
#  184  frwd06_mon_state_hvi                                 float64
#  185  frwd06_mon_metro_hvi_pct_chg                         float64
#  186  frwd06_mon_state_hvi_pct_chg                         float64
#  187  frwd07_mon_metro_hvi                                 float64
#  188  frwd07_mon_state_hvi                                 float64
#  189  frwd07_mon_metro_hvi_pct_chg                         float64
#  190  frwd07_mon_state_hvi_pct_chg                         float64
#  191  cluster_1                                            bool
#  192  cluster_2                                            bool
#  193  cluster_3                                            bool
#  194  cluster_4                                            bool
#  195  cluster_5                                            bool
# dtypes: bool(5), datetime64[ns](1), float64(184), int32(2), object(4)
# memory usage: 71.5+ MB

# %%
x = ['state_population_normalized',
     'state_job_openings_normalized',
     'state_personal_income_normalized',
     'metro_rent_normalized',
     'metro_pct_blw_list_normalized']
y = 'metro_hvi_normalized'
df = sample_dfs['metro_samp_val_train_normalized']
fig, ax = plt.subplots(5,1, figsize=(7,30))

for i in range(5):
    sns.scatterplot(data=df,
                    x=x[i],
                    y=y,
                    ax=ax[i])
plt.show()

# %%
x = ['state_population_normalized',
     'state_job_openings_normalized',
     'state_personal_income_normalized',
     'metro_rent_normalized',
     'metro_pct_blw_list_normalized']
y = 'metro_hvi_normalized'
df = metro_clusters_viz_df
fig, ax = plt.subplots(5,1, figsize=(7,30))

for i in range(5):
    sns.scatterplot(data=df,
                    x=x[i],
                    y=y,
                    hue='cluster',
                    ax=ax[i])
plt.show()

# %% [markdown]
# # Export all train/test datasets

# %%
#Pickle the dictionary of DataFrames to a file
with open('../Data/test_train_datasets.pkl', 'wb') as f:
    pickle.dump(sample_dfs, f)  # 'wb' for writing in binary mode
