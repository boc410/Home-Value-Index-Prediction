# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle

import time
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning) #suppress runtime warnings

import random
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_absolute_error as mae

# %%
#Load (unpickle) the dictionary of DataFrames from the file
with open('../Data/test_train_datasets.pkl', 'rb') as f:
    sample_dfs = pickle.load(f)  # 'rb' for reading in binary mode

sample_dfs.keys()
# Out:
# dict_keys(['metro_samp_1', 'metro_samp_1_train', 'metro_samp_1_test', 'metro_samp_2', 'metro_samp_2_train', 'metro_samp_2_test', 'metro_samp_3', 'metro_samp_3_train', 'metro_samp_3_test', 'metro_samp_val', 'metro_samp_val_train', 'metro_samp_val_test', 'metro_samp_1_train_normalized', 'metro_samp_1_test_normalized', 'metro_samp_2_train_normalized', 'metro_samp_2_test_normalized', 'metro_samp_3_train_normalized', 'metro_samp_3_test_normalized', 'metro_samp_val_train_normalized', 'metro_samp_val_test_normalized'])

# %%
X_cols = [col for col in sample_dfs['metro_samp_val_train_normalized'].columns if "frwd" not in col]
y_cols = [col for col in sample_dfs['metro_samp_val_train_normalized'].columns if "frwd" in col]

# %%
#set folds for cross validation testing
cv_folds = pd.DataFrame({'fold':['samp_1','samp_2','samp_3'],
                         'train_df':['metro_samp_1_train_normalized','metro_samp_2_train_normalized','metro_samp_3_train_normalized'],
                         'test_df':['metro_samp_1_test_normalized','metro_samp_2_test_normalized','metro_samp_3_test_normalized']})

val = pd.DataFrame({'fold':['val'],
                    'train_df':['metro_samp_val_train_normalized'],
                    'test_df':['metro_samp_val_test_normalized']})

# %%
#create function to produce confusion matrix from test results
def conf_matrix(test_results):
    pos = test_results[test_results.y_test < 0]
    true_pos = pos[pos.y_pred < 0]
    false_neg = pos[pos.y_pred >= 0]

    neg = test_results[test_results.y_test >= 0]
    true_neg = neg[neg.y_pred >= 0]
    false_pos = neg[neg.y_pred < 0]

    confusion_matrix = np.array([[len(true_pos), len(false_pos)],
                                [len(false_neg), len(true_neg)]])

    confusion_matrix_pct = confusion_matrix / len(test_results)
    
    return(confusion_matrix, confusion_matrix_pct)

# %%
#create class to generate key statistics from confusion matrix
class confusion_matrix_class:
    def __init__(self, cm):
        self.cm = cm
        self.tp = cm[0,0]
        self.fp = cm[0,1]
        self.fn = cm[1,0]
        self.tn = cm[1,1]
        self.accuracy = ((self.tp+self.tn)/(self.tp+self.fp+self.fn+self.tn))
        self.precision = (self.tp/(self.tp+self.fp))
        self.recall = (self.tp/(self.tp+self.fn))
        self.F1 = (2*self.precision*self.recall)/(self.precision+self.recall)
        self.specificity = (self.tn/(self.tn+self.fp))

# %%
compare_df = pd.DataFrame()

#create function to produce consistent results for comparison across models
def create_results_record(model, cv_fold, y_var, dataset, cm, error):                
    new_record_dict = {'model': model,
                      'cv_fold': cv_fold,
                      'y': y_var,
                      'dataset': dataset,
                      'mae': error,
                      'accuracy': cm.accuracy,
                      'precision': cm.precision,
                      'recall': cm.recall,
                      'F1': cm.F1,
                      'specificity': cm.specificity,
                      'tp': cm.tp,
                      'fp': cm.fp,
                      'fn': cm.fn,
                      'tn': cm.tn}
    return(new_record_dict)

# %%
HGBR_results = pd.DataFrame()

#create function to test Gradient Boosting model
def HGBR(cv_fold, 
         X_vars=X_cols,
         y_var='frwd01_mon_metro_hvi_pct_chg',
         learning_rate=.1,
         min_samples_leaf=20,
         max_depth=None,
         seed=42, 
         HGBR_results_df=HGBR_results):

    fold = cv_fold['fold']
    train_df = sample_dfs[cv_fold['train_df']]
    test_df = sample_dfs[cv_fold['test_df']]
    
    #identify and drop columns with over 75% of data missing in training dataset
    drop_cols = train_df.isna().sum().divide(len(train_df)).sort_values(ascending=False).reset_index().rename(columns={'index':'col',0:'missing'})
    drop_cols['drop'] = np.where(drop_cols['missing'] > .70, "drop", "keep")
    drop_cols = list(drop_cols[drop_cols['drop'] == 'drop'].col)
    train_df = train_df.drop(columns=drop_cols)
    test_df = test_df.drop(columns=drop_cols)
    X_cols_rf = [col for col in X_vars if col not in drop_cols]

    #define training set
    train_df = train_df.replace(np.inf, np.nan)
    train_df = train_df.dropna(subset=[y_var])
    X = train_df[X_cols_rf[7:]]
    y = train_df[y_var]

    #train and score model with training data
    hgbr = HistGradientBoostingRegressor(learning_rate=learning_rate,
                                         min_samples_leaf=min_samples_leaf,
                                         max_depth=max_depth,
                                         random_state=seed)
    hgbr.fit(X, y)
    train_score = hgbr.score(X, y)

    #predict and score with test data
    test_df = test_df.replace(np.inf, np.nan)
    test_df = test_df.dropna(subset=[y_var])
    X_test = test_df[X_cols_rf[7:]]
    y_test = test_df[y_var]
    test_score = hgbr.score(X_test, y_test)
    y_pred = hgbr.predict(X_test)
    error = mae(y_test, y_pred)
    
    #create categorization of prediction
    results_index = test_df[X_vars[:7]].reset_index()
    results = pd.DataFrame(zip(y_test,y_pred), columns=['y_test','y_pred']).reset_index()
    test_results = pd.concat([results_index, results], axis=1)
    test_results['y_diff'] = test_results['y_pred'] - test_results['y_test']
    test_results['direction'] = ((test_results['y_test']*test_results['y_pred'])/
                                  abs(test_results['y_test']*test_results['y_pred']))
    test_results['direction'] = np.where(test_results['direction'] == 1, "same", "diff")
    cm, cm_pct = conf_matrix(test_results)
    hgbr_cm = confusion_matrix_class(cm)

    #add record to test results df
    new_record = create_results_record(model='HGBR', 
                                       cv_fold=fold, 
                                       y_var=y_var, 
                                       dataset='test', 
                                       cm=hgbr_cm,
                                       error=error)
                  
    HGBR_results_df = pd.concat([HGBR_results_df, pd.DataFrame([new_record])], ignore_index=True).drop_duplicates()
    HGBR_results_df[['tp','fp','fn','tn']] = HGBR_results_df[['tp','fp','fn','tn']].astype(int)
    
    return(HGBR_results_df, test_results)

# %%
y_focus = [col for col in y_cols if "mon_metro_hvi_pct_chg" in col]

# %%
for y in y_focus:

    for i in range(len(cv_folds)):

        cv_fold = cv_folds.loc[i]
        HGBR_results, test_results = HGBR(cv_fold,
                                          y_var=y,
                                          HGBR_results_df=HGBR_results)

# %%
mean_df = HGBR_results.groupby(['model','y','dataset'])[HGBR_results.select_dtypes(include=np.number).columns.tolist()].mean().reset_index()
mean_df['cv_fold'] = 'mean'

HGBR_results = pd.concat([HGBR_results, mean_df], ignore_index=True)
HGBR_results = HGBR_results.sort_values(['y','cv_fold']).drop_duplicates(subset=['cv_fold','y','dataset']).reset_index().drop(columns='index')
HGBR_results.sort_values(by=['recall'], ascending=False)
# Out:
#    model cv_fold                             y dataset       mae  accuracy  \
# 3   HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003025  0.930649
# 2   HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004635  0.967002
# 0   HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003167  0.941462
# 7   HGBR  samp_3  frwd02_mon_metro_hvi_pct_chg    test  0.008934  0.889914
# 6   HGBR  samp_2  frwd02_mon_metro_hvi_pct_chg    test  0.012409  0.962528
# 1   HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001840  0.926734
# 4   HGBR    mean  frwd02_mon_metro_hvi_pct_chg    test  0.008707  0.922912
# 5   HGBR  samp_1  frwd02_mon_metro_hvi_pct_chg    test  0.004777  0.916294
# 11  HGBR  samp_3  frwd03_mon_metro_hvi_pct_chg    test  0.016925  0.877983
# 9   HGBR  samp_1  frwd03_mon_metro_hvi_pct_chg    test  0.008768  0.915362
# 8   HGBR    mean  frwd03_mon_metro_hvi_pct_chg    test  0.013997  0.920116
# 15  HGBR  samp_3  frwd04_mon_metro_hvi_pct_chg    test  0.025658  0.855239
# 13  HGBR  samp_1  frwd04_mon_metro_hvi_pct_chg    test  0.012396  0.933352
# 12  HGBR    mean  frwd04_mon_metro_hvi_pct_chg    test  0.020696  0.917878
# 10  HGBR  samp_2  frwd03_mon_metro_hvi_pct_chg    test  0.016300  0.967002
# 17  HGBR  samp_1  frwd06_mon_metro_hvi_pct_chg    test  0.018806  0.961689
# 19  HGBR  samp_3  frwd06_mon_metro_hvi_pct_chg    test  0.036419  0.880872
# 21  HGBR  samp_1  frwd07_mon_metro_hvi_pct_chg    test  0.022692  0.973248
# 16  HGBR    mean  frwd06_mon_metro_hvi_pct_chg    test  0.028316  0.937547
# 20  HGBR    mean  frwd07_mon_metro_hvi_pct_chg    test  0.032769  0.941182
# 23  HGBR  samp_3  frwd07_mon_metro_hvi_pct_chg    test  0.041483  0.877517
# 14  HGBR  samp_2  frwd04_mon_metro_hvi_pct_chg    test  0.024035  0.965045
# 18  HGBR  samp_2  frwd06_mon_metro_hvi_pct_chg    test  0.029722  0.970078
# 22  HGBR  samp_2  frwd07_mon_metro_hvi_pct_chg    test  0.034130  0.972782
#
#     precision    recall        F1  specificity          tp          fp  \
# 3    0.545611  0.745882  0.630219     0.946548  634.000000  528.000000
# 2    0.494845  0.687679  0.575540     0.976395  240.000000  245.000000
# 0    0.567282  0.650071  0.595295     0.964738  472.333333  350.333333
# 7    0.398561  0.616240  0.484054     0.914946  554.000000  836.000000
# 6    0.430288  0.520349  0.471053     0.977176  179.000000  237.000000
# 1    0.661389  0.516651  0.580128     0.971272  543.000000  278.000000
# 4    0.437155  0.511356  0.463679     0.951458  360.000000  481.666667
# 5    0.482615  0.397480  0.435930     0.962253  347.000000  372.000000
# 11   0.343721  0.387397  0.364254     0.926639  375.000000  716.000000
# 9    0.314241  0.303892  0.308980     0.955964  203.000000  443.000000
# 8    0.383011  0.282513  0.303435     0.959037  211.000000  405.333333
# 15   0.243786  0.250737  0.247213     0.918546  255.000000  791.000000
# 13   0.264770  0.242000  0.252874     0.967149  121.000000  336.000000
# 12   0.502852  0.166891  0.171945     0.961898  126.333333  375.666667
# 10   0.491071  0.156250  0.237069     0.994507   55.000000   57.000000
# 17   0.162162  0.104895  0.127389     0.985156   30.000000  155.000000
# 19   0.279461  0.072363  0.114958     0.977664   83.000000  214.000000
# 21   0.142857  0.070755  0.094637     0.991442   15.000000   90.000000
# 16   0.220812  0.059086  0.121173     0.987607   37.666667  123.000000
# 20   0.210526  0.033412  0.073976     0.993769   17.333333   62.000000
# 23   0.278195  0.029482  0.053314     0.989866   37.000000   96.000000
# 14   1.000000  0.007937  0.015748     1.000000    3.000000    0.000000
# 18        NaN  0.000000       NaN     1.000000    0.000000    0.000000
# 22        NaN  0.000000       NaN     1.000000    0.000000    0.000000
#
#              fn            tn
# 3    216.000000   9350.000000
# 2    109.000000  10134.000000
# 0    277.666667   9627.666667
# 7    345.000000   8993.000000
# 6    165.000000  10147.000000
# 1    508.000000   9399.000000
# 4    345.333333   9541.000000
# 5    526.000000   9483.000000
# 11   593.000000   9044.000000
# 9    465.000000   9617.000000
# 8    451.666667   9660.000000
# 15   762.000000   8920.000000
# 13   379.000000   9892.000000
# 12   505.333333   9720.666667
# 10   297.000000  10319.000000
# 17   256.000000  10287.000000
# 19  1064.000000   9367.000000
# 21   197.000000  10426.000000
# 16   547.000000  10020.333333
# 20   569.000000  10079.666667
# 23  1218.000000   9377.000000
# 14   375.000000  10350.000000
# 18   321.000000  10407.000000
# 22   292.000000  10436.000000

# %% [markdown]
# Will focus on predicting whether price will increase or decrease in the following month

# %% [markdown]
# # Tuning

# %% [markdown]
# Set y variable for focus of analysis

# %%
y_var = 'frwd01_mon_metro_hvi_pct_chg'

# %% [markdown]
# Identify variations of features to use for tuning

# %%
#set X features (all pct change lag from 1 month, selective other pct lag, clusters, and normalized amounts for current period)
X_cols_1 = (X_cols[:7]+
            X_cols[X_cols.index('metro_for_sale_inventory_normalized'):
                   X_cols.index('prev01_mon_metro_for_sale_inventory')]+
            X_cols[X_cols.index('prev01_mon_metro_for_sale_inventory_pct_chg'):
                   X_cols.index('prev01_mon_state_job_openings_szn_adjd_pct_chg')]+
            ['prev02_mon_metro_hvi']+
            ['prev02_mon_metro_rent']+
            ['prev02_mon_state_job_openings_pct_chg']+
            ['prev02_mon_state_population_pct_chg']+
            ['prev02_mon_state_personal_income_pct_chg']+
            ['prev03_mon_metro_hvi']+
            ['prev03_mon_metro_rent']+
            ['prev03_mon_state_job_openings_pct_chg']+
            ['prev03_mon_state_population_pct_chg']+
            ['prev03_mon_state_personal_income_pct_chg']+
            ['prev06_mon_metro_hvi']+
            ['prev06_mon_metro_rent']+
            ['prev06_mon_state_job_openings_pct_chg']+
            ['prev06_mon_state_population_pct_chg']+
            ['prev06_mon_state_personal_income_pct_chg']+
            X_cols[-5:])
X_cols_1.remove('state_job_openings_szn_adjd_normalized')
X_cols_1.remove('state_personal_income_per_capita_normalized')
X_cols_1.remove('prev01_mon_state_personal_income_per_capita_pct_chg')

# %%
#set X features (all pct change lag and normalized amounts for current period)
X_cols_2 = (X_cols[:7]+
            X_cols[X_cols.index('metro_for_sale_inventory_normalized'):
                   X_cols.index('prev01_mon_metro_for_sale_inventory')]+
            X_cols[X_cols.index('prev01_mon_metro_for_sale_inventory_pct_chg'):
                   X_cols.index('prev01_mon_state_job_openings_szn_adjd_pct_chg')]+
            X_cols[X_cols.index('prev02_mon_metro_for_sale_inventory_pct_chg'):
                   X_cols.index('prev02_mon_state_job_openings_szn_adjd_pct_chg')]+
            X_cols[X_cols.index('prev03_mon_metro_for_sale_inventory_pct_chg'):
                   X_cols.index('prev03_mon_state_job_openings_szn_adjd_pct_chg')]+
            X_cols[X_cols.index('prev06_mon_metro_for_sale_inventory_pct_chg'):
                   X_cols.index('prev06_mon_state_job_openings_szn_adjd_pct_chg')])

# %% [markdown]
# *****
# **Baseline model**
# *****
# Create baseline model (prediction constant as average % change for each metro area)

# %%
start_time = time.time()
baseline_results_df = pd.DataFrame()

for i in range(len(cv_folds)):
    #set datasets for cross validation fold
    cv_fold = cv_folds.loc[i]
    fold = cv_fold['fold']
    train_df = sample_dfs[cv_fold['train_df']].dropna(subset=y_var)
    train_df = train_df.replace(np.inf, np.nan)
    test_df = sample_dfs[cv_fold['test_df']].dropna(subset=y_var)
    test_df = test_df.replace(np.inf, np.nan)
    
    #train model
    baseline_y_pred = train_df.groupby('metro_id')[y_var].agg(['mean','median']).reset_index()
    train_df = train_df.merge(baseline_y_pred, on='metro_id')

    #use mean for baseline
    train_df['y_true'] = np.where(train_df[y_var] >= 0, 0, 1)
    train_df['y_pred'] = np.where(train_df['mean'] >= 0, 0, 1)
    baseline_cm = confusion_matrix_class(confusion_matrix(train_df['y_true'], train_df['y_pred']))
    train_error = mae(train_df[y_var],train_df['mean'])

    new_record = create_results_record(model="baseline_mean", 
                                       cv_fold=fold,
                                       y_var=y_var, 
                                       dataset="train", 
                                       cm=baseline_cm,
                                       error=train_error)
    baseline_results_df = pd.concat([baseline_results_df, pd.DataFrame([new_record])], ignore_index=True)

    #test model
    test_df = test_df.merge(baseline_y_pred, on='metro_id')
    test_df['y_true'] = np.where(test_df[y_var] >= 0, 1, 0)
    test_df['y_pred'] = np.where(test_df['mean'] >= 0, 1, 0)
    baseline_cm = confusion_matrix_class(confusion_matrix(test_df['y_true'], test_df['y_pred']))
    test_error = mae(test_df[y_var],test_df['mean'])

    new_record = create_results_record(model="baseline_mean", 
                                       cv_fold=fold,
                                       y_var=y_var, 
                                       dataset="test", 
                                       cm=baseline_cm,
                                       error=test_error)
    baseline_results_df = pd.concat([baseline_results_df, pd.DataFrame([new_record])], ignore_index=True)
    
    
mean_df = baseline_results_df.groupby(['model','y','dataset'])[baseline_results_df.select_dtypes(include=np.number).columns.tolist()].mean().reset_index()
mean_df['cv_fold'] = 'mean'

baseline_results_df = pd.concat([baseline_results_df, mean_df], ignore_index=True)
baseline_results_df = baseline_results_df.sort_values(['dataset','y','cv_fold']).drop_duplicates(subset=['cv_fold','y','dataset']).reset_index().drop(columns='index')

compare_df = pd.concat([compare_df, 
                        baseline_results_df[(baseline_results_df['cv_fold'] == 'mean') & 
                                            (baseline_results_df['dataset'] == 'test')]],
                       axis=0)
compare_df[['tp','fp','fn','tn']] = compare_df[['tp','fp','fn','tn']].astype(int)
compare_df = compare_df.drop_duplicates()

end_time = time.time()
execution_duration = end_time - start_time
print(f"Execution time: {execution_duration:.2f} seconds")

baseline_results_df
# Out:
# Execution time: 0.25 seconds
#            model cv_fold                             y dataset       mae  \
# 0  baseline_mean    mean  frwd01_mon_metro_hvi_pct_chg    test  0.006199
# 1  baseline_mean  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002956
# 2  baseline_mean  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.009248
# 3  baseline_mean  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.006392
# 4  baseline_mean    mean  frwd01_mon_metro_hvi_pct_chg   train  0.003374
# 5  baseline_mean  samp_1  frwd01_mon_metro_hvi_pct_chg   train  0.002753
# 6  baseline_mean  samp_2  frwd01_mon_metro_hvi_pct_chg   train  0.002744
# 7  baseline_mean  samp_3  frwd01_mon_metro_hvi_pct_chg   train  0.004623
#
#    accuracy  precision    recall        F1  specificity            tp  \
# 0  0.923254   0.063960  0.296980  0.096363     0.933224     45.333333
# 1  0.891033   0.086584  0.303333  0.134715     0.907940     91.000000
# 2  0.958706   0.088825  0.198718  0.122772     0.969921     31.000000
# 3  0.920022   0.016471  0.388889  0.031603     0.921811     14.000000
# 4  0.894469   0.992705  0.899377  0.943732     0.540653  24693.666667
# 5  0.883965   0.987137  0.892375  0.937367     0.580786  14734.000000
# 6  0.888941   0.992521  0.894109  0.940748     0.523316  24419.000000
# 7  0.910501   0.998456  0.911649  0.953080     0.517857  34928.000000
#
#            fp           fn            tn
# 0  704.666667   118.666667   9859.333333
# 1  960.000000   209.000000   9468.000000
# 2  318.000000   125.000000  10254.000000
# 3  836.000000    22.000000   9856.000000
# 4  143.333333  2684.666667    175.333333
# 5  192.000000  1777.000000    266.000000
# 6  184.000000  2892.000000    202.000000
# 7   54.000000  3385.000000     58.000000

# %%
baseline_results_df[baseline_results_df.cv_fold=='mean']
# Out:
#            model cv_fold                             y dataset       mae  \
# 0  baseline_mean    mean  frwd01_mon_metro_hvi_pct_chg    test  0.006199
# 4  baseline_mean    mean  frwd01_mon_metro_hvi_pct_chg   train  0.003374
#
#    accuracy  precision    recall        F1  specificity            tp  \
# 0  0.923254   0.063960  0.296980  0.096363     0.933224     45.333333
# 4  0.894469   0.992705  0.899377  0.943732     0.540653  24693.666667
#
#            fp           fn           tn
# 0  704.666667   118.666667  9859.333333
# 4  143.333333  2684.666667   175.333333

# %% [markdown]
# *****
# **Historical Gradient Boosting Model (HGBM)**
# *****
# Tune historical gradient boosting model and assess results

# %%
#set parameter ranges for tuning HGBR model
random.seed(42)
k=15

learning_rate_rdm = np.array(random.choices(range(0,15),k=k)) / 100 + .01
min_samples_leaf_rdm = np.array(random.choices(range(100,201),k=k))
max_depth_rdm = np.array(random.choices(range(5,21),k=k))

params_df = pd.DataFrame({'learning_rate':learning_rate_rdm,
                          'min_samples_leaf':min_samples_leaf_rdm,
                          'max_depth':max_depth_rdm})

# %%
#test with all X columns
start_time = time.time()
HGBR_cv_results = pd.DataFrame(columns=['idx'])
X_vars = X_cols
m_name = 'HGBR|x0|'

for idx in range(k):
    for i in range(len(cv_folds)):

        cv_fold = cv_folds.loc[i]
        HGBR_cv_results, test_results = HGBR(cv_fold,
                                             X_vars=X_vars,
                                             y_var=y_var,
                                             learning_rate=learning_rate_rdm[idx],
                                             min_samples_leaf=min_samples_leaf_rdm[idx],
                                             max_depth=max_depth_rdm[idx],
                                             HGBR_results_df=HGBR_cv_results)
    
    HGBR_cv_results['idx'] = HGBR_cv_results['idx'].fillna(str(idx).zfill(2))
    mean_df = HGBR_cv_results.groupby(['model','y','dataset','idx'])[HGBR_cv_results.select_dtypes(include=np.number).columns.tolist()].mean().reset_index()
    mean_df['cv_fold'] = 'mean'
    

    HGBR_cv_results = pd.concat([HGBR_cv_results, mean_df], ignore_index=True)
    HGBR_cv_results = HGBR_cv_results.sort_values(['y','cv_fold','dataset']).drop_duplicates(subset=['cv_fold','y','idx','dataset']).reset_index().drop(columns='index')


cv_results = pd.concat([params_df,HGBR_cv_results[HGBR_cv_results.cv_fold == 'mean']], axis=1).drop(columns=['idx'])
cv_results['model'] = m_name+cv_results['learning_rate'].round(2).astype(str)+"-"+cv_results['min_samples_leaf'].astype(str)+"-"+cv_results['max_depth'].astype(str)
cv_results[['tp','fp','fn','tn']] = cv_results[['tp','fp','fn','tn']].astype(int)

compare_df = pd.concat([compare_df, 
                        cv_results.drop(columns=['learning_rate','min_samples_leaf','max_depth'])],
                       axis=0).drop_duplicates()

end_time = time.time()
execution_duration = end_time - start_time
print(f"Execution time: {execution_duration:.2f} seconds")

cv_results.sort_values('recall', ascending=False)
# Out:
# Execution time: 135.16 seconds
#     learning_rate  min_samples_leaf  max_depth                model cv_fold  \
# 0            0.10               102         20   HGBR|x0|0.1-102-20    mean
# 6            0.14               181         17  HGBR|x0|0.14-181-17    mean
# 4            0.12               122         18  HGBR|x0|0.12-122-18    mean
# 8            0.07               181         13  HGBR|x0|0.07-181-13    mean
# 5            0.11               159         14  HGBR|x0|0.11-159-14    mean
# 11           0.08               115         13  HGBR|x0|0.08-115-13    mean
# 2            0.05               165          6   HGBR|x0|0.05-165-6    mean
# 10           0.04               134         11  HGBR|x0|0.04-134-11    mean
# 3            0.04               155          6   HGBR|x0|0.04-155-6    mean
# 7            0.02               100         16  HGBR|x0|0.02-100-16    mean
# 9            0.01               170         20  HGBR|x0|0.01-170-20    mean
# 1            0.01               120         10  HGBR|x0|0.01-120-10    mean
#
#                                y dataset       mae  accuracy  precision  \
# 0   frwd01_mon_metro_hvi_pct_chg    test  0.003309  0.939411   0.546813
# 6   frwd01_mon_metro_hvi_pct_chg    test  0.003239  0.940654   0.558574
# 4   frwd01_mon_metro_hvi_pct_chg    test  0.003347  0.941151   0.556751
# 8   frwd01_mon_metro_hvi_pct_chg    test  0.003324  0.944879   0.590451
# 5   frwd01_mon_metro_hvi_pct_chg    test  0.003252  0.944848   0.587991
# 11  frwd01_mon_metro_hvi_pct_chg    test  0.003264  0.944041   0.578704
# 2   frwd01_mon_metro_hvi_pct_chg    test  0.003199  0.945439   0.603217
# 10  frwd01_mon_metro_hvi_pct_chg    test  0.003224  0.945004   0.605621
# 3   frwd01_mon_metro_hvi_pct_chg    test  0.003201  0.946340   0.621013
# 7   frwd01_mon_metro_hvi_pct_chg    test  0.003369  0.949167   0.701353
# 9   frwd01_mon_metro_hvi_pct_chg    test  0.003805  0.944072   0.852045
# 1   frwd01_mon_metro_hvi_pct_chg    test  0.003868  0.942953   0.841731
#
#       recall        F1  specificity   tp   fp   fn    tn
# 0   0.649848  0.582180     0.962970  468  368  281  9609
# 6   0.649626  0.590403     0.963636  474  361  275  9616
# 4   0.649514  0.588403     0.964934  468  349  282  9628
# 8   0.644869  0.606050     0.968714  469  311  280  9667
# 5   0.639749  0.604945     0.969382  462  304  287  9673
# 11  0.639617  0.599886     0.968169  466  316  284  9661
# 2   0.609250  0.602745     0.970748  454  289  296  9688
# 10  0.602765  0.598458     0.970786  449  289  301  9689
# 3   0.588611  0.601612     0.973423  437  262  313  9715
# 7   0.473958  0.564416     0.985575  347  142  402  9835
# 9   0.271036  0.401312     0.996927  180   30  569  9947
# 1   0.260535  0.386439     0.996903  169   31  581  9947

# %%
#test results for each fold
HGBR_cv_results.sort_values(by=['idx','cv_fold'])
# Out:
#    idx model cv_fold                             y dataset       mae  \
# 0   00  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003309
# 12  00  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001842
# 24  00  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.005050
# 36  00  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003034
# 1   01  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003868
# 13  01  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002018
# 25  01  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.006024
# 37  01  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003563
# 2   02  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003199
# 14  02  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001876
# 26  02  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004644
# 38  02  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003077
# 3   03  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003201
# 15  03  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001859
# 27  03  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004676
# 39  03  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003069
# 4   04  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003347
# 16  04  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001831
# 28  04  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.005250
# 40  04  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.002960
# 5   05  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003252
# 17  05  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001855
# 29  05  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004830
# 41  05  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003070
# 6   06  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003239
# 18  06  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001940
# 30  06  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004557
# 42  06  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003219
# 7   07  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003369
# 19  07  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001875
# 31  07  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.005177
# 43  07  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003054
# 8   08  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003324
# 20  08  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001855
# 32  08  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004963
# 44  08  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003153
# 9   09  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003805
# 21  09  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002010
# 33  09  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.005839
# 45  09  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003566
# 10  10  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003224
# 22  10  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001828
# 34  10  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004791
# 46  10  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003054
# 11  11  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003264
# 23  11  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001829
# 35  11  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004975
# 47  11  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.002988
#
#     accuracy  precision    recall        F1  specificity     tp          fp  \
# 0   0.939411   0.546813  0.649848  0.582180     0.962970  468.0  368.000000
# 12  0.924124   0.640237  0.514748  0.570675     0.968585  541.0  304.000000
# 24  0.961596   0.443447  0.707736  0.545254     0.970132  247.0  310.000000
# 36  0.932513   0.556757  0.727059  0.630612     0.950192  618.0  492.000000
# 1   0.942953   0.841731  0.260535  0.386439     0.996903  169.0   31.000000
# 13  0.917506   0.860870  0.188392  0.309133     0.996693  198.0   32.000000
# 25  0.976510   0.777143  0.389685  0.519084     0.996242  136.0   39.000000
# 37  0.934843   0.887179  0.203529  0.331100     0.997773  173.0   22.000000
# 2   0.945439   0.603217  0.609250  0.602745     0.970748  454.0  289.000000
# 14  0.924590   0.640371  0.525214  0.577104     0.967965  552.0  310.000000
# 2   296.0   9688.000000
# 14  499.0   9367.000000
# 26  142.0  10222.000000
# 38  247.0   9477.000000
# 3   313.0   9715.000000
# 15  513.0   9386.000000
# 27  145.0  10245.000000
# 39  281.0   9515.000000
# 4   282.0   9628.000000
# 16  501.0   9371.000000
# 28  100.0  10064.000000
# 40  245.0   9451.000000
# 5   287.0   9673.000000
# 17  507.0   9385.000000
# 29  107.0  10136.000000
# 41  248.0   9500.000000
# 6   275.0   9616.000000
# 18  503.0   9387.000000
# 30  114.0  10122.000000
# 42  209.0   9341.000000
# 7   402.0   9835.000000
# 19  601.0   9501.000000
# 31  173.0  10292.000000
# 43  434.0   9713.000000
# 8   280.0   9667.000000
# 20  518.0   9425.000000
# 32  114.0  10149.000000
# 44  209.0   9427.000000
# 9   569.0   9947.000000
# 21  810.0   9639.000000
# 33  213.0  10343.000000
# 45  685.0   9860.000000
# 10  301.0   9689.000000
# 22  521.0   9397.000000
# 34  146.0  10232.000000
# 46  236.0   9438.000000
# 11  284.0   9661.666667
# 23  513.0   9374.000000
# 35  115.0  10130.000000
# 47  224.0   9481.000000

# %%
#test with first subset of X columns
start_time = time.time()
HGBR_cv_results = pd.DataFrame(columns=['idx'])
X_vars = X_cols_1
m_name = 'HGBR|x1|'

for idx in range(k):
    for i in range(len(cv_folds)):

        cv_fold = cv_folds.loc[i]
        HGBR_cv_results, test_results = HGBR(cv_fold,
                                             X_vars=X_vars,
                                             y_var=y_var,
                                             learning_rate=learning_rate_rdm[idx],
                                             min_samples_leaf=min_samples_leaf_rdm[idx],
                                             max_depth=max_depth_rdm[idx],
                                             HGBR_results_df=HGBR_cv_results)
    
    HGBR_cv_results['idx'] = HGBR_cv_results['idx'].fillna(str(idx).zfill(2))
    mean_df = HGBR_cv_results.groupby(['model','y','dataset','idx'])[HGBR_cv_results.select_dtypes(include=np.number).columns.tolist()].mean().reset_index()
    mean_df['cv_fold'] = 'mean'
    

    HGBR_cv_results = pd.concat([HGBR_cv_results, mean_df], ignore_index=True)
    HGBR_cv_results = HGBR_cv_results.sort_values(['y','cv_fold','dataset']).drop_duplicates(subset=['cv_fold','y','idx','dataset']).reset_index().drop(columns='index')


cv_results = pd.concat([params_df,HGBR_cv_results[HGBR_cv_results.cv_fold == 'mean']], axis=1).drop(columns=['idx'])
cv_results['model'] = m_name+cv_results['learning_rate'].round(2).astype(str)+"-"+cv_results['min_samples_leaf'].astype(str)+"-"+cv_results['max_depth'].astype(str)
cv_results[['tp','fp','fn','tn']] = cv_results[['tp','fp','fn','tn']].astype(int)

compare_df = pd.concat([compare_df, 
                        cv_results.drop(columns=['learning_rate','min_samples_leaf','max_depth'])],
                       axis=0).drop_duplicates()

end_time = time.time()
execution_duration = end_time - start_time
print(f"Execution time: {execution_duration:.2f} seconds")

cv_results.sort_values('recall', ascending=False)
# Out:
# Execution time: 53.60 seconds
#     learning_rate  min_samples_leaf  max_depth                model cv_fold  \
# 0            0.10               102         20   HGBR|x1|0.1-102-20    mean
# 4            0.12               122         18  HGBR|x1|0.12-122-18    mean
# 5            0.11               159         14  HGBR|x1|0.11-159-14    mean
# 6            0.14               181         17  HGBR|x1|0.14-181-17    mean
# 11           0.08               115         13  HGBR|x1|0.08-115-13    mean
# 8            0.07               181         13  HGBR|x1|0.07-181-13    mean
# 10           0.04               134         11  HGBR|x1|0.04-134-11    mean
# 2            0.05               165          6   HGBR|x1|0.05-165-6    mean
# 3            0.04               155          6   HGBR|x1|0.04-155-6    mean
# 7            0.02               100         16  HGBR|x1|0.02-100-16    mean
# 9            0.01               170         20  HGBR|x1|0.01-170-20    mean
# 1            0.01               120         10  HGBR|x1|0.01-120-10    mean
#
#                                y dataset       mae  accuracy  precision  \
# 0   frwd01_mon_metro_hvi_pct_chg    test  0.003676  0.928132   0.484059
# 4   frwd01_mon_metro_hvi_pct_chg    test  0.003726  0.929623   0.488598
# 5   frwd01_mon_metro_hvi_pct_chg    test  0.003706  0.928909   0.484103
# 6   frwd01_mon_metro_hvi_pct_chg    test  0.003527  0.932606   0.500445
# 11  frwd01_mon_metro_hvi_pct_chg    test  0.003638  0.927635   0.481653
# 8   frwd01_mon_metro_hvi_pct_chg    test  0.003596  0.929654   0.489763
# 10  frwd01_mon_metro_hvi_pct_chg    test  0.003581  0.934377   0.536074
# 2   frwd01_mon_metro_hvi_pct_chg    test  0.003463  0.938821   0.545443
# 3   frwd01_mon_metro_hvi_pct_chg    test  0.003469  0.939597   0.555889
# 7   frwd01_mon_metro_hvi_pct_chg    test  0.003578  0.945532   0.634524
# 9   frwd01_mon_metro_hvi_pct_chg    test  0.003926  0.942301   0.816326
# 1   frwd01_mon_metro_hvi_pct_chg    test  0.003975  0.941368   0.817418
#
#       recall        F1  specificity   tp   fp   fn    tn
# 0   0.659046  0.538951     0.950359  474  495  275  9482
# 4   0.651575  0.538822     0.952645  468  473  281  9504
# 5   0.649582  0.535163     0.951836  469  482  280  9496
# 6   0.642789  0.547652     0.956041  466  439  283  9538
# 11  0.639421  0.534389     0.950744  464  490  285  9487
# 8   0.631816  0.533788     0.953614  458  463  291  9514
# 10  0.608450  0.560621     0.959281  449  403  300  9574
# 2   0.587906  0.559570     0.966258  429  335  321  9642
# 3   0.574349  0.558608     0.967927  420  318  329  9659
# 7   0.502111  0.558089     0.979414  369  204  380  9774
# 9   0.250898  0.376201     0.996321  167   36  582  9941
# 1   0.240593  0.359798     0.996645  154   33  595  9944

# %%
#test results for each fold
HGBR_cv_results.sort_values(by=['idx','cv_fold'])
# Out:
#    idx model cv_fold                             y dataset       mae  \
# 0   00  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003676
# 12  00  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001938
# 24  00  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.005433
# 36  00  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003658
# 1   01  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003975
# 13  01  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002109
# 25  01  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.006139
# 37  01  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003678
# 2   02  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003463
# 14  02  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001940
# 26  02  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004973
# 38  02  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003475
# 3   03  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003469
# 15  03  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001926
# 27  03  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004979
# 39  03  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003502
# 4   04  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003726
# 16  04  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001939
# 28  04  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.005671
# 40  04  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003568
# 5   05  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003706
# 17  05  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001916
# 29  05  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.005682
# 41  05  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003521
# 6   06  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003527
# 18  06  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001952
# 30  06  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.005030
# 42  06  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003599
# 7   07  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.
# 45  0.934284   0.864322  0.202353  0.327931     0.997267  172.000000
# 10  0.934377   0.536074  0.608450  0.560621     0.959281  449.000000
# 22  0.923565   0.635404  0.515699  0.569328     0.967862  542.000000
# 34  0.968494   0.513189  0.613181  0.558747     0.980441  214.000000
# 46  0.911074   0.459627  0.696471  0.553789     0.929540  592.000000
# 11  0.927635   0.481653  0.639421  0.534389     0.950744  464.333333
# 23  0.922073   0.620922  0.525214  0.569072     0.965175  552.000000
# 35  0.952368   0.373437  0.684814  0.483316     0.961364  239.000000
# 47  0.908464   0.450599  0.708235  0.550778     0.925693  602.000000
#
#             fp          fn            tn
# 0   495.000000  275.000000   9482.000000
# 12  322.000000  501.000000   9355.000000
# 24  469.000000   97.000000   9910.000000
# 36  696.000000  228.000000   9182.000000
# 1    33.000000  595.000000   9944.000000
# 13   29.000000  887.000000   9648.000000
# 25   45.000000  223.000000  10334.000000
# 37   27.000000  676.000000   9851.000000
# 2   335.000000  321.000000   9642.000000
# 14  325.000000  509.000000   9352.000000
# 26  266.000000  129.000000  10113.000000
# 38  415.000000  325.000000   9463.000000
# 3   318.000000  329.000000   9659.000000
# 15  284.000000  519.000000   9393.000000
# 27  237.000000  137.000000  10142.000000
# 39  435.000000  332.000000   9443.000000
# 4   473.000000  281.000000   9504.000000
# 16  327.000000  503.000000   9350.000000
# 28  507.000000   98.000000   9872.000000
# 40  587.000000  243.000000   9291.000000
# 5   482.000000  280.000000   9496.000000
# 17  334.000000  496.000000   9343.000000
# 29  531.000000  102.000000   9848.000000
# 41  581.000000  244.000000   9297.000000
# 6   439.000000  283.000000   9538.000000
# 18  350.000000  475.000000   9327.000000
# 30  468.000000  105.000000   9911.000000
# 42  500.000000  271.000000   9378.000000
# 7   204.000000  380.000000   9774.000000
# 19  205.000000  566.000000   9472.000000
# 31  129.000000  165.000000  10250.000000
# 43  278.000000  410.000000   9600.000000
# 8   463.000000  291.000000   9514.000000
# 20  304.000000  509.000000   9373.000000
# 32  450.000000  113.000000   9929.000000
# 44  636.000000  252.000000   9242.000000
# 9    36.000000  582.000000   9941.000000
# 21   44.000000  843.000000   9633.000000
# 33   39.000000  226.000000  10340.000000
# 45   27.000000  678.000000   9851.000000
# 10  403.000000  300.000000   9574.000000
# 22  311.000000  509.000000   9366.000000
# 34  203.000000  135.000000  10176.000000
# 46  696.000000  258.000000   9182.000000
# 11  490.666667  285.666667   9487.333333
# 23  337.000000  499.000000   9340.000000
# 35  401.000000  110.000000   9978.000000
# 47  734.000000  248.000000   9144.000000

# %%
#test with second subset of X columns
start_time = time.time()
HGBR_cv_results = pd.DataFrame(columns=['idx'])
X_vars = X_cols_2
m_name = 'HGBR|x2|'

for idx in range(k):
    for i in range(len(cv_folds)):

        cv_fold = cv_folds.loc[i]
        HGBR_cv_results, test_results = HGBR(cv_fold,
                                             X_vars=X_vars,
                                             y_var=y_var,
                                             learning_rate=learning_rate_rdm[idx],
                                             min_samples_leaf=min_samples_leaf_rdm[idx],
                                             max_depth=max_depth_rdm[idx],
                                             HGBR_results_df=HGBR_cv_results)
    
    HGBR_cv_results['idx'] = HGBR_cv_results['idx'].fillna(str(idx).zfill(2))
    mean_df = HGBR_cv_results.groupby(['model','y','dataset','idx'])[HGBR_cv_results.select_dtypes(include=np.number).columns.tolist()].mean().reset_index()
    mean_df['cv_fold'] = 'mean'
    

    HGBR_cv_results = pd.concat([HGBR_cv_results, mean_df], ignore_index=True)
    HGBR_cv_results = HGBR_cv_results.sort_values(['y','cv_fold','dataset']).drop_duplicates(subset=['cv_fold','y','idx','dataset']).reset_index().drop(columns='index')


cv_results = pd.concat([params_df,HGBR_cv_results[HGBR_cv_results.cv_fold == 'mean']], axis=1).drop(columns=['idx'])
cv_results['model'] = m_name+cv_results['learning_rate'].round(2).astype(str)+"-"+cv_results['min_samples_leaf'].astype(str)+"-"+cv_results['max_depth'].astype(str)
cv_results[['tp','fp','fn','tn']] = cv_results[['tp','fp','fn','tn']].astype(int)

compare_df = pd.concat([compare_df, 
                        cv_results.drop(columns=['learning_rate','min_samples_leaf','max_depth'])],
                       axis=0).drop_duplicates()

end_time = time.time()
execution_duration = end_time - start_time
print(f"Execution time: {execution_duration:.2f} seconds")

cv_results.sort_values('recall', ascending=False)
# Out:
# Execution time: 69.76 seconds
#     learning_rate  min_samples_leaf  max_depth                model cv_fold  \
# 4            0.12               122         18  HGBR|x2|0.12-122-18    mean
# 0            0.10               102         20   HGBR|x2|0.1-102-20    mean
# 8            0.07               181         13  HGBR|x2|0.07-181-13    mean
# 5            0.11               159         14  HGBR|x2|0.11-159-14    mean
# 6            0.14               181         17  HGBR|x2|0.14-181-17    mean
# 11           0.08               115         13  HGBR|x2|0.08-115-13    mean
# 2            0.05               165          6   HGBR|x2|0.05-165-6    mean
# 10           0.04               134         11  HGBR|x2|0.04-134-11    mean
# 3            0.04               155          6   HGBR|x2|0.04-155-6    mean
# 7            0.02               100         16  HGBR|x2|0.02-100-16    mean
# 9            0.01               170         20  HGBR|x2|0.01-170-20    mean
# 1            0.01               120         10  HGBR|x2|0.01-120-10    mean
#
#                                y dataset       mae  accuracy  precision  \
# 4   frwd01_mon_metro_hvi_pct_chg    test  0.003284  0.941337   0.560742
# 0   frwd01_mon_metro_hvi_pct_chg    test  0.003236  0.941586   0.562446
# 8   frwd01_mon_metro_hvi_pct_chg    test  0.003254  0.942332   0.565752
# 5   frwd01_mon_metro_hvi_pct_chg    test  0.003278  0.944103   0.581804
# 6   frwd01_mon_metro_hvi_pct_chg    test  0.003232  0.942549   0.566840
# 11  frwd01_mon_metro_hvi_pct_chg    test  0.003245  0.944942   0.586150
# 2   frwd01_mon_metro_hvi_pct_chg    test  0.003217  0.946651   0.619766
# 10  frwd01_mon_metro_hvi_pct_chg    test  0.003190  0.946122   0.612578
# 3   frwd01_mon_metro_hvi_pct_chg    test  0.003210  0.947179   0.628219
# 7   frwd01_mon_metro_hvi_pct_chg    test  0.003307  0.948359   0.688272
# 9   frwd01_mon_metro_hvi_pct_chg    test  0.003810  0.943606   0.849318
# 1   frwd01_mon_metro_hvi_pct_chg    test  0.003871  0.942953   0.837631
#
# 29  113.0  10129.000000
# 41  214.0   9441.000000
# 6   283.0   9644.000000
# 18  504.0   9385.000000
# 30  111.0  10096.000000
# 42  234.0   9453.000000
# 7   402.0   9826.000000
# 19  599.0   9501.000000
# 31  176.0  10288.000000
# 43  432.0   9690.000000
# 8   279.0   9638.000000
# 20  516.0   9405.000000
# 32  112.0  10091.000000
# 44  210.0   9420.000000
# 9   574.0   9947.000000
# 21  828.0   9641.000000
# 33  210.0  10341.000000
# 45  685.0   9860.000000
# 10  306.0   9706.000000
# 22  527.0   9400.000000
# 34  148.0  10230.000000
# 46  245.0   9490.000000
# 11  290.0   9677.333333
# 23  525.0   9425.000000
# 35  108.0  10081.000000
# 47  237.0   9526.000000

# %% [markdown]
# Summary of cross validation results for Historical Gradient Boosting Model

# %%
compare_df[['tp','fp','fn','tn']] = compare_df[['tp','fp','fn','tn']].astype(int)
compare_df[compare_df.model.str.contains("HGBR")].sort_values('recall', ascending=False).drop(columns=['y'])
# Out:
#                   model cv_fold dataset       mae  accuracy  precision  \
# 0    HGBR|x1|0.1-102-20    mean    test  0.003676  0.928132   0.484059
# 4   HGBR|x2|0.12-122-18    mean    test  0.003284  0.941337   0.560742
# 0    HGBR|x2|0.1-102-20    mean    test  0.003236  0.941586   0.562446
# 4   HGBR|x1|0.12-122-18    mean    test  0.003726  0.929623   0.488598
# 0    HGBR|x0|0.1-102-20    mean    test  0.003309  0.939411   0.546813
# 6   HGBR|x0|0.14-181-17    mean    test  0.003239  0.940654   0.558574
# 5   HGBR|x1|0.11-159-14    mean    test  0.003706  0.928909   0.484103
# 4   HGBR|x0|0.12-122-18    mean    test  0.003347  0.941151   0.556751
# 8   HGBR|x2|0.07-181-13    mean    test  0.003254  0.942332   0.565752
# 8   HGBR|x0|0.07-181-13    mean    test  0.003324  0.944879   0.590451
# 5   HGBR|x2|0.11-159-14    mean    test  0.003278  0.944103   0.581804
# 6   HGBR|x1|0.14-181-17    mean    test  0.003527  0.932606   0.500445
# 6   HGBR|x2|0.14-181-17    mean    test  0.003232  0.942549   0.566840
# 5   HGBR|x0|0.11-159-14    mean    test  0.003252  0.944848   0.587991
# 11  HGBR|x0|0.08-115-13    mean    test  0.003264  0.944041   0.578704
# 11  HGBR|x1|0.08-115-13    mean    test  0.003638  0.927635   0.481653
# 11  HGBR|x2|0.08-115-13    mean    test  0.003245  0.944942   0.586150
# 8   HGBR|x1|0.07-181-13    mean    test  0.003596  0.929654   0.489763
# 2    HGBR|x0|0.05-165-6    mean    test  0.003199  0.945439   0.603217
# 10  HGBR|x1|0.04-134-11    mean    test  0.003581  0.934377   0.536074
# 10  HGBR|x0|0.04-134-11    mean    test  0.003224  0.945004   0.605621
# 2    HGBR|x2|0.05-165-6    mean    test  0.003217  0.946651   0.619766
# 10  HGBR|x2|0.04-134-11    mean    test  0.003190  0.946122   0.612578
# 3    HGBR|x0|0.04-155-6    mean    test  0.003201  0.946340   0.621013
# 2    HGBR|x1|0.05-165-6    mean    test  0.003463  0.938821   0.545443
# 3    HGBR|x2|0.04-155-6    mean    test  0.003210  0.947179   0.628219
# 3    HGBR|x1|0.04-155-6    mean    test  0.003469  0.939597   0.555889
# 7   HGBR|x1|0.02-100-16    mean    test  0.003578  0.945532   0.634524
# 7   HGBR|x0|0.02-100-16    mean    test  0.003369  0.949167   0.701353
# 7   HGBR|x2|0.02-100-16    mean    test  0.003307  0.948359   0.688272
# 9   HGBR|x0|0.01-170-20    mean    test  0.003805  0.944072   0.852045
# 9   HGBR|x2|0.01-170-20    mean    test  0.003810  0.943606   0.849318
# 1   HGBR|x2|0.01-120-10    mean    test  0.003871  0.942953   0.837631
# 1   HGBR|x0|0.01-120-10    mean    test  0.003868  0.942953   0.841731
# 9   HGBR|x1|0.01-170-20    mean    test  0.003926  0.942301   0.816326
# 1   HGBR|x1|0.01-120-10    mean    test  0.003975  0.941368   0.817418
#
#       recall        F1  specificity   tp   fp   fn    tn
# 0   0.659046  0.538951     0.950359  474  495  275  9482
# 4   0.656879  0.588930     0.964717  472  352  277  9626
# 0   0.653103  0.589544     0.965546  467  343  283  9634
# 4   0.651575  0.538822     0.952645  468  473  281  9504
# 0   0.649848  0.582180     0.962970  468  368  281  9609
# 6   0.649626  0.590403     0.963636  474  361  275  9616
# 5   0.649582  0.535163     0.951836  469  482  280  9496
# 4   0.649514  0.588403     0.964934  468  349  282  9628
# 8   0.647021  0.591769     0.965926  470  339  279  9638
# 8   0.644869  0.606050     0.968714  469  311  280  9667
# 5   0.643229  0.600574     0.968096  467  317  282  9660
# 6   0.642789  0.547652     0.956041  466  439  283  9538
# 6   0.642370  0.592490     0.966511  467  333  283  9644
# 5   0.639749  0.604945     0.969382  462  304  287  9673
# 11  0.639617  0.599886     0.968169  466  316  284  9661
# 11  0.639421  0.534389     0.950744  464  490  285  9487
# 11  0.637399  0.597818     0.969871  460  300  290  9677
# 8   0.631816  0.533788     0.953614  458  463  291  9514
# 2   0.609250  0.602745     0.970748  454  289  296  9688
# 10  0.608450  0.560621     0.959281  449  403  300  9574
# 10  0.602765  0.598458     0.970786  449  289  301  9689
# 2   0.597783  0.605571     0.972674  447  270  302  9708
# 10  0.595423  0.599173     0.972580  443  271  306  9706
# 3   0.588611  0.601612     0.973423  437  262  313  9715
# 2   0.587906  0.559570     0.966258  429  335  321  9642
# 3   0.581083  0.601800     0.974592  434  251  315  9727
# 3   0.574349  0.558608     0.967927  420  318  329  9659
# 7   0.502111  0.558089     0.979414  369  204  380  9774
# 7   0.473958  0.564416     0.985575  347  142  402  9835
# 7   0.472511  0.559010     0.984671  347  151  402  9826
# 9   0.271036  0.401312     0.996927  180   30  569  9947
# 9   0.268192  0.396144     0.996932  175   30  574  9947
# 1   0.263718  0.388613     0.996772  170   32  579  9945
# 1   0.260535  0.386439     0.996903  169   31  581  9947
# 9   0.250898  0.376201     0.996321  167   36  582  9941
# 1   0.240593  0.359798     0.996645  154   33  595  9944

# %% [markdown]
# *****
# **Random forest model**
# *****
# Tune random forest regressor model and assess results

# %%
#create function to generate prediction and assess results from fitted model
def model_predict(model, results_df, df, set_name, pred_cols, y_var=y_var, m_name=m_name, fold=fold):
    X = df[pred_cols]
    
    df['y_pred_pct'] = model.predict(X)
    df['y_true'] = np.where(df[y_var] >= 0, 1, 0)
    df['y_pred'] = np.where(df['y_pred_pct'] >= 0, 1, 0)
    cm = confusion_matrix_class(confusion_matrix(df['y_true'], df['y_pred']))
    error = mae(df[y_var], df['y_pred_pct'])

    new_record = create_results_record(model=m_name, 
                                       cv_fold=fold,
                                       y_var=y_var, 
                                       dataset=set_name, 
                                       cm=cm,
                                       error=error)
    results_df = pd.concat([results_df, pd.DataFrame([new_record])], ignore_index=True)
    
    return(results_df)

# %%
#create function to train and test random forest model 
def RF(model_name, X_vars, y_var, cv_folds, RF_results_df, params):
    
    for idx in range(len(params)):
    
        n_est = params['n_estimators'][idx]
        min_samp_lf = params['min_samples_leaf'][idx]
        max_f = params['max_features'][idx]
        m_name = model_name+"|"+str(n_est)+"-"+str(min_samp_lf)+"-"+str(max_f)
        
        for i in range(len(cv_folds)):

            cv_fold = cv_folds.loc[i]
            fold = cv_fold['fold']
            train_df = sample_dfs[cv_fold['train_df']]
            test_df = sample_dfs[cv_fold['test_df']]

            #identify and drop columns with over 75% of data missing in training dataset
            drop_cols = train_df.isna().sum().divide(len(train_df)).sort_values(ascending=False).reset_index().rename(columns={'index':'col',0:'missing'})
            #print(drop_cols.to_string())
            drop_cols['drop'] = np.where(drop_cols['missing'] > .70, "drop", "keep")
            drop_cols = list(drop_cols[drop_cols['drop'] == 'drop'].col)
            train_df = train_df.drop(columns=drop_cols)
            test_df = test_df.drop(columns=drop_cols)
            X_cols_rf = [col for col in X_vars if col not in drop_cols]

            #define training set
            train_df = train_df.replace(np.inf, np.nan)
            train_df = train_df.dropna()
            X = train_df[X_cols_rf[7:]]
            y = train_df[y_var]

            #define test data
            test_df = test_df.replace(np.inf, np.nan)
            test_df = test_df.dropna()
            X_test = test_df[X_cols_rf[7:]]
            y_test = test_df[y_var]

            rf_model = RandomForestRegressor(n_estimators=n_est, 
                                             min_samples_leaf=params['min_samples_leaf'][idx],
                                             max_features=params['max_features'][idx],
                                             n_jobs=-1, 
                                             random_state=42)
            rf_model.fit(X, y)
            
            RF_results_df = model_predict(rf_model, RF_results_df, train_df, "train", X_cols_rf[7:], y_var, m_name, fold)
            RF_results_df = model_predict(rf_model, RF_results_df, test_df, "test", X_cols_rf[7:], y_var, m_name, fold)

    return(RF_results_df)

# %%
#set parameter ranges for tuning RF model
random.seed(42)

k=15
n_estimators_rdm = np.array(random.choices(range(10,101),k=k))
min_samples_leaf_rdm = np.array(random.choices(range(20,101),k=k))
max_features_rdm = np.array(random.choices(['sqrt','log2',None],k=k))

RF_params_df = pd.DataFrame({'n_estimators':n_estimators_rdm,
                             'min_samples_leaf':min_samples_leaf_rdm,
                             'max_features':max_features_rdm})

# %%
#test with all X columns
start_time = time.time()
RF_results_df = pd.DataFrame()

RF_results_df = RF(model_name='RF|x0', X_vars=X_cols, y_var=y_var, cv_folds=cv_folds, RF_results_df=RF_results_df, params=RF_params_df)

mean_df = RF_results_df.groupby(['model','y','dataset'])[RF_results_df.select_dtypes(include=np.number).columns.tolist()].mean().reset_index()
mean_df['cv_fold'] = 'mean'
RF_results_df = pd.concat([RF_results_df, mean_df], ignore_index=True)
RF_results_df = RF_results_df.sort_values(['y','cv_fold','dataset']).drop_duplicates(subset=['cv_fold','y','dataset','model']).reset_index().drop(columns='index')

compare_df = pd.concat([compare_df, 
                        RF_results_df[(RF_results_df['cv_fold'] == 'mean') & 
                                      (RF_results_df['dataset'] == 'test')]],
                       axis=0)

end_time = time.time()
execution_duration = end_time - start_time
print(f"Execution time: {execution_duration:.2f} seconds")

RF_results_df.head(k)
# Out:
# Execution time: 70.03 seconds
#                model cv_fold                             y dataset       mae  \
# 0   RF|x0|12-27-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.004699
# 1   RF|x0|12-37-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002922
# 2   RF|x0|12-97-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005425
# 3   RF|x0|17-47-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005249
# 4   RF|x0|28-88-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.004944
# 5   RF|x0|29-47-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002955
# 6   RF|x0|30-85-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002991
# 7   RF|x0|35-67-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005163
# 8   RF|x0|48-32-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002919
# 9   RF|x0|55-27-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.004691
# 10  RF|x0|68-64-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002961
# 11  RF|x0|69-68-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.004799
# 12  RF|x0|71-85-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005094
# 13  RF|x0|77-20-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.004990
# 14  RF|x0|91-76-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002974
#
#     accuracy  precision    recall        F1  specificity         tp  \
# 0   0.960557   0.064985  0.320635  0.147737     0.963654  14.000000
# 1   0.963340   0.448290  0.487110  0.444424     0.977500  85.000000
# 2   0.960734   0.000000       NaN       NaN     0.960734   0.000000
# 3   0.959832   0.001323  0.125000  0.007812     0.960788   0.333333
# 4   0.959916   0.000000  0.000000       NaN     0.960729   0.000000
# 5   0.966384   0.419671  0.551055  0.438684     0.975490  75.000000
# 6   0.967292   0.394694  0.554894  0.437985     0.975101  74.333333
# 7   0.960734   0.000000       NaN       NaN     0.960734   0.000000
# 8   0.963461   0.470024  0.483248  0.454103     0.978140  88.666667
# 9   0.960153   0.047619  0.264706  0.225000     0.963209  12.000000
# 10  0.966513   0.402801  0.542280  0.434472     0.975002  74.000000
# 11  0.960622   0.009259  0.318182  0.053232     0.961218   2.333333
# 12  0.960734   0.000000       NaN       NaN     0.960734   0.000000
# 13  0.959552   0.014550  0.220000  0.079422     0.961460   3.666667
# 14  0.966710   0.394286  0.542615  0.433476     0.975052  74.333333
#
#             fp         fn           tn
# 0   179.666667  15.333333  4723.666667
# 1   108.666667  71.000000  4668.000000
# 2   193.666667   0.000000  4739.000000
# 3   193.333333   4.666667  4734.333333
# 4   193.666667   4.000000  4735.000000
# 5   118.666667  46.666667  4692.333333
# 6   119.333333  42.333333  4696.666667
# 7   193.666667   0.000000  4739.000000
# 8   105.000000  74.000000  4665.000000
# 9   181.666667  15.000000  4724.000000
# 10  119.666667  46.000000  4693.000000
# 11  191.333333   3.000000  4736.000000
# 12  193.666667   0.000000  4739.000000
# 13  190.000000   9.333333  4729.666667
# 14  119.333333  45.333333  4693.666667

# %%
RF_results_df.sort_values(by=['dataset','model','cv_fold']).head(k*4)
# Out:
#                 model cv_fold                             y dataset       mae  \
# 0    RF|x0|12-27-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.004699
# 42   RF|x0|12-27-sqrt  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001655
# 72   RF|x0|12-27-sqrt  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.007865
# 102  RF|x0|12-27-sqrt  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.004578
# 1    RF|x0|12-37-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002922
# 31   RF|x0|12-37-None  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001399
# 61   RF|x0|12-37-None  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004187
# 91   RF|x0|12-37-None  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.
# 68    16.000000   42.000000  4819.000000
# 98   184.000000   61.000000  5167.000000
# 9    181.666667   15.000000  4724.000000
# 41   216.000000   32.000000  4096.000000
# 71    31.000000   13.000000  4848.000000
# 101  298.000000    0.000000  5228.000000
# 10   119.666667   46.000000  4693.000000
# 30   156.000000   38.000000  4090.000000
# 60    17.000000   40.000000  4821.000000
# 90   186.000000   60.000000  5168.000000
# 11   191.333333    3.000000  4736.000000
# 44   245.000000    4.000000  4124.000000
# 74    31.000000    5.000000  4856.000000
# 104  298.000000    0.000000  5228.000000
# 12   193.666667    0.000000  4739.000000
# 35   252.000000    0.000000  4128.000000
# 65    31.000000    0.000000  4861.000000
# 95   298.000000    0.000000  5228.000000
# 13   190.000000    9.333333  4729.666667
# 34   241.000000   14.000000  4114.000000
# 64    31.000000   14.000000  4847.000000
# 94   298.000000    0.000000  5228.000000
# 14   119.333333   45.333333  4693.666667
# 36   156.000000   38.000000  4090.000000
# 66    18.000000   37.000000  4824.000000
# 96   184.000000   61.000000  5167.000000

# %%
#test with first subset of X columns
start_time = time.time()
RF_results_df = pd.DataFrame()

RF_results_df = RF(model_name='RF|x1', X_vars=X_cols_1, y_var=y_var, cv_folds=cv_folds, RF_results_df=RF_results_df, params=RF_params_df)

mean_df = RF_results_df.groupby(['model','y','dataset'])[RF_results_df.select_dtypes(include=np.number).columns.tolist()].mean().reset_index()
mean_df['cv_fold'] = 'mean'
RF_results_df = pd.concat([RF_results_df, mean_df], ignore_index=True)
RF_results_df = RF_results_df.sort_values(['y','cv_fold','dataset']).drop_duplicates(subset=['cv_fold','y','dataset','model']).reset_index().drop(columns='index')

compare_df = pd.concat([compare_df, 
                        RF_results_df[(RF_results_df['cv_fold'] == 'mean') & 
                                      (RF_results_df['dataset'] == 'test')]],
                       axis=0)

end_time = time.time()
execution_duration = end_time - start_time
print(f"Execution time: {execution_duration:.2f} seconds")

RF_results_df.head(k)
# Out:
# Execution time: 25.01 seconds
#                model cv_fold                             y dataset       mae  \
# 0   RF|x1|12-27-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005147
# 1   RF|x1|12-37-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003015
# 2   RF|x1|12-97-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005238
# 3   RF|x1|17-47-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005317
# 4   RF|x1|28-88-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005298
# 5   RF|x1|29-47-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003057
# 6   RF|x1|30-85-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003056
# 7   RF|x1|35-67-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005194
# 8   RF|x1|48-32-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003045
# 9   RF|x1|55-27-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005117
# 10  RF|x1|68-64-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003065
# 11  RF|x1|69-68-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005133
# 12  RF|x1|71-85-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005218
# 13  RF|x1|77-20-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.004915
# 14  RF|x1|91-76-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003058
#
#     accuracy  precision    recall        F1  specificity         tp  \
# 0   0.960053   0.027948  0.291667  0.070018     0.961678   4.666667
# 1   0.962894   0.421444  0.496381  0.417634     0.976119  77.000000
# 2   0.960734   0.000000       NaN       NaN     0.960734   0.000000
# 3   0.960189   0.000000  0.000000       NaN     0.960731   0.000000
# 4   0.960734   0.000000       NaN       NaN     0.960734   0.000000
# 5   0.962835   0.426293  0.493962  0.415685     0.975835  76.000000
# 6   0.966786   0.391543  0.544725  0.428489     0.974935  73.333333
# 7   0.960734   0.000000       NaN       NaN     0.960734   0.000000
# 8   0.962971   0.449408  0.474769  0.436668     0.977558  85.333333
# 9   0.960357   0.025303  0.347222  0.063997     0.961559   4.000000
# 10  0.966324   0.399446  0.539924  0.430267     0.974824  73.000000
# 11  0.960734   0.000000       NaN       NaN     0.960734   0.000000
# 12  0.960734   0.000000       NaN       NaN     0.960734   0.000000
# 13  0.960069   0.027948  0.306548  0.069324     0.961685   4.666667
# 14  0.966316   0.387574  0.537235  0.423271     0.974699  72.333333
#
#             fp         fn           tn
# 0   189.000000   8.000000  4731.000000
# 1   116.666667  65.333333  4673.666667
# 2   193.666667   0.000000  4739.000000
# 3   193.666667   2.666667  4736.333333
# 4   193.666667   0.000000  4739.000000
# 5   117.666667  64.666667  4674.333333
# 6   120.333333  44.000000  4695.000000
# 7   193.666667   0.000000  4739.000000
# 8   108.333333  73.333333  4665.666667
# 9   189.666667   6.000000  4733.000000
# 10  120.666667  46.000000  4693.000000
# 11  193.666667   0.000000  4739.000000
# 12  193.666667   0.000000  4739.000000
# 13  189.000000   8.000000  4731.000000
# 14  121.333333  45.333333  4693.666667

# %%
RF_results_df.sort_values(by=['dataset','model','cv_fold']).head(k*4)
# Out:
#                 model cv_fold                             y dataset       mae  \
# 0    RF|x1|12-27-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005147
# 42   RF|x1|12-27-sqrt  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001821
# 72   RF|x1|12-27-sqrt  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.009473
# 102  RF|x1|12-27-sqrt  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.004147
# 1    RF|x1|12-37-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003015
# 31   RF|x1|12-37-None  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001439
# 61   RF|x1|12-37-None  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004309
# 91   RF|x1|12-37-None  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003296
# 2    RF|x1|12-97-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005238
# 39   RF|x1|12-97-log2  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002001
# 69   RF|x1|12-97-log2  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.009579
# 99   RF|x1|12-97-log2  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.004134
# 3    RF|x1|17-47-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005317
# 37   RF|x1|17-47-log2  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001844
# 67   RF|x1|17-47-log2  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.009727
# 97   RF|x1|17-47-log2  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.004380
# 4    RF|x1|28-88-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005298
# 43   RF|x1|28-88-sqrt  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001749
# 73   RF|x1|28-88-sqrt  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.009859
# 103  RF|x1|28-88-sqrt  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.004287
# 5    RF|x1|29-47-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003057
# 40   RF|x1|29-47-None  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001427
# 70   RF|x1|29-47-None  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004476
# 100  RF|x1|29-47-None  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003269
# 6    RF|x1|30-85-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003056
# 33   RF|x1|30-85-None  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001419
# 63   RF|x1|30-85-None  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004431
# 93   RF|x1|30-85-None  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003318
# 7    RF|x1|35-67-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005194
# 32   RF|x1|35-67-log2  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001731
# 62   RF|x1|35-67-log2  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.009496
# 92   RF|x1|35-67-log2  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.004356
# 8    RF|x1|48-32-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003045
# 38   RF|x1|48-32-None  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001460
# 68   RF|x1|48-32-None  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004441
# 98   RF|x1|48-32-None  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003235
# 9    RF|x1|55-27-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005117
# 41   RF|x1|55-27-sqrt  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001769
# 71   RF|x1|55-27-sqrt  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.009482
# 101  RF|x1|55-27-sqrt  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.004100
# 10   RF|x1|68-64-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003065
# 30   RF|x1|68-64-None  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001425
# 60   RF|x1|68-64-None  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004478
# 90   RF|x1|68-64-None  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003292
# 11   RF|x1|69-68-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005133
# 44   RF|x1|69-68-sqrt  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001773
# 74   RF|x1|69-68-sqrt  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.009452
# 104  RF|x1|69-68-sqrt  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.004173
# 12   RF|x1|71-85-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005218
# 35   RF|x1|71-85-log2  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001815
# 65   RF|x1|71-85-log2  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.009397
# 95   RF|x1|71-85-log2  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.004443
# 13   RF|x1|77-20-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.004915
# 34   RF|x1|77-20-log2  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001795
# 64   RF|x1|77-20-log2  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.009072
# 94   RF|x1|77-20-log2  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003879
# 14   RF|x1|91-76-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003058
# 36   RF|x1|91-76-None  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001423
# 66   RF|x1|91-76-None  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004450
# 96   RF|x1|91-76-None  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.
# 3    193.666667    2.666667  4736.333333
# 37   252.000000    0.000000  4128.000000
# 67    31.000000    8.000000  4853.000000
# 97   298.000000    0.000000  5228.000000
# 4    193.666667    0.000000  4739.000000
# 43   252.000000    0.000000  4128.000000
# 73    31.000000    0.000000  4861.000000
# 103  298.000000    0.000000  5228.000000
# 5    117.666667   64.666667  4674.333333
# 40   121.000000  112.000000  4016.000000
# 70    16.000000   47.000000  4814.000000
# 100  216.000000   35.000000  5193.000000
# 6    120.333333   44.000000  4695.000000
# 33   153.000000   38.000000  4090.000000
# 63    18.000000   41.000000  4820.000000
# 93   190.000000   53.000000  5175.000000
# 7    193.666667    0.000000  4739.000000
# 32   252.000000    0.000000  4128.000000
# 62    31.000000    0.000000  4861.000000
# 92   298.000000    0.000000  5228.000000
# 8    108.333333   73.333333  4665.666667
# 38   114.000000  119.000000  4009.000000
# 68    17.000000   44.000000  4817.000000
# 98   194.000000   57.000000  5171.000000
# 9    189.666667    6.000000  4733.000000
# 41   241.000000    7.000000  4121.000000
# 71    30.000000   11.000000  4850.000000
# 101  298.000000    0.000000  5228.000000
# 10   120.666667   46.000000  4693.000000
# 30   156.000000   38.000000  4090.000000
# 60    17.000000   41.000000  4820.000000
# 90   189.000000   59.000000  5169.000000
# 11   193.666667    0.000000  4739.000000
# 44   252.000000    0.000000  4128.000000
# 74    31.000000    0.000000  4861.000000
# 104  298.000000    0.000000  5228.000000
# 12   193.666667    0.000000  4739.000000
# 35   252.000000    0.000000  4128.000000
# 65    31.000000    0.000000  4861.000000
# 95   298.000000    0.000000  5228.000000
# 13   189.000000    8.000000  4731.000000
# 34   239.000000   11.000000  4117.000000
# 64    30.000000   13.000000  4848.000000
# 94   298.000000    0.000000  5228.000000
# 14   121.333333   45.333333  4693.666667
# 36   156.000000   38.000000  4090.000000
# 66    18.000000   41.000000  4820.000000
# 96   190.000000   57.000000  5171.000000

# %%
#test with second subset of X columns
start_time = time.time()
RF_results_df = pd.DataFrame()

RF_results_df = RF(model_name='RF|x2', X_vars=X_cols_2, y_var=y_var, cv_folds=cv_folds, RF_results_df=RF_results_df, params=RF_params_df)

mean_df = RF_results_df.groupby(['model','y','dataset'])[RF_results_df.select_dtypes(include=np.number).columns.tolist()].mean().reset_index()
mean_df['cv_fold'] = 'mean'
RF_results_df = pd.concat([RF_results_df, mean_df], ignore_index=True)
RF_results_df = RF_results_df.sort_values(['y','cv_fold','dataset']).drop_duplicates(subset=['cv_fold','y','dataset','model']).reset_index().drop(columns='index')

compare_df = pd.concat([compare_df, 
                        RF_results_df[(RF_results_df['cv_fold'] == 'mean') & 
                                      (RF_results_df['dataset'] == 'test')]],
                       axis=0)

end_time = time.time()
execution_duration = end_time - start_time
print(f"Execution time: {execution_duration:.2f} seconds")

RF_results_df.head(k)
# Out:
# Execution time: 44.03 seconds
#                model cv_fold                             y dataset       mae  \
# 0   RF|x2|12-27-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.004610
# 1   RF|x2|12-37-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002915
# 2   RF|x2|12-97-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005124
# 3   RF|x2|17-47-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005066
# 4   RF|x2|28-88-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.004772
# 5   RF|x2|29-47-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002947
# 6   RF|x2|30-85-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002990
# 7   RF|x2|35-67-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.004882
# 8   RF|x2|48-32-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002908
# 9   RF|x2|55-27-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.004428
# 10  RF|x2|68-64-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002958
# 11  RF|x2|69-68-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.004587
# 12  RF|x2|71-85-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.004956
# 13  RF|x2|77-20-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.004471
# 14  RF|x2|91-76-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002971
#
#     accuracy  precision    recall        F1  specificity         tp  \
# 0   0.960345   0.048942  0.293651  0.234921     0.963303  12.333333
# 1   0.963031   0.438223  0.484683  0.432267     0.976978  82.000000
# 2   0.960734   0.000000       NaN       NaN     0.960734   0.000000
# 3   0.961715   0.046467  0.821429  0.123087     0.962691   9.333333
# 4   0.959576   0.000000  0.000000       NaN     0.960727   0.000000
# 5   0.965358   0.414617  0.532042  0.428189     0.975726  76.000000
# 6   0.966914   0.390220  0.548766  0.430939     0.974860  73.000000
# 7   0.960734   0.000000       NaN       NaN     0.960734   0.000000
# 8   0.963173   0.457034  0.476395  0.442685     0.977954  87.666667
# 9   0.960697   0.079706  0.364072  0.171829     0.963962  15.333333
# 10  0.966678   0.390930  0.543295  0.427591     0.974886  73.333333
# 11  0.959796   0.005291  0.333333  0.031008     0.961006   1.333333
# 12  0.960734   0.000000       NaN       NaN     0.960734   0.000000
# 13  0.959343   0.022487  0.293103  0.120996     0.961897   5.666667
# 14  0.966823   0.389812  0.547351  0.430224     0.974827  73.000000
#
#             fp         fn           tn
# 0   181.333333  14.666667  4724.333333
# 1   111.666667  69.666667  4669.333333
# 2   193.666667   0.000000  4739.000000
# 3   184.333333   5.000000  4734.000000
# 4   193.666667   5.666667  4733.333333
# 5   117.666667  52.333333  4686.666667
# 6   120.666667  43.000000  4696.000000
# 7   193.666667   0.000000  4739.000000
# 8   106.000000  74.333333  4664.666667
# 9   178.333333  16.333333  4722.666667
# 10  120.333333  44.333333  4694.666667
# 11  192.333333   6.000000  4733.000000
# 12  193.666667   0.000000  4739.000000
# 13  188.000000  12.666667  4726.333333
# 14  120.666667  43.333333  4695.666667

# %%
RF_results_df.sort_values(by=['dataset','model','cv_fold']).head(k*4)
# Out:
#                 model cv_fold                             y dataset       mae  \
# 0    RF|x2|12-27-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.004610
# 42   RF|x2|12-27-sqrt  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001642
# 72   RF|x2|12-27-sqrt  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.008132
# 102  RF|x2|12-27-sqrt  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.004054
# 1    RF|x2|12-37-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002915
# 31   RF|x2|12-37-None  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001396
# 61   RF|x2|12-37-None  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004189
# 91   RF|x2|12-37-None  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003159
# 2    RF|x2|12-97-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005124
# 39   RF|x2|12-97-log2  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001868
# 69   RF|x2|12-97-log2  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.009119
# 99   RF|x2|12-97-log2  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.004387
# 3    RF|x2|17-47-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005066
# 37   RF|x2|17-47-log2  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001689
# 67   RF|x2|17-47-log2  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.009271
# 97   RF|x2|17-47-log2  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.004237
# 4    RF|x2|28-88-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.004772
# 43   RF|x2|28-88-sqrt  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001672
# 73   RF|x2|28-88-sqrt  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.008430
# 103  RF|x2|28-88-sqrt  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.004214
# 5    RF|x2|29-47-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002947
# 40   RF|x2|29-47-None  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001383
# 70   RF|x2|29-47-None  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004338
# 100  RF|x2|29-47-None  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003119
# 6    RF|x2|30-85-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002990
# 33   RF|x2|30-85-None  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001389
# 63   RF|x2|30-85-None  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004386
# 93   RF|x2|30-85-None  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003196
# 7    RF|x2|35-67-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.004882
# 32   RF|x2|35-67-log2  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.001674
# 62   RF|x2|35-67-log2  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.008579
# 92   RF|x2|35-67-log2  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.004393
# 8    RF|x2|48-32-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.
# 11   192.333333    6.000000  4733.000000
# 44   248.000000    2.000000  4126.000000
# 74    31.000000   16.000000  4845.000000
# 104  298.000000    0.000000  5228.000000
# 12   193.666667    0.000000  4739.000000
# 35   252.000000    0.000000  4128.000000
# 65    31.000000    0.000000  4861.000000
# 95   298.000000    0.000000  5228.000000
# 13   188.000000   12.666667  4726.333333
# 34   235.000000   12.000000  4116.000000
# 64    31.000000   26.000000  4835.000000
# 94   298.000000    0.000000  5228.000000
# 14   120.666667   43.333333  4695.666667
# 36   156.000000   38.000000  4090.000000
# 66    18.000000   38.000000  4823.000000
# 96   188.000000   54.000000  5174.000000

# %% [markdown]
# Summary of cross validation results for Random Forest Model

# %%
compare_df[['tp','fp','fn','tn']] = compare_df[['tp','fp','fn','tn']].astype(int)
compare_df[compare_df.model.str.contains("RF")].sort_values('recall', ascending=False).drop(columns=['y'])
# Out:
#                model cv_fold dataset       mae  accuracy  precision    recall  \
# 3   RF|x2|17-47-log2    mean    test  0.005066  0.961715   0.046467  0.821429
# 6   RF|x0|30-85-None    mean    test  0.002991  0.967292   0.394694  0.554894
# 5   RF|x0|29-47-None    mean    test  0.002955  0.966384   0.419671  0.551055
# 6   RF|x2|30-85-None    mean    test  0.002990  0.966914   0.390220  0.548766
# 14  RF|x2|91-76-None    mean    test  0.002971  0.966823   0.389812  0.547351
# 6   RF|x1|30-85-None    mean    test  0.003056  0.966786   0.391543  0.544725
# 10  RF|x2|68-64-None    mean    test  0.002958  0.966678   0.390930  0.543295
# 14  RF|x0|91-76-None    mean    test  0.002974  0.966710   0.394286  0.542615
# 10  RF|x0|68-64-None    mean    test  0.002961  0.966513   0.402801  0.542280
# 10  RF|x1|68-64-None    mean    test  0.003065  0.966324   0.399446  0.539924
# 14  RF|x1|91-76-None    mean    test  0.003058  0.966316   0.387574  0.537235
# 5   RF|x2|29-47-None    mean    test  0.002947  0.965358   0.414617  0.532042
# 1   RF|x1|12-37-None    mean    test  0.003015  0.962894   0.421444  0.496381
# 5   RF|x1|29-47-None    mean    test  0.003057  0.962835   0.426293  0.493962
# 1   RF|x0|12-37-None    mean    test  0.002922  0.963340   0.448290  0.487110
# 1   RF|x2|12-37-None    mean    test  0.002915  0.963031   0.438223  0.484683
# 8   RF|x0|48-32-None    mean    test  0.002919  0.963461   0.470024  0.483248
# 8   RF|x2|48-32-None    mean    test  0.002908  0.963173   0.457034  0.476395
# 8   RF|x1|48-32-None    mean    test  0.003045  0.962971   0.449408  0.474769
# 9   RF|x2|55-27-sqrt    mean    test  0.004428  0.960697   0.079706  0.364072
# 9   RF|x1|55-27-sqrt    mean    test  0.005117  0.960357   0.025303  0.347222
# 11  RF|x2|69-68-sqrt    mean    test  0.004587  0.959796   0.005291  0.333333
# 0   RF|x0|12-27-sqrt    mean    test  0.004699  0.960557   0.064985  0.320635
# 11  RF|x0|69-68-sqrt    mean    test  0.004799  0.960622   0.009259  0.318182
# 13  RF|x1|77-20-log2    mean    test  0.004915  0.960069   0.027948  0.306548
# 0   RF|x2|12-27-sqrt    mean    test  0.004610  0.960345   0.048942  0.293651
# 3        NaN     0.960731   0  193   2  4736
# 4        NaN     0.960727   0  193   5  4733
# 4        NaN     0.960729   0  193   4  4735
# 2        NaN     0.960734   0  193   0  4739
# 7        NaN     0.960734   0  193   0  4739
# 12       NaN     0.960734   0  193   0  4739
# 2        NaN     0.960734   0  193   0  4739
# 4        NaN     0.960734   0  193   0  4739
# 7        NaN     0.960734   0  193   0  4739
# 11       NaN     0.960734   0  193   0  4739
# 12       NaN     0.960734   0  193   0  4739
# 2        NaN     0.960734   0  193   0  4739
# 7        NaN     0.960734   0  193   0  4739
# 12       NaN     0.960734   0  193   0  4739

# %% [markdown]
# *****
# **Final comparison**
# *****
# Identify which model optimizes for recall

# %%
compare_df = compare_df.sort_values('recall', ascending=False).reset_index().drop(columns='index').drop_duplicates()
compare_df[['tp','fp','fn','tn']] = compare_df[['tp','fp','fn','tn']].astype(int)
compare_df.head(25)
# Out:
#                   model cv_fold                             y dataset  \
# 0      RF|x2|17-47-log2    mean  frwd01_mon_metro_hvi_pct_chg    test
# 1    HGBR|x1|0.1-102-20    mean  frwd01_mon_metro_hvi_pct_chg    test
# 2   HGBR|x2|0.12-122-18    mean  frwd01_mon_metro_hvi_pct_chg    test
# 3    HGBR|x2|0.1-102-20    mean  frwd01_mon_metro_hvi_pct_chg    test
# 4   HGBR|x1|0.12-122-18    mean  frwd01_mon_metro_hvi_pct_chg    test
# 5    HGBR|x0|0.1-102-20    mean  frwd01_mon_metro_hvi_pct_chg    test
# 6   HGBR|x0|0.14-181-17    mean  frwd01_mon_metro_hvi_pct_chg    test
# 7   HGBR|x1|0.11-159-14    mean  frwd01_mon_metro_hvi_pct_chg    test
# 8   HGBR|x0|0.12-122-18    mean  frwd01_mon_metro_hvi_pct_chg    test
# 9   HGBR|x2|0.07-181-13    mean  frwd01_mon_metro_hvi_pct_chg    test
# 10  HGBR|x0|0.07-181-13    mean  frwd01_mon_metro_hvi_pct_chg    test
# 11  HGBR|x2|0.11-159-14    mean  frwd01_mon_metro_hvi_pct_chg    test
# 12  HGBR|x1|0.14-181-17    mean  frwd01_mon_metro_hvi_pct_chg    test
# 13  HGBR|x2|0.14-181-17    mean  frwd01_mon_metro_hvi_pct_chg    test
# 14  HGBR|x0|0.11-159-14    mean  frwd01_mon_metro_hvi_pct_chg    test
# 15  HGBR|x0|0.08-115-13    mean  frwd01_mon_metro_hvi_pct_chg    test
# 16  HGBR|x1|0.08-115-13    mean  frwd01_mon_metro_hvi_pct_chg    test
# 17  HGBR|x2|0.08-115-13    mean  frwd01_mon_metro_hvi_pct_chg    test
# 18  HGBR|x1|0.07-181-13    mean  frwd01_mon_metro_hvi_pct_chg    test
# 19   HGBR|x0|0.05-165-6    mean  frwd01_mon_metro_hvi_pct_chg    test
# 20  HGBR|x1|0.04-134-11    mean  frwd01_mon_metro_hvi_pct_chg    test
# 21  HGBR|x0|0.04-134-11    mean  frwd01_mon_metro_hvi_pct_chg    test
# 22   HGBR|x2|0.05-165-6    mean  frwd01_mon_metro_hvi_pct_chg    test
# 23  HGBR|x2|0.04-134-11    mean  frwd01_mon_metro_hvi_pct_chg    test
# 24   HGBR|x0|0.04-155-6    mean  frwd01_mon_metro_hvi_pct_chg    test
#
#          mae  accuracy  precision    recall        F1  specificity   tp   fp  \
# 0   0.005066  0.961715   0.046467  0.821429  0.123087     0.962691    9  184
# 1   0.003676  0.928132   0.484059  0.659046  0.538951     0.950359  474  495
# 2   0.003284  0.941337   0.560742  0.656879  0.588930     0.964717  472  352
# 3   0.003236  0.941586   0.562446  0.653103  0.589544     0.965546  467  343
# 4   0.003726  0.929623   0.488598  0.651575  0.538822     0.952645  468  473
# 5   0.003309  0.939411   0.546813  0.649848  0.582180     0.962970  468  368
# 6   0.003239  0.940654   0.558574  0.649626  0.590403     0.963636  474  361
# 7   0.003706  0.928909   0.484103  0.649582  0.535163     0.951836  469  482
# 8   0.003347  0.941151   0.556751  0.649514  0.588403     0.964934  468  349
# 9   0.003254  0.942332   0.565752  0.647021  0.591769     0.965926  470  339
# 10  0.003324  0.944879   0.590451  0.644869  0.606050     0.968714  469  311
# 11  0.003278  0.944103   0.581804  0.643229  0.600574     0.968096  467  317
# 12  0.003527  0.932606   0.500445  0.642789  0.547652     0.956041  466  439
# 13  0.003232  0.942549   0.566840  0.642370  0.592490     0.966511  467  333
# 14  0.003252  0.944848   0.587991  0.639749  0.604945     0.969382  462  304
# 15  0.003264  0.944041   0.578704  0.639617  0.599886     0.968169  466  316
# 16  0.003638  0.927635   0.481653  0.639421  0.534389     0.950744  464  490
# 17  0.003245  0.944942   0.586150  0.637399  0.597818     0.969871  460  300
# 18  0.003596  0.929654   0.489763  0.631816  0.533788     0.953614  458  463
# 19  0.003199  0.945439   0.603217  0.609250  0.602745     0.970748  454  289
# 20  0.003581  0.934377   0.536074  0.608450  0.560621     0.959281  449  403
# 21  0.003224  0.945004   0.605621  0.602765  0.598458     0.970786  449  289
# 22  0.003217  0.946651   0.619766  0.597783  0.605571     0.972674  447  270
# 23  0.003190  0.946122   0.612578  0.595423  0.599173     0.972580  443  271
# 24  0.003201  0.946340   0.621013  0.588611  0.601612     0.973423  437  262
#
#      fn    tn
# 0     5  4734
# 1   275  9482
# 2   277  9626
# 3   283  9634
# 4   281  9504
# 5   281  9609
# 6   275  9616
# 7   280  9496
# 8   282  9628
# 9   279  9638
# 10  280  9667
# 11  282  9660
# 12  283  9538
# 13  283  9644
# 14  287  9673
# 15  284  9661
# 16  285  9487
# 17  290  9677
# 18  291  9514
# 19  296  9688
# 20  300  9574
# 21  301  9689
# 22  302  9708
# 23  306  9706
# 24  313  9715

# %%
compare_df.head(1)
# Out:
#               model cv_fold                             y dataset       mae  \
# 0  RF|x2|17-47-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005066
#
#    accuracy  precision    recall        F1  specificity  tp   fp  fn    tn
# 0  0.961715   0.046467  0.821429  0.123087     0.962691   9  184   5  4734

# %% [markdown]
# Identify which model optimizes for F1 score

# %%
compare_df = compare_df.sort_values('F1', ascending=False)
compare_df.head(25)
# Out:
#                   model cv_fold                             y dataset  \
# 10  HGBR|x0|0.07-181-13    mean  frwd01_mon_metro_hvi_pct_chg    test
# 22   HGBR|x2|0.05-165-6    mean  frwd01_mon_metro_hvi_pct_chg    test
# 14  HGBR|x0|0.11-159-14    mean  frwd01_mon_metro_hvi_pct_chg    test
# 19   HGBR|x0|0.05-165-6    mean  frwd01_mon_metro_hvi_pct_chg    test
# 26   HGBR|x2|0.04-155-6    mean  frwd01_mon_metro_hvi_pct_chg    test
# 24   HGBR|x0|0.04-155-6    mean  frwd01_mon_metro_hvi_pct_chg    test
# 11  HGBR|x2|0.11-159-14    mean  frwd01_mon_metro_hvi_pct_chg    test
# 15  HGBR|x0|0.08-115-13    mean  frwd01_mon_metro_hvi_pct_chg    test
# 23  HGBR|x2|0.04-134-11    mean  frwd01_mon_metro_hvi_pct_chg    test
# 21  HGBR|x0|0.04-134-11    mean  frwd01_mon_metro_hvi_pct_chg    test
# 17  HGBR|x2|0.08-115-13    mean  frwd01_mon_metro_hvi_pct_chg    test
# 13  HGBR|x2|0.14-181-17    mean  frwd01_mon_metro_hvi_pct_chg    test
# 9   HGBR|x2|0.07-181-13    mean  frwd01_mon_metro_hvi_pct_chg    test
# 6   HGBR|x0|0.14-181-17    mean  frwd01_mon_metro_hvi_pct_chg    test
# 3    HGBR|x2|0.1-102-20    mean  frwd01_mon_metro_hvi_pct_chg    test
# 2   HGBR|x2|0.12-122-18    mean  frwd01_mon_metro_hvi_pct_chg    test
# 8   HGBR|x0|0.12-122-18    mean  frwd01_mon_metro_hvi_pct_chg    test
# 5    HGBR|x0|0.1-102-20    mean  frwd01_mon_metro_hvi_pct_chg    test
# 47  HGBR|x0|0.02-100-16    mean  frwd01_mon_metro_hvi_pct_chg    test
# 20  HGBR|x1|0.04-134-11    mean  frwd01_mon_metro_hvi_pct_chg    test
# 25   HGBR|x1|0.05-165-6    mean  frwd01_mon_metro_hvi_pct_chg    test
# 48  HGBR|x2|0.02-100-16    mean  frwd01_mon_metro_hvi_pct_chg    test
# 27   HGBR|x1|0.04-155-6    mean  frwd01_mon_metro_hvi_pct_chg    test
# 39  HGBR|x1|0.02-100-16    mean  frwd01_mon_metro_hvi_pct_chg    test
# 12  HGBR|x1|0.14-181-17    mean  frwd01_mon_metro_hvi_pct_chg    test
#
#          mae  accuracy  precision    recall        F1  specificity   tp   fp  \
# 10  0.003324  0.944879   0.590451  0.644869  0.606050     0.968714  469  311
# 22  0.003217  0.946651   0.619766  0.597783  0.605571     0.972674  447  270
# 14  0.003252  0.944848   0.587991  0.639749  0.604945     0.969382  462  304
# 19  0.003199  0.945439   0.603217  0.609250  0.602745     0.970748  454  289
# 26  0.003210  0.947179   0.628219  0.581083  0.601800     0.974592  434  251
# 24  0.003201  0.946340   0.621013  0.588611  0.601612     0.973423  437  262
# 11  0.003278  0.944103   0.581804  0.643229  0.600574     0.968096  467  317
# 15  0.003264  0.944041   0.578704  0.639617  0.599886     0.968169  466  316
# 23  0.003190  0.946122   0.612578  0.595423  0.599173     0.972580  443  271
# 21  0.003224  0.945004   0.605621  0.602765  0.598458     0.970786  449  289
# 17  0.003245  0.944942   0.586150  0.637399  0.597818     0.969871  460  300
# 13  0.003232  0.942549   0.566840  0.642370  0.592490     0.966511  467  333
# 9   0.003254  0.942332   0.565752  0.647021  0.591769     0.965926  470  339
# 6   0.003239  0.940654   0.558574  0.649626  0.590403     0.963636  474  361
# 3   0.003236  0.941586   0.562446  0.653103  0.589544     0.965546  467  343
# 2   0.003284  0.941337   0.560742  0.656879  0.588930     0.964717  472  352
# 8   0.003347  0.941151   0.556751  0.649514  0.588403     0.964934  468  349
# 5   0.003309  0.939411   0.546813  0.649848  0.582180     0.962970  468  368
# 47  0.003369  0.949167   0.701353  0.473958  0.564416     0.985575  347  142
# 20  0.003581  0.934377   0.536074  0.608450  0.560621     0.959281  449  403
# 25  0.003463  0.938821   0.545443  0.587906  0.559570     0.966258  429  335
# 48  0.003307  0.948359   0.688272  0.472511  0.559010     0.984671  347  151
# 27  0.003469  0.939597   0.555889  0.574349  0.558608     0.967927  420  318
# 39  0.003578  0.945532   0.634524  0.502111  0.558089     0.979414  369  204
# 12  0.003527  0.932606   0.500445  0.642789  0.547652     0.956041  466  439
#
#      fn    tn
# 10  280  9667
# 22  302  9708
# 14  287  9673
# 19  296  9688
# 26  315  9727
# 24  313  9715
# 11  282  9660
# 15  284  9661
# 23  306  9706
# 21  301  9689
# 17  290  9677
# 13  283  9644
# 9   279  9638
# 6   275  9616
# 3   283  9634
# 2   277  9626
# 8   282  9628
# 5   281  9609
# 47  402  9835
# 20  300  9574
# 25  321  9642
# 48  402  9826
# 27  329  9659
# 39  380  9774
# 12  283  9538

# %%
compare_df.head(1)
# Out:
#                   model cv_fold                             y dataset  \
# 10  HGBR|x0|0.07-181-13    mean  frwd01_mon_metro_hvi_pct_chg    test
#
#          mae  accuracy  precision    recall       F1  specificity   tp   fp  \
# 10  0.003324  0.944879   0.590451  0.644869  0.60605     0.968714  469  311
#
#      fn    tn
# 10  280  9667

# %% [markdown]
# Identify which model optimizes for mean absolute error

# %%
compare_df = compare_df.sort_values('mae', ascending=True)
print(compare_df.to_string())
# Out:
#                   model cv_fold                             y dataset       mae  accuracy  precision    recall        F1  specificity   tp   fp   fn    tn
# 45     RF|x2|48-32-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002908  0.963173   0.457034  0.476395  0.442685     0.977954   87  106   74  4664
# 43     RF|x2|12-37-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002915  0.963031   0.438223  0.484683  0.432267     0.976978   82  111   69  4669
# 44     RF|x0|48-32-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002919  0.963461   0.470024  0.483248  0.454103     0.978140   88  105   74  4665
# 42     RF|x0|12-37-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002922  0.963340   0.448290  0.487110  0.444424     0.977500   85  108   71  4668
# 38     RF|x2|29-47-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002947  0.965358   0.414617  0.532042  0.428189     0.975726   76  117   52  4686
# 29     RF|x0|29-47-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002955  0.966384   0.419671  0.551055  0.438684     0.975490   75  118   46  4692
# 33     RF|x2|68-64-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002958  0.966678   0.390930  0.543295  0.427591     0.974886   73  120   44  4694
# 35     RF|x0|68-64-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002961  0.966513   0.402801  0.542280  0.434472     0.975002   74  119   46  4693
# 31     RF|x2|91-76-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002971  0.966823   0.389812  0.547351  0.430224     0.974827   73  120   43  4695
# 34     RF|x0|91-76-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002974  0.966710   0.394286  0.542615  0.433476     0.975052   74  119   45  4693
# 30     RF|x2|30-85-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002990  0.966914   0.390220  0.548766  0.430939     0.974860   73  120   43  4696
# 28     RF|x0|30-85-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002991  0.967292   0.394694  0.554894  0.437985     0.975101   74  119   42  4696
# 40     RF|x1|12-37-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003015  0.962894   0.421444  0.496381  0.417634     0.976119   77  116   65  4673
# 46     RF|x1|48-32-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003045  0.962971   0.449408  0.474769  0.436668     0.977558   85  108   73  4665
# 32     RF|x1|30-85-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003056  0.966786   0.391543  0.544725  0.428489     0.974935   73  120   44  4695
# 41     RF|x1|29-47-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003057  0.962835   0.426293  0.493962  0.415685     0.975835   76  117   64  4674
# 37     RF|x1|91-76-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003058  0.966316   0.387574  0.537235  0.423271     0.974699   72  121   45  4693
# 36     RF|x1|68-64-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003065  0.966324   0.399446  0.539924  0.430267     0.974824   73  120   46  4693
# 23  HGBR|x2|0.04-134-11    mean  frwd01_mon_metro_hvi_pct_chg    test  0.003190  0.946122   0.612578  0.595423  0.599173     0.972580  443  271  306  9706
# 19   HGBR|x0|0.05-165-6    mean  frwd01_mon_metro_hvi_pct_chg    test  0.
log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005317  0.960189   0.000000  0.000000       NaN     0.960731    0  193    2  4736
# 71     RF|x0|12-97-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.005425  0.960734   0.000000       NaN       NaN     0.960734    0  193    0  4739
# 55        baseline_mean    mean  frwd01_mon_metro_hvi_pct_chg    test  0.006199  0.923254   0.063960  0.296980  0.096363     0.933224   45  704  118  9859

# %%
compare_df[compare_df.tp > 5].head(25)
# Out:
#                   model cv_fold                             y dataset  \
# 45     RF|x2|48-32-None    mean  frwd01_mon_metro_hvi_pct_chg    test
# 43     RF|x2|12-37-None    mean  frwd01_mon_metro_hvi_pct_chg    test
# 44     RF|x0|48-32-None    mean  frwd01_mon_metro_hvi_pct_chg    test
# 42     RF|x0|12-37-None    mean  frwd01_mon_metro_hvi_pct_chg    test
# 38     RF|x2|29-47-None    mean  frwd01_mon_metro_hvi_pct_chg    test
# 29     RF|x0|29-47-None    mean  frwd01_mon_metro_hvi_pct_chg    test
# 33     RF|x2|68-64-None    mean  frwd01_mon_metro_hvi_pct_chg    test
# 35     RF|x0|68-64-None    mean  frwd01_mon_metro_hvi_pct_chg    test
# 31     RF|x2|91-76-None    mean  frwd01_mon_metro_hvi_pct_chg    test
# 34     RF|x0|91-76-None    mean  frwd01_mon_metro_hvi_pct_chg    test
# 30     RF|x2|30-85-None    mean  frwd01_mon_metro_hvi_pct_chg    test
# 28     RF|x0|30-85-None    mean  frwd01_mon_metro_hvi_pct_chg    test
# 40     RF|x1|12-37-None    mean  frwd01_mon_metro_hvi_pct_chg    test
# 46     RF|x1|48-32-None    mean  frwd01_mon_metro_hvi_pct_chg    test
# 32     RF|x1|30-85-None    mean  frwd01_mon_metro_hvi_pct_chg    test
# 41     RF|x1|29-47-None    mean  frwd01_mon_metro_hvi_pct_chg    test
# 37     RF|x1|91-76-None    mean  frwd01_mon_metro_hvi_pct_chg    test
# 36     RF|x1|68-64-None    mean  frwd01_mon_metro_hvi_pct_chg    test
# 23  HGBR|x2|0.04-134-11    mean  frwd01_mon_metro_hvi_pct_chg    test
# 19   HGBR|x0|0.05-165-6    mean  frwd01_mon_metro_hvi_pct_chg    test
# 24   HGBR|x0|0.04-155-6    mean  frwd01_mon_metro_hvi_pct_chg    test
# 26   HGBR|x2|0.04-155-6    mean  frwd01_mon_metro_hvi_pct_chg    test
# 22   HGBR|x2|0.05-165-6    mean  frwd01_mon_metro_hvi_pct_chg    test
# 21  HGBR|x0|0.04-134-11    mean  frwd01_mon_metro_hvi_pct_chg    test
# 13  HGBR|x2|0.14-181-17    mean  frwd01_mon_metro_hvi_pct_chg    test
#
#          mae  accuracy  precision    recall        F1  specificity   tp   fp  \
# 45  0.002908  0.963173   0.457034  0.476395  0.442685     0.977954   87  106
# 43  0.002915  0.963031   0.438223  0.484683  0.432267     0.976978   82  111
# 44  0.002919  0.963461   0.470024  0.483248  0.454103     0.978140   88  105
# 42  0.002922  0.963340   0.448290  0.487110  0.444424     0.977500   85  108
# 38  0.002947  0.965358   0.414617  0.532042  0.428189     0.975726   76  117
# 29  0.002955  0.966384   0.419671  0.551055  0.438684     0.975490   75  118
# 33  0.002958  0.966678   0.390930  0.543295  0.427591     0.974886   73  120
# 35  0.002961  0.966513   0.402801  0.542280  0.434472     0.975002   74  119
# 31  0.002971  0.966823   0.389812  0.547351  0.430224     0.974827   73  120
# 34  0.002974  0.966710   0.394286  0.542615  0.433476     0.975052   74  119
# 30  0.002990  0.966914   0.390220  0.548766  0.430939     0.974860   73  120
# 28  0.002991  0.967292   0.394694  0.554894  0.437985     0.975101   74  119
# 40  0.003015  0.962894   0.421444  0.496381  0.417634     0.976119   77  116
# 46  0.003045  0.962971   0.449408  0.474769  0.436668     0.977558   85  108
# 32  0.003056  0.966786   0.391543  0.544725  0.428489     0.974935   73  120
# 41  0.003057  0.962835   0.426293  0.493962  0.415685     0.975835   76  117
# 37  0.003058  0.966316   0.387574  0.537235  0.423271     0.974699   72  121
# 36  0.003065  0.966324   0.399446  0.539924  0.430267     0.974824   73  120
# 23  0.003190  0.946122   0.612578  0.595423  0.599173     0.972580  443  271
# 19  0.003199  0.945439   0.603217  0.609250  0.602745     0.970748  454  289
# 24  0.003201  0.946340   0.621013  0.588611  0.601612     0.973423  437  262
# 26  0.003210  0.947179   0.628219  0.581083  0.601800     0.974592  434  251
# 22  0.003217  0.946651   0.619766  0.597783  0.605571     0.972674  447  270
# 21  0.003224  0.945004   0.605621  0.602765  0.598458     0.970786  449  289
# 13  0.003232  0.942549   0.566840  0.642370  0.592490     0.966511  467  333
#
#      fn    tn
# 45   74  4664
# 43   69  4669
# 44   74  4665
# 42   71  4668
# 38   52  4686
# 29   46  4692
# 33   44  4694
# 35   46  4693
# 31   43  4695
# 34   45  4693
# 30   43  4696
# 28   42  4696
# 40   65  4673
# 46   73  4665
# 32   44  4695
# 41   64  4674
# 37   45  4693
# 36   46  4693
# 23  306  9706
# 19  296  9688
# 24  313  9715
# 26  315  9727
# 22  302  9708
# 21  301  9689
# 13  283  9644

# %%
#model with lowest mae will be used

# %%
compare_df.head(1)
# Out:
#                model cv_fold                             y dataset       mae  \
# 45  RF|x2|48-32-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002908
#
#     accuracy  precision    recall        F1  specificity  tp   fp  fn    tn
# 45  0.963173   0.457034  0.476395  0.442685     0.977954  87  106  74  4664

# %% [markdown]
# *****
# **Train and test selected model with validation set**
# *****
# Selected model details
#
# Estimator: Random Forest
#
# Set of predictor variables: Set 2 (all pct change lag and normalized amounts for current period)
#
# Parameters:
#
#     n_estimators = 48
#
#     min_samples_leaf = 32
#
#     max_features = None

# %%
#test best model with validation dataset
start_time = time.time()
val_results_df = pd.DataFrame()
val_params_df = pd.DataFrame({'n_estimators':[48],
                             'min_samples_leaf':[32],
                             'max_features':[None]})

val_results_df = RF(model_name='RF|x2', X_vars=X_cols_2, y_var=y_var, cv_folds=val, RF_results_df=val_results_df, params=val_params_df)

end_time = time.time()
execution_duration = end_time - start_time
print(f"Execution time: {execution_duration:.2f} seconds")

val_results_df.sort_values('dataset')
# Out:
# Execution time: 5.98 seconds
#               model cv_fold                             y dataset       mae  \
# 1  RF|x2|48-32-None     val  frwd01_mon_metro_hvi_pct_chg    test  0.002576
# 0  RF|x2|48-32-None     val  frwd01_mon_metro_hvi_pct_chg   train  0.001225
#
#    accuracy  precision    recall        F1  specificity    tp   fp   fn     tn
# 1  0.849621   0.660153  0.943076  0.776651     0.813773  1723  887  104   3876
# 0  0.972988   0.518029  0.833656  0.638992     0.977101   431  401   86  17111

# %%
print("training y | mean:",format(sample_dfs[val['train_df'][0]][y_var].mean(),".5%"),
      "  std:",format(sample_dfs[val['train_df'][0]][y_var].std(),".5%"),
      "  mae:",format(val_results_df['mae'][0]/(sample_dfs[val['test_df'][0]][y_var].std()),".0%"),"of std")
print("test y | mean:",format(sample_dfs[val['test_df'][0]][y_var].mean(),".5%"),
      "  std:",format(sample_dfs[val['test_df'][0]][y_var].std(),".5%"),
      "  mae:",format(val_results_df['mae'][1]/(sample_dfs[val['test_df'][0]][y_var].std()),".0%"),"of std")
# Out:
# training y | mean: 0.75662%   std: 0.69519%   mae: 19% of std
# test y | mean: 0.08406%   std: 0.63287%   mae: 41% of std

# %% [markdown]
# **Validation test results**
#  - The model was able to predict the percentage of home value change within 41% of one standard deviation of the actual home value change for the test period.
#  - Out of the 1,827 periods where home value declined, the model correctly predicted a decline 94.3% of the time (recall).
#  - Out of the 2,610 periods where the model predicted a decline, only 66% of the time did a decline actually occur (precision).
#  - Out of the 4,763 periods where home value increased, the model correctly predicted an increase 81.4% of the time (specificity).
