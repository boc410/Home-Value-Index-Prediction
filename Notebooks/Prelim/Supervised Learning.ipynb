# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle
import time

import random
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_absolute_error as mae

# %%
#Load (unpickle) the dictionary of DataFrames from the file
with open('../Data/test_train_datasets.pkl', 'rb') as f:
    sample_dfs = pickle.load(f)  # 'rb' for reading in binary mode

sample_dfs.keys()
# Out:
# dict_keys(['metro_samp_1', 'metro_samp_1_train', 'metro_samp_1_test', 'metro_samp_2', 'metro_samp_2_train', 'metro_samp_2_test', 'metro_samp_3', 'metro_samp_3_train', 'metro_samp_3_test', 'metro_samp_val', 'metro_samp_val_train', 'metro_samp_val_test', 'metro_samp_1_train_normalized', 'metro_samp_1_test_normalized', 'metro_samp_2_train_normalized', 'metro_samp_2_test_normalized', 'metro_samp_3_train_normalized', 'metro_samp_3_test_normalized', 'metro_samp_val_train_normalized', 'metro_samp_val_test_normalized'])

# %%
X_cols = [col for col in sample_dfs['metro_samp_val_train_normalized'].columns if "frwd" not in col]
y_cols = [col for col in sample_dfs['metro_samp_val_train_normalized'].columns if "frwd" in col]

# %%
#set folds for cross validation testing
cv_folds = pd.DataFrame({'fold':['samp_1','samp_2','samp_3'],
                         'train_df':['metro_samp_1_train_normalized','metro_samp_2_train_normalized','metro_samp_3_train_normalized'],
                         'test_df':['metro_samp_1_test_normalized','metro_samp_2_test_normalized','metro_samp_3_test_normalized']})

val = pd.DataFrame({'fold':['val'],
                    'train_df':['metro_samp_val_train_normalized'],
                    'test_df':['metro_samp_val_test_normalized']})

# %%
#create function to produce confusion matrix from test results
def conf_matrix(test_results):
    pos = test_results[test_results.y_test < 0]
    true_pos = pos[pos.y_pred < 0]
    false_neg = pos[pos.y_pred >= 0]

    neg = test_results[test_results.y_test >= 0]
    true_neg = neg[neg.y_pred >= 0]
    false_pos = neg[neg.y_pred < 0]

    confusion_matrix = np.array([[len(true_pos), len(false_pos)],
                                [len(false_neg), len(true_neg)]])

    confusion_matrix_pct = confusion_matrix / len(test_results)
    
    return(confusion_matrix, confusion_matrix_pct)

# %%
#create class to generate key statistics from confusion matrix
class confusion_matrix_class:
    def __init__(self, cm):
        self.cm = cm
        self.tp = cm[0,0]
        self.fp = cm[0,1]
        self.fn = cm[1,0]
        self.tn = cm[1,1]
        self.accuracy = ((self.tp+self.tn)/(self.tp+self.fp+self.fn+self.tn))
        self.precision = (self.tp/(self.tp+self.fp))
        self.recall = (self.tp/(self.tp+self.fn))
        self.F1 = (2*self.precision*self.recall)/(self.precision+self.recall)
        self.specificity = (self.tn/(self.tn+self.fp))

# %%
compare_df = pd.DataFrame()

#create function to produce consistent results for comparison across models
def create_results_record(model, cv_fold, y_var, dataset, cm, error):                
    new_record_dict = {'model': model,
                      'cv_fold': cv_fold,
                      'y': y_var,
                      'dataset': dataset,
                      'mae': error,
                      'accuracy': cm.accuracy,
                      'precision': cm.precision,
                      'recall': cm.recall,
                      'F1': cm.F1,
                      'specificity': cm.specificity,
                      'tp': cm.tp,
                      'fp': cm.fp,
                      'fn': cm.fn,
                      'tn': cm.tn}
    return(new_record_dict)

# %%
HGBR_results = pd.DataFrame()

#create function to test Gradient Boosting model
def HGBR(cv_fold, 
         X_vars=X_cols,
         y_var='frwd01_mon_metro_hvi_pct_chg',
         learning_rate=.1,
         min_samples_leaf=20,
         max_depth=None,
         seed=42, 
         HGBR_results_df=HGBR_results):

    fold = cv_fold['fold']
    train_df = sample_dfs[cv_fold['train_df']]
    test_df = sample_dfs[cv_fold['test_df']]
    
    #define training set
    train_df = train_df.dropna(subset=[y_var])
    X = train_df[X_vars[7:]]
    y = train_df[y_var]

    #train and score model with training data
    hgbr = HistGradientBoostingRegressor(learning_rate=learning_rate,
                                         min_samples_leaf=min_samples_leaf,
                                         max_depth=max_depth,
                                         random_state=seed)
    hgbr.fit(X, y)
    train_score = hgbr.score(X, y)

    #predict and score with test data
    test_df = test_df.dropna(subset=[y_var])
    X_test = test_df[X_vars[7:]]
    y_test = test_df[y_var]
    test_score = hgbr.score(X_test, y_test)
    y_pred = hgbr.predict(X_test)
    error = mae(y_test, y_pred)
    
    #create categorization of prediction
    results_index = test_df[X_vars[:7]].reset_index()
    results = pd.DataFrame(zip(y_test,y_pred), columns=['y_test','y_pred']).reset_index()
    test_results = pd.concat([results_index, results], axis=1)
    test_results['y_diff'] = test_results['y_pred'] - test_results['y_test']
    test_results['direction'] = ((test_results['y_test']*test_results['y_pred'])/
                                  abs(test_results['y_test']*test_results['y_pred']))
    test_results['direction'] = np.where(test_results['direction'] == 1, "same", "diff")
    cm, cm_pct = conf_matrix(test_results)
    hgbr_cm = confusion_matrix_class(cm)

    #add record to test results df
    new_record = create_results_record(model='HGBR', 
                                       cv_fold=fold, 
                                       y_var=y_var, 
                                       dataset='test', 
                                       cm=hgbr_cm,
                                       error=error)
                  
    HGBR_results_df = pd.concat([HGBR_results_df, pd.DataFrame([new_record])], ignore_index=True).drop_duplicates()
    HGBR_results_df[['tp','fp','fn','tn']] = HGBR_results_df[['tp','fp','fn','tn']].astype(int)
    
    return(HGBR_results_df, test_results)

# %%
y_focus = [col for col in y_cols if "mon_metro_hvi_pct_chg" in col]

# %%
for y in y_focus:

    for i in range(len(cv_folds)):

        cv_fold = cv_folds.loc[i]
        HGBR_results, test_results = HGBR(cv_fold,
                                          y_var=y,
                                          HGBR_results_df=HGBR_results)

# %%
mean_df = HGBR_results.groupby(['model','y','dataset'])[HGBR_results.select_dtypes(include=np.number).columns.tolist()].mean().reset_index()
mean_df['cv_fold'] = 'mean'

HGBR_results = pd.concat([HGBR_results, mean_df], ignore_index=True)
HGBR_results = HGBR_results.sort_values(['y','cv_fold']).drop_duplicates(subset=['cv_fold','y','dataset']).reset_index().drop(columns='index')
HGBR_results.sort_values(by=['recall'], ascending=False)
# Out:
#    model cv_fold                             y dataset       mae  accuracy  \
# 3   HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.002582  0.807801
# 1   HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002732  0.766323
# 7   HGBR  samp_3  frwd02_mon_metro_hvi_pct_chg    test  0.005648  0.818029
# 0   HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002453  0.811420
# 2   HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.002045  0.860135
# 4   HGBR    mean  frwd02_mon_metro_hvi_pct_chg    test  0.005144  0.828043
# 6   HGBR  samp_2  frwd02_mon_metro_hvi_pct_chg    test  0.004582  0.866706
# 11  HGBR  samp_3  frwd03_mon_metro_hvi_pct_chg    test  0.008235  0.861217
# 5   HGBR  samp_1  frwd02_mon_metro_hvi_pct_chg    test  0.005202  0.799395
# 15  HGBR  samp_3  frwd04_mon_metro_hvi_pct_chg    test  0.010670  0.870698
# 8   HGBR    mean  frwd03_mon_metro_hvi_pct_chg    test  0.007962  0.838047
# 10  HGBR  samp_2  frwd03_mon_metro_hvi_pct_chg    test  0.007302  0.869243
# 9   HGBR  samp_1  frwd03_mon_metro_hvi_pct_chg    test  0.008350  0.783681
# 12  HGBR    mean  frwd04_mon_metro_hvi_pct_chg    test  0.010667  0.841681
# 14  HGBR  samp_2  frwd04_mon_metro_hvi_pct_chg    test  0.009933  0.865340
# 19  HGBR  samp_3  frwd06_mon_metro_hvi_pct_chg    test  0.014032  0.889586
# 23  HGBR  samp_3  frwd07_mon_metro_hvi_pct_chg    test  0.016043  0.890220
# 13  HGBR  samp_1  frwd04_mon_metro_hvi_pct_chg    test  0.011400  0.789007
# 16  HGBR    mean  frwd06_mon_metro_hvi_pct_chg    test  0.014813  0.852883
# 18  HGBR  samp_2  frwd06_mon_metro_hvi_pct_chg    test  0.014527  0.866445
# 20  HGBR    mean  frwd07_mon_metro_hvi_pct_chg    test  0.016756  0.861414
# 17  HGBR  samp_1  frwd06_mon_metro_hvi_pct_chg    test  0.015881  0.802617
# 21  HGBR  samp_1  frwd07_mon_metro_hvi_pct_chg    test  0.017837  0.812808
# 22  HGBR  samp_2  frwd07_mon_metro_hvi_pct_chg    test  0.016386  0.881213
#
#     precision    recall        F1  specificity           tp           fp  \
# 3    0.436269  0.756462  0.553387     0.817392  3190.000000  4122.000000
# 1    0.522402  0.714474  0.603525     0.783507  2705.000000  2473.000000
# 7    0.425949  0.697935  0.529031     0.838632  2738.000000  3690.000000
# 0    0.505487  0.696449  0.581150     0.835741  2473.333333  2601.333333
# 2    0.557791  0.618410  0.586538     0.906323  1525.000000  1209.000000
# 4    0.534455  0.566441  0.536306     0.889929  1910.333333  1914.333333
# 6    0.558550  0.522382  0.539861     0.927320  1202.000000   950.000000
# 11   0.496746  0.516653  0.506504     0.916309  1908.000000  1933.000000
# 5    0.618867  0.479005  0.540027     0.903836  1791.000000  1103.000000
# 15   0.493141  0.419977  0.453628     0.936746  1438.000000  1478.000000
# 8    0.542482  0.404783  0.456190     0.930729  1303.000000  1149.666667
# 10   0.547130  0.360243  0.434440     0.951697   772.000000   639.000000
# 9    0.583571  0.337452  0.427627     0.924181  1229.000000   877.000000
# 12   0.520109  0.330848  0.396499     0.944105   982.666667   930.000000
# 14   0.483565  0.326914  0.390100     0.947029   662.000000   707.000000
# 19   0.498917  0.311781  0.383750     0.961193   921.000000   925.000000
# 23   0.449425  0.282821  0.347170     0.960125   782.000000   958.000000
# 13   0.583620  0.245655  0.345770     0.948541   848.000000   605.000000
# 16   0.469287  0.242178  0.315642     0.956746   632.666667   698.666667
# 18   0.410329  0.234694  0.298599     0.953516   437.000000   628.000000
# 20   0.462008  0.206192  0.280284     0.963545   518.333333   616.333333
# 17   0.498615  0.180060  0.264576     0.955528   540.000000   543.000000
# 21   0.455056  0.176663  0.254517     0.953283   486.000000   582.000000
# 22   0.481544  0.159091  0.239167     0.977226   287.000000   309.000000
#
#              fn            tn
# 3   1027.000000  18451.000000
# 1   1081.000000   8950.000000
# 7   1185.000000  19177.000000
# 0   1016.333333  13032.666667
# 2    941.000000  11697.000000
# 4   1410.666667  13888.333333
# 6   1099.000000  12121.000000
# 11  1785.000000  21164.000000
# 5   1948.000000  10367.000000
# 15  1986.000000  21888.000000
# 8   1856.333333  14814.666667
# 10  1371.000000  12590.000000
# 9   2413.000000  10690.000000
# 12  1984.333333  15226.666667
# 14  1363.000000  12640.000000
# 19  2033.000000  22911.000000
# 23  1983.000000  23067.000000
# 13  2604.000000  11152.000000
# 16  1972.333333  15820.000000
# 18  1425.000000  12882.000000
# 20  1921.666667  16067.333333
# 17  2459.000000  11667.000000
# 21  2265.000000  11876.000000
# 22  1517.000000  13259.000000

# %% [markdown]
# Will focus on predicting whether price will increase or decrease in the following month

# %% [markdown]
# # Tuning

# %% [markdown]
# Set y variable for focus of analysis

# %%
y_var = 'frwd01_mon_metro_hvi_pct_chg'

# %% [markdown]
# Identify variations of features to use for tuning

# %%
#set X features (all pct change lag from 1 month, selective other pct lag, clusters, and normalized amounts for current period)
X_cols_1 = (X_cols[:7]+
            X_cols[X_cols.index('metro_for_sale_inventory_normalized'):
                   X_cols.index('prev01_mon_metro_for_sale_inventory')]+
            X_cols[X_cols.index('prev01_mon_metro_for_sale_inventory_pct_chg'):
                   X_cols.index('prev01_mon_state_job_openings_szn_adjd_pct_chg')]+
            ['prev04_mon_metro_hvi']+
            ['prev04_mon_metro_rent']+
            ['prev04_mon_state_job_openings_pct_chg']+
            ['prev04_mon_state_population_pct_chg']+
            ['prev04_mon_state_personal_income_pct_chg']+
            ['prev07_mon_metro_hvi']+
            ['prev07_mon_metro_rent']+
            ['prev07_mon_state_job_openings_pct_chg']+
            ['prev07_mon_state_population_pct_chg']+
            ['prev07_mon_state_personal_income_pct_chg']+
            ['prev12_mon_metro_hvi']+
            ['prev12_mon_metro_rent']+
            ['prev12_mon_state_job_openings_pct_chg']+
            ['prev12_mon_state_population_pct_chg']+
            ['prev12_mon_state_personal_income_pct_chg']+
            X_cols[-5:])
X_cols_1.remove('state_job_openings_szn_adjd_normalized')
X_cols_1.remove('state_personal_income_per_capita_normalized')
X_cols_1.remove('prev01_mon_state_personal_income_per_capita_pct_chg')

# %%
#set X features (all pct change lag and normalized amounts for current period)
X_cols_2 = (X_cols[:7]+
            X_cols[X_cols.index('metro_for_sale_inventory_normalized'):
                   X_cols.index('prev01_mon_metro_for_sale_inventory')]+
            X_cols[X_cols.index('prev01_mon_metro_for_sale_inventory_pct_chg'):
                   X_cols.index('prev01_mon_state_job_openings_szn_adjd_pct_chg')]+
            X_cols[X_cols.index('prev04_mon_metro_for_sale_inventory_pct_chg'):
                   X_cols.index('prev04_mon_state_job_openings_szn_adjd_pct_chg')]+
            X_cols[X_cols.index('prev07_mon_metro_for_sale_inventory_pct_chg'):
                   X_cols.index('prev07_mon_state_job_openings_szn_adjd_pct_chg')]+
            X_cols[X_cols.index('prev12_mon_metro_for_sale_inventory_pct_chg'):
                   X_cols.index('prev12_mon_state_job_openings_szn_adjd_pct_chg')])

# %% [markdown]
# *****
# **Baseline model**
# *****
# Create baseline model (prediction constant as average % change for each metro area)

# %%
start_time = time.time()
baseline_results_df = pd.DataFrame()

for i in range(len(cv_folds)):
    #set datasets for cross validation fold
    cv_fold = cv_folds.loc[i]
    fold = cv_fold['fold']
    train_df = sample_dfs[cv_fold['train_df']].dropna(subset=y_var)
    test_df = sample_dfs[cv_fold['test_df']].dropna(subset=y_var)

    #train model
    baseline_y_pred = train_df.groupby('metro_id')[y_var].agg(['mean','median']).reset_index()
    train_df = train_df.merge(baseline_y_pred, on='metro_id')

    #use mean for baseline
    train_df['y_true'] = np.where(train_df[y_var] >= 0, 0, 1)
    train_df['y_pred'] = np.where(train_df['mean'] >= 0, 0, 1)
    baseline_cm = confusion_matrix_class(confusion_matrix(train_df['y_true'], train_df['y_pred']))
    train_error = mae(train_df[y_var],train_df['mean'])

    new_record = create_results_record(model="baseline_mean", 
                                       cv_fold=fold,
                                       y_var=y_var, 
                                       dataset="train", 
                                       cm=baseline_cm,
                                       error=train_error)
    baseline_results_df = pd.concat([baseline_results_df, pd.DataFrame([new_record])], ignore_index=True)

    #test model
    test_df = test_df.merge(baseline_y_pred, on='metro_id')
    test_df['y_true'] = np.where(test_df[y_var] >= 0, 1, 0)
    test_df['y_pred'] = np.where(test_df['mean'] >= 0, 1, 0)
    baseline_cm = confusion_matrix_class(confusion_matrix(test_df['y_true'], test_df['y_pred']))
    test_error = mae(test_df[y_var],test_df['mean'])

    new_record = create_results_record(model="baseline_mean", 
                                       cv_fold=fold,
                                       y_var=y_var, 
                                       dataset="test", 
                                       cm=baseline_cm,
                                       error=test_error)
    baseline_results_df = pd.concat([baseline_results_df, pd.DataFrame([new_record])], ignore_index=True)
    
    
mean_df = baseline_results_df.groupby(['model','y','dataset'])[baseline_results_df.select_dtypes(include=np.number).columns.tolist()].mean().reset_index()
mean_df['cv_fold'] = 'mean'

baseline_results_df = pd.concat([baseline_results_df, mean_df], ignore_index=True)
baseline_results_df = baseline_results_df.sort_values(['dataset','y','cv_fold']).drop_duplicates(subset=['cv_fold','y','dataset']).reset_index().drop(columns='index')

compare_df = pd.concat([compare_df, 
                        baseline_results_df[(baseline_results_df['cv_fold'] == 'mean') & 
                                            (baseline_results_df['dataset'] == 'test')]],
                       axis=0)
compare_df[['tp','fp','fn','tn']] = compare_df[['tp','fp','fn','tn']].astype(int)
compare_df = compare_df.drop_duplicates()

end_time = time.time()
execution_duration = end_time - start_time
print(f"Execution time: {execution_duration:.2f} seconds")

baseline_results_df
# Out:
# Execution time: 1.02 seconds
#            model cv_fold                             y dataset       mae  \
# 0  baseline_mean    mean  frwd01_mon_metro_hvi_pct_chg    test  0.004159
# 1  baseline_mean  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.004305
# 2  baseline_mean  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.004216
# 3  baseline_mean  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.003955
# 4  baseline_mean    mean  frwd01_mon_metro_hvi_pct_chg   train  0.004590
# 5  baseline_mean  samp_1  frwd01_mon_metro_hvi_pct_chg   train  0.004681
# 6  baseline_mean  samp_2  frwd01_mon_metro_hvi_pct_chg   train  0.004590
# 7  baseline_mean  samp_3  frwd01_mon_metro_hvi_pct_chg   train  0.004500
#
#    accuracy  precision    recall        F1  specificity            tp  \
# 0  0.724844   0.218602  0.241648  0.228088     0.821684    758.333333
# 1  0.653758   0.284733  0.296480  0.290488     0.766007   1078.000000
# 2  0.738355   0.210057  0.199846  0.204824     0.847574    518.000000
# 3  0.782419   0.161015  0.228620  0.188952     0.851469    679.000000
# 4  0.660696   0.933031  0.670141  0.780023     0.567910  68030.333333
# 5  0.653099   0.913555  0.661673  0.767476     0.598055  55472.000000
# 6  0.656388   0.929178  0.667380  0.776814     0.561670  67095.000000
# 7  0.672603   0.956361  0.681371  0.795779     0.544006  81524.000000
#
#             fp            fn            tn
# 0  2731.333333   2307.666667  13326.333333
# 1  2708.000000   2558.000000   8865.000000
# 2  1948.000000   2074.000000  10832.000000
# 3  3538.000000   2291.000000  20282.000000
# 4  4694.333333  33309.000000   6267.000000
# 5  5249.000000  28364.000000   7810.000000
# 6  5114.000000  33440.000000   6553.000000
# 7  3720.000000  38123.000000   4438.000000

# %% [markdown]
# *****
# **Historical Gradient Boosting Model (HGBM)**
# *****
# Tune historical gradient boosting model and assess results

# %%
#set parameter ranges for tuning HGBR model
random.seed(42)
learning_rate_rdm = np.array(random.choices(range(0,15),k=10)) / 100 + .01
min_samples_leaf_rdm = np.array(random.choices(range(100,201),k=10))
max_depth_rdm = np.array(random.choices(range(5,21),k=10))

params_df = pd.DataFrame({'learning_rate':learning_rate_rdm,
                          'min_samples_leaf':min_samples_leaf_rdm,
                          'max_depth':max_depth_rdm})

# %%
#test with all X columns
start_time = time.time()
HGBR_cv_results = pd.DataFrame(columns=['idx'])
X_vars = X_cols
m_name = 'HGBR|x0|'

for idx in range(10):
    for i in range(len(cv_folds)):

        cv_fold = cv_folds.loc[i]
        HGBR_cv_results, test_results = HGBR(cv_fold,
                                             X_vars=X_vars,
                                             y_var=y_var,
                                             learning_rate=learning_rate_rdm[idx],
                                             min_samples_leaf=min_samples_leaf_rdm[idx],
                                             max_depth=max_depth_rdm[idx],
                                             HGBR_results_df=HGBR_cv_results)
    
    HGBR_cv_results['idx'] = HGBR_cv_results['idx'].fillna(str(idx).zfill(2))
    mean_df = HGBR_cv_results.groupby(['model','y','dataset','idx'])[HGBR_cv_results.select_dtypes(include=np.number).columns.tolist()].mean().reset_index()
    mean_df['cv_fold'] = 'mean'
    

    HGBR_cv_results = pd.concat([HGBR_cv_results, mean_df], ignore_index=True)
    HGBR_cv_results = HGBR_cv_results.sort_values(['y','cv_fold','dataset']).drop_duplicates(subset=['cv_fold','y','idx','dataset']).reset_index().drop(columns='index')


cv_results = pd.concat([params_df,HGBR_cv_results[HGBR_cv_results.cv_fold == 'mean']], axis=1).drop(columns=['idx'])
cv_results['model'] = m_name+cv_results['learning_rate'].round(2).astype(str)+"-"+cv_results['min_samples_leaf'].astype(str)+"-"+cv_results['max_depth'].astype(str)
cv_results[['tp','fp','fn','tn']] = cv_results[['tp','fp','fn','tn']].astype(int)

compare_df = pd.concat([compare_df, 
                        cv_results.drop(columns=['learning_rate','min_samples_leaf','max_depth'])],
                       axis=0).drop_duplicates()

end_time = time.time()
execution_duration = end_time - start_time
print(f"Execution time: {execution_duration:.2f} seconds")

cv_results.sort_values('recall', ascending=False)
# Out:
# Execution time: 409.10 seconds
#    learning_rate  min_samples_leaf  max_depth                model cv_fold  \
# 7           0.02               159          6   HGBR|x0|0.02-159-6    mean
# 8           0.07               181         18  HGBR|x0|0.07-181-18    mean
# 3           0.04               120          7   HGBR|x0|0.04-120-7    mean
# 2           0.05               102         10  HGBR|x0|0.05-102-10    mean
# 5           0.11               155         10  HGBR|x0|0.11-155-10    mean
# 4           0.12               165         20  HGBR|x0|0.12-165-20    mean
# 0           0.10               122         17   HGBR|x0|0.1-122-17    mean
# 6           0.14               122          6   HGBR|x0|0.14-122-6    mean
# 1           0.01               151         16  HGBR|x0|0.01-151-16    mean
# 9           0.01               100         14  HGBR|x0|0.01-100-14    mean
#
#                               y dataset       mae  accuracy  precision  \
# 7  frwd01_mon_metro_hvi_pct_chg    test  0.002475  0.794638   0.473873
# 8  frwd01_mon_metro_hvi_pct_chg    test  0.002432  0.800359   0.477358
# 3  frwd01_mon_metro_hvi_pct_chg    test  0.002461  0.803003   0.481359
# 2  frwd01_mon_metro_hvi_pct_chg    test  0.002409  0.817962   0.511574
# 5  frwd01_mon_metro_hvi_pct_chg    test  0.002412  0.814739   0.512255
# 4  frwd01_mon_metro_hvi_pct_chg    test  0.002380  0.820190   0.521712
# 0  frwd01_mon_metro_hvi_pct_chg    test  0.002381  0.818700   0.514717
# 6  frwd01_mon_metro_hvi_pct_chg    test  0.002373  0.833986   0.547755
# 1  frwd01_mon_metro_hvi_pct_chg    test  0.002569  0.835024   0.601629
# 9  frwd01_mon_metro_hvi_pct_chg    test  0.002588  0.830657   0.595210
#
#      recall        F1  specificity    tp    fp    fn     tn
# 7  0.734303  0.572662     0.808568  2556  2796   933  12838
# 8  0.733019  0.576322     0.815277  2580  2899   909  12734
# 3  0.721689  0.577099     0.820290  2534  2720   955  12913
# 2  0.715940  0.595756     0.839880  2519  2456   970  13178
# 5  0.710716  0.589789     0.837219  2525  2621   964  13013
# 4  0.698989  0.592076     0.845946  2494  2446   995  13187
# 0  0.693680  0.588103     0.845580  2463  2413  1026  13220
# 6  0.693563  0.610869     0.864878  2456  2050  1033  13584
# 1  0.599109  0.586291     0.885107  2086  1470  1403  14163
# 9  0.589586  0.576825     0.881427  2055  1509  1434  14125

# %%
#test results for each fold
HGBR_cv_results.sort_values(by=['idx','cv_fold'])
# Out:
#    idx model cv_fold                             y dataset       mae  \
# 0   00  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002381
# 10  00  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002517
# 20  00  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.002120
# 30  00  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.002506
# 1   01  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002569
# 11  01  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002576
# 21  01  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.002564
# 31  01  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.002569
# 2   02  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002409
# 12  02  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002533
# 22  02  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.002170
# 32  02  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.002523
# 3   03  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002461
# 13  03  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002609
# 23  03  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.002283
# 33  03  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.
# 8   0.800359   0.477358  0.733019  0.576322     0.815277  2580.000000  2899.0
# 18  0.773161   0.532432  0.728473  0.615213     0.787972  2758.000000  2422.0
# 28  0.825527   0.470395  0.695864  0.561335     0.850302  1716.000000  1932.0
# 38  0.802389   0.429247  0.774721  0.552418     0.807558  3267.000000  4344.0
# 9   0.830657   0.595210  0.589586  0.576825     0.881427  2055.333333  1509.0
# 19  0.773950   0.537307  0.661912  0.593136     0.811083  2506.000000  2158.0
# 29  0.810630   0.432227  0.575426  0.493651     0.855571  1419.000000  1864.0
# 39  0.907391   0.816096  0.531420  0.643688     0.977628  2241.000000   505.0
#
#              fn       tn
# 0   1026.000000  13220.0
# 10  1094.000000   9128.0
# 20   946.000000  11603.0
# 30  1039.000000  18930.0
# 1   1403.000000  14163.0
# 11  1272.000000   9381.0
# 21  1011.000000  11070.0
# 31  1926.000000  22039.0
# 2    970.000000  13178.0
# 12  1069.000000   9023.0
# 22   790.000000  11394.0
# 32  1052.000000  19117.0
# 3    955.000000  12913.0
# 13  1050.000000   8860.0
# 23   754.000000  10894.0
# 33  1062.000000  18987.0
# 4    995.000000  13187.0
# 14  1049.000000   9122.0
# 24   991.000000  11776.0
# 34   945.000000  18664.0
# 5    964.000000  13013.0
# 15  1053.000000   9103.0
# 25   911.000000  11710.0
# 35   929.000000  18226.0
# 6   1033.000000  13584.0
# 16  1157.000000   9300.0
# 26   907.000000  11667.0
# 36  1037.000000  19785.0
# 7    933.000000  12838.0
# 17  1070.000000   9026.0
# 27   619.000000   9921.0
# 37  1111.000000  19567.0
# 8    909.000000  12734.0
# 18  1028.000000   9001.0
# 28   750.000000  10974.0
# 38   950.000000  18229.0
# 9   1434.333333  14125.0
# 19  1280.000000   9265.0
# 29  1047.000000  11042.0
# 39  1976.000000  22068.0

# %%
#test with first subset of X columns
start_time = time.time()
HGBR_cv_results = pd.DataFrame(columns=['idx'])
X_vars = X_cols_1
m_name = 'HGBR|x1|'

for idx in range(10):
    for i in range(len(cv_folds)):

        cv_fold = cv_folds.loc[i]
        HGBR_cv_results, test_results = HGBR(cv_fold,
                                             X_vars=X_vars,
                                             y_var=y_var,
                                             learning_rate=learning_rate_rdm[idx],
                                             min_samples_leaf=min_samples_leaf_rdm[idx],
                                             max_depth=max_depth_rdm[idx],
                                             HGBR_results_df=HGBR_cv_results)
    
    HGBR_cv_results['idx'] = HGBR_cv_results['idx'].fillna(str(idx).zfill(2))
    mean_df = HGBR_cv_results.groupby(['model','y','dataset','idx'])[HGBR_cv_results.select_dtypes(include=np.number).columns.tolist()].mean().reset_index()
    mean_df['cv_fold'] = 'mean'
    

    HGBR_cv_results = pd.concat([HGBR_cv_results, mean_df], ignore_index=True)
    HGBR_cv_results = HGBR_cv_results.sort_values(['y','cv_fold','dataset']).drop_duplicates(subset=['cv_fold','y','idx','dataset']).reset_index().drop(columns='index')


cv_results = pd.concat([params_df,HGBR_cv_results[HGBR_cv_results.cv_fold == 'mean']], axis=1).drop(columns=['idx'])
cv_results['model'] = m_name+cv_results['learning_rate'].round(2).astype(str)+"-"+cv_results['min_samples_leaf'].astype(str)+"-"+cv_results['max_depth'].astype(str)
cv_results[['tp','fp','fn','tn']] = cv_results[['tp','fp','fn','tn']].astype(int)

compare_df = pd.concat([compare_df, 
                        cv_results.drop(columns=['learning_rate','min_samples_leaf','max_depth'])],
                       axis=0).drop_duplicates()

end_time = time.time()
execution_duration = end_time - start_time
print(f"Execution time: {execution_duration:.2f} seconds")

cv_results.sort_values('recall', ascending=False)
# Out:
# Execution time: 131.20 seconds
#    learning_rate  min_samples_leaf  max_depth                model cv_fold  \
# 7           0.02               159          6   HGBR|x1|0.02-159-6    mean
# 2           0.05               102         10  HGBR|x1|0.05-102-10    mean
# 8           0.07               181         18  HGBR|x1|0.07-181-18    mean
# 3           0.04               120          7   HGBR|x1|0.04-120-7    mean
# 4           0.12               165         20  HGBR|x1|0.12-165-20    mean
# 0           0.10               122         17   HGBR|x1|0.1-122-17    mean
# 5           0.11               155         10  HGBR|x1|0.11-155-10    mean
# 6           0.14               122          6   HGBR|x1|0.14-122-6    mean
# 1           0.01               151         16  HGBR|x1|0.01-151-16    mean
# 9           0.01               100         14  HGBR|x1|0.01-100-14    mean
#
#                               y dataset       mae  accuracy  precision  \
# 7  frwd01_mon_metro_hvi_pct_chg    test  0.002519  0.790946   0.462651
# 2  frwd01_mon_metro_hvi_pct_chg    test  0.002425  0.821525   0.520265
# 8  frwd01_mon_metro_hvi_pct_chg    test  0.002492  0.814111   0.502865
# 3  frwd01_mon_metro_hvi_pct_chg    test  0.002459  0.818082   0.513262
# 4  frwd01_mon_metro_hvi_pct_chg    test  0.002403  0.821003   0.516059
# 0  frwd01_mon_metro_hvi_pct_chg    test  0.002426  0.821623   0.521923
# 5  frwd01_mon_metro_hvi_pct_chg    test  0.002415  0.830279   0.540665
# 6  frwd01_mon_metro_hvi_pct_chg    test  0.002360  0.833591   0.558164
# 1  frwd01_mon_metro_hvi_pct_chg    test  0.002602  0.833657   0.595026
# 9  frwd01_mon_metro_hvi_pct_chg    test  0.002621  0.831488   0.593792
#
#      recall        F1  specificity    tp    fp    fn     tn
# 7  0.734987  0.565600     0.804238  2562  2965   927  12669
# 2  0.726953  0.606013     0.841318  2553  2385   936  13248
# 8  0.724706  0.593537     0.833376  2541  2478   948  13156
# 3  0.722239  0.599951     0.838714  2525  2360   964  13273
# 4  0.705228  0.595268     0.846788  2486  2334  1003  13299
# 0  0.703413  0.598962     0.847129  2472  2273  1017  13361
# 5  0.701046  0.609433     0.858561  2467  2150  1022  13484
# 6  0.676151  0.609323     0.866282  2398  1946  1091  13687
# 1  0.610870  0.588151     0.880401  2123  1536  1366  14097
# 9  0.605165  0.583880     0.878639  2105  1549  1384  14085

# %%
#test results for each fold
HGBR_cv_results.sort_values(by=['idx','cv_fold'])
# Out:
#    idx model cv_fold                             y dataset       mae  \
# 0   00  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002426
# 10  00  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002643
# 20  00  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.002220
# 30  00  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.002416
# 1   01  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002602
# 11  01  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002596
# 21  01  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.002592
# 31  01  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.002619
# 2   02  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002425
# 12  02  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002619
# 22  02  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.002204
# 32  02  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.
# 37  0.818477   0.453539  0.747688  0.564598     0.831702  3153.000000  3799.0
# 8   0.814111   0.502865  0.724706  0.593537     0.833376  2541.000000  2478.0
# 18  0.768295   0.525290  0.718700  0.606960     0.784733  2721.000000  2459.0
# 28  0.826893   0.473469  0.705596  0.566683     0.850070  1740.000000  1935.0
# 38  0.847144   0.509836  0.749822  0.606968     0.865326  3162.000000  3040.0
# 9   0.831488   0.593792  0.605165  0.583880     0.878639  2105.666667  1549.0
# 19  0.774541   0.537257  0.679873  0.600210     0.805918  2574.000000  2217.0
# 29  0.813167   0.439439  0.597324  0.506360     0.854409  1473.000000  1879.0
# 39  0.906756   0.804679  0.538297  0.645070     0.975590  2270.000000   551.0
#
#         fn       tn
# 0   1017.0  13361.0
# 10  1154.0   8942.0
# 20   801.0  11422.0
# 30  1097.0  19719.0
# 1   1366.0  14097.0
# 11  1202.0   9321.0
# 21   969.0  10987.0
# 31  1927.0  21984.0
# 2    936.0  13248.0
# 12  1038.0   8892.0
# 22   741.0  11413.0
# 32  1031.0  19440.0
# 3    964.0  13273.0
# 13  1101.0   8909.0
# 23   698.0  11054.0
# 33  1094.0  19858.0
# 4   1003.0  13299.0
# 14  1144.0   9203.0
# 24   828.0  11298.0
# 34  1039.0  19397.0
# 5   1022.0  13484.0
# 15  1148.0   9176.0
# 25   823.0  11658.0
# 35  1096.0  19618.0
# 6   1091.0  13687.0
# 16  1132.0   8923.0
# 26   979.0  11870.0
# 36  1162.0  20270.0
# 7    927.0  12669.0
# 17  1086.0   9024.0
# 27   631.0  10209.0
# 37  1064.0  18774.0
# 8    948.0  13156.0
# 18  1065.0   8964.0
# 28   726.0  10971.0
# 38  1055.0  19533.0
# 9   1384.0  14085.0
# 19  1212.0   9206.0
# 29   993.0  11027.0
# 39  1947.0  22022.0

# %%
#test with second subset of X columns
start_time = time.time()
HGBR_cv_results = pd.DataFrame(columns=['idx'])
X_vars = X_cols_2
m_name = 'HGBR|x2|'

for idx in range(10):
    for i in range(len(cv_folds)):

        cv_fold = cv_folds.loc[i]
        HGBR_cv_results, test_results = HGBR(cv_fold,
                                             X_vars=X_vars,
                                             y_var=y_var,
                                             learning_rate=learning_rate_rdm[idx],
                                             min_samples_leaf=min_samples_leaf_rdm[idx],
                                             max_depth=max_depth_rdm[idx],
                                             HGBR_results_df=HGBR_cv_results)
    
    HGBR_cv_results['idx'] = HGBR_cv_results['idx'].fillna(str(idx).zfill(2))
    mean_df = HGBR_cv_results.groupby(['model','y','dataset','idx'])[HGBR_cv_results.select_dtypes(include=np.number).columns.tolist()].mean().reset_index()
    mean_df['cv_fold'] = 'mean'
    

    HGBR_cv_results = pd.concat([HGBR_cv_results, mean_df], ignore_index=True)
    HGBR_cv_results = HGBR_cv_results.sort_values(['y','cv_fold','dataset']).drop_duplicates(subset=['cv_fold','y','idx','dataset']).reset_index().drop(columns='index')


cv_results = pd.concat([params_df,HGBR_cv_results[HGBR_cv_results.cv_fold == 'mean']], axis=1).drop(columns=['idx'])
cv_results['model'] = m_name+cv_results['learning_rate'].round(2).astype(str)+"-"+cv_results['min_samples_leaf'].astype(str)+"-"+cv_results['max_depth'].astype(str)
cv_results[['tp','fp','fn','tn']] = cv_results[['tp','fp','fn','tn']].astype(int)

compare_df = pd.concat([compare_df, 
                        cv_results.drop(columns=['learning_rate','min_samples_leaf','max_depth'])],
                       axis=0).drop_duplicates()

end_time = time.time()
execution_duration = end_time - start_time
print(f"Execution time: {execution_duration:.2f} seconds")

cv_results.sort_values('recall', ascending=False)
# Out:
# Execution time: 188.52 seconds
#    learning_rate  min_samples_leaf  max_depth                model cv_fold  \
# 7           0.02               159          6   HGBR|x2|0.02-159-6    mean
# 3           0.04               120          7   HGBR|x2|0.04-120-7    mean
# 8           0.07               181         18  HGBR|x2|0.07-181-18    mean
# 2           0.05               102         10  HGBR|x2|0.05-102-10    mean
# 5           0.11               155         10  HGBR|x2|0.11-155-10    mean
# 0           0.10               122         17   HGBR|x2|0.1-122-17    mean
# 6           0.14               122          6   HGBR|x2|0.14-122-6    mean
# 4           0.12               165         20  HGBR|x2|0.12-165-20    mean
# 1           0.01               151         16  HGBR|x2|0.01-151-16    mean
# 9           0.01               100         14  HGBR|x2|0.01-100-14    mean
#
#                               y dataset       mae  accuracy  precision  \
# 7  frwd01_mon_metro_hvi_pct_chg    test  0.002478  0.794020   0.472557
# 3  frwd01_mon_metro_hvi_pct_chg    test  0.002460  0.799319   0.474738
# 8  frwd01_mon_metro_hvi_pct_chg    test  0.002480  0.785902   0.454628
# 2  frwd01_mon_metro_hvi_pct_chg    test  0.002374  0.819253   0.515471
# 5  frwd01_mon_metro_hvi_pct_chg    test  0.002431  0.817366   0.518918
# 0  frwd01_mon_metro_hvi_pct_chg    test  0.002420  0.810436   0.499407
# 6  frwd01_mon_metro_hvi_pct_chg    test  0.002354  0.830881   0.538165
# 4  frwd01_mon_metro_hvi_pct_chg    test  0.002395  0.816215   0.520806
# 1  frwd01_mon_metro_hvi_pct_chg    test  0.002569  0.835732   0.603402
# 9  frwd01_mon_metro_hvi_pct_chg    test  0.002590  0.832526   0.599066
#
#      recall        F1  specificity    tp    fp    fn     tn
# 7  0.734321  0.571796     0.807743  2558  2812   931  12822
# 3  0.732812  0.575205     0.813957  2571  2851   918  12782
# 8  0.730101  0.557348     0.798742  2569  3213   920  12420
# 2  0.715767  0.597638     0.841521  2522  2457   967  13177
# 5  0.701974  0.592046     0.842471  2488  2490  1001  13143
# 0  0.697548  0.577935     0.834576  2479  2643  1010  12990
# 6  0.691659  0.604852     0.861594  2449  2077  1040  13556
# 4  0.688622  0.585437     0.843792  2447  2550  1042  13083
# 1  0.598434  0.586930     0.886122  2084  1457  1405  14176
# 9  0.591531  0.580178     0.883339  2060  1485  1429  14149

# %%
#test results for each fold
HGBR_cv_results.sort_values(by=['idx','cv_fold'])
# Out:
#    idx model cv_fold                             y dataset       mae  \
# 0   00  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002420
# 10  00  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002494
# 20  00  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.002139
# 30  00  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.002626
# 1   01  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002569
# 11  01  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002574
# 21  01  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.002559
# 31  01  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.002573
# 2   02  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002374
# 12  02  HGBR  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002508
# 22  02  HGBR  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.002127
# 32  02  HGBR  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.002488
# 3   03  HGBR    mean  frwd01_mon_metro_hvi_pct_chg    test  0.
# 37  0.845054   0.505361  0.737728  0.599826     0.865104  3111.000000  3045.0
# 8   0.785902   0.454628  0.730101  0.557348     0.798742  2569.000000  3213.0
# 18  0.773358   0.532830  0.726624  0.614817     0.788847  2751.000000  2412.0
# 28  0.809133   0.439908  0.694647  0.538679     0.831009  1713.000000  2181.0
# 38  0.775215   0.391147  0.769030  0.518548     0.776370  3243.000000  5048.0
# 9   0.832526   0.599066  0.591531  0.580178     0.883339  2060.333333  1485.0
# 19  0.774344   0.538048  0.661120  0.593269     0.811871  2503.000000  2149.0
# 29  0.815769   0.443379  0.581103  0.502984     0.860607  1433.000000  1799.0
# 39  0.907465   0.815770  0.532369  0.644282     0.977540  2245.000000   507.0
#
#              fn       tn
# 0   1010.000000  12990.0
# 10  1052.000000   9106.0
# 20   950.000000  11558.0
# 30  1030.000000  18307.0
# 1   1405.000000  14176.0
# 11  1273.000000   9392.0
# 21  1013.000000  11094.0
# 31  1930.000000  22044.0
# 2    967.000000  13177.0
# 12  1065.000000   9054.0
# 22   805.000000  11506.0
# 32  1033.000000  18971.0
# 3    918.000000  12782.0
# 13  1041.000000   8934.0
# 23   715.000000  10751.0
# 33   998.000000  18662.0
# 4   1042.000000  13083.0
# 14  1091.000000   9193.0
# 24   969.000000  11904.0
# 34  1067.000000  18154.0
# 5   1001.000000  13143.0
# 15  1133.000000   9020.0
# 25   899.000000  11771.0
# 35   971.000000  18639.0
# 6   1040.000000  13556.0
# 16  1158.000000   9316.0
# 26   914.000000  11460.0
# 36  1048.000000  19893.0
# 7    931.000000  12822.0
# 17  1062.000000   9021.0
# 27   627.000000   9917.0
# 37  1106.000000  19528.0
# 8    920.000000  12420.0
# 18  1035.000000   9011.0
# 28   753.000000  10725.0
# 38   974.000000  17525.0
# 9   1429.333333  14149.0
# 19  1283.000000   9274.0
# 29  1033.000000  11107.0
# 39  1972.000000  22066.0

# %% [markdown]
# Summary of cross validation results for Historical Gradient Boosting Model

# %%
compare_df[['tp','fp','fn','tn']] = compare_df[['tp','fp','fn','tn']].astype(int)
compare_df[compare_df.model.str.contains("HGBR")].sort_values('recall', ascending=False).drop(columns=['y'])
# Out:
#                  model cv_fold dataset       mae  accuracy  precision  \
# 7   HGBR|x1|0.02-159-6    mean    test  0.002519  0.790946   0.462651
# 7   HGBR|x2|0.02-159-6    mean    test  0.002478  0.794020   0.472557
# 7   HGBR|x0|0.02-159-6    mean    test  0.002475  0.794638   0.473873
# 8  HGBR|x0|0.07-181-18    mean    test  0.002432  0.800359   0.477358
# 3   HGBR|x2|0.04-120-7    mean    test  0.002460  0.799319   0.474738
# 8  HGBR|x2|0.07-181-18    mean    test  0.002480  0.785902   0.454628
# 2  HGBR|x1|0.05-102-10    mean    test  0.002425  0.821525   0.520265
# 8  HGBR|x1|0.07-181-18    mean    test  0.002492  0.814111   0.502865
# 3   HGBR|x1|0.04-120-7    mean    test  0.002459  0.818082   0.513262
# 3   HGBR|x0|0.04-120-7    mean    test  0.002461  0.803003   0.481359
# 2  HGBR|x0|0.05-102-10    mean    test  0.002409  0.817962   0.511574
# 2  HGBR|x2|0.05-102-10    mean    test  0.002374  0.819253   0.515471
# 5  HGBR|x0|0.11-155-10    mean    test  0.002412  0.814739   0.512255
# 4  HGBR|x1|0.12-165-20    mean    test  0.002403  0.821003   0.516059
# 0   HGBR|x1|0.1-122-17    mean    test  0.002426  0.821623   0.521923
# 5  HGBR|x2|0.11-155-10    mean    test  0.002431  0.817366   0.518918
# 5  HGBR|x1|0.11-155-10    mean    test  0.002415  0.830279   0.540665
# 4  HGBR|x0|0.12-165-20    mean    test  0.002380  0.820190   0.521712
# 0   HGBR|x2|0.1-122-17    mean    test  0.002420  0.810436   0.499407
# 0   HGBR|x0|0.1-122-17    mean    test  0.002381  0.818700   0.514717
# 6   HGBR|x0|0.14-122-6    mean    test  0.002373  0.833986   0.547755
# 6   HGBR|x2|0.14-122-6    mean    test  0.002354  0.830881   0.538165
# 4  HGBR|x2|0.12-165-20    mean    test  0.002395  0.816215   0.520806
# 6   HGBR|x1|0.14-122-6    mean    test  0.002360  0.833591   0.558164
# 1  HGBR|x1|0.01-151-16    mean    test  0.002602  0.833657   0.595026
# 9  HGBR|x1|0.01-100-14    mean    test  0.002621  0.831488   0.593792
# 1  HGBR|x0|0.01-151-16    mean    test  0.002569  0.835024   0.601629
# 1  HGBR|x2|0.01-151-16    mean    test  0.002569  0.835732   0.603402
# 9  HGBR|x2|0.01-100-14    mean    test  0.002590  0.832526   0.599066
# 9  HGBR|x0|0.01-100-14    mean    test  0.002588  0.830657   0.595210
#
#      recall        F1  specificity    tp    fp    fn     tn
# 7  0.734987  0.565600     0.804238  2562  2965   927  12669
# 7  0.734321  0.571796     0.807743  2558  2812   931  12822
# 7  0.734303  0.572662     0.808568  2556  2796   933  12838
# 8  0.733019  0.576322     0.815277  2580  2899   909  12734
# 3  0.732812  0.575205     0.813957  2571  2851   918  12782
# 8  0.730101  0.557348     0.798742  2569  3213   920  12420
# 2  0.726953  0.606013     0.841318  2553  2385   936  13248
# 8  0.724706  0.593537     0.833376  2541  2478   948  13156
# 3  0.722239  0.599951     0.838714  2525  2360   964  13273
# 3  0.721689  0.577099     0.820290  2534  2720   955  12913
# 2  0.715940  0.595756     0.839880  2519  2456   970  13178
# 2  0.715767  0.597638     0.841521  2522  2457   967  13177
# 5  0.710716  0.589789     0.837219  2525  2621   964  13013
# 4  0.705228  0.595268     0.846788  2486  2334  1003  13299
# 0  0.703413  0.598962     0.847129  2472  2273  1017  13361
# 5  0.701974  0.592046     0.842471  2488  2490  1001  13143
# 5  0.701046  0.609433     0.858561  2467  2150  1022  13484
# 4  0.698989  0.592076     0.845946  2494  2446   995  13187
# 0  0.697548  0.577935     0.834576  2479  2643  1010  12990
# 0  0.693680  0.588103     0.845580  2463  2413  1026  13220
# 6  0.693563  0.610869     0.864878  2456  2050  1033  13584
# 6  0.691659  0.604852     0.861594  2449  2077  1040  13556
# 4  0.688622  0.585437     0.843792  2447  2550  1042  13083
# 6  0.676151  0.609323     0.866282  2398  1946  1091  13687
# 1  0.610870  0.588151     0.880401  2123  1536  1366  14097
# 9  0.605165  0.583880     0.878639  2105  1549  1384  14085
# 1  0.599109  0.586291     0.885107  2086  1470  1403  14163
# 1  0.598434  0.586930     0.886122  2084  1457  1405  14176
# 9  0.591531  0.580178     0.883339  2060  1485  1429  14149
# 9  0.589586  0.576825     0.881427  2055  1509  1434  14125

# %% [markdown]
# *****
# **Random forest model**
# *****
# Tune random forest regressor model and assess results

# %%
#create function to generate prediction and assess results from fitted model
def model_predict(model, results_df, df, set_name, pred_cols, y_var=y_var, m_name=m_name, fold=fold):
    X = df[pred_cols]
    
    df['y_pred_pct'] = model.predict(X)
    df['y_true'] = np.where(df[y_var] >= 0, 1, 0)
    df['y_pred'] = np.where(df['y_pred_pct'] >= 0, 1, 0)
    cm = confusion_matrix_class(confusion_matrix(df['y_true'], df['y_pred']))
    error = mae(df[y_var], df['y_pred_pct'])

    new_record = create_results_record(model=m_name, 
                                       cv_fold=fold,
                                       y_var=y_var, 
                                       dataset=set_name, 
                                       cm=cm,
                                       error=error)
    results_df = pd.concat([results_df, pd.DataFrame([new_record])], ignore_index=True)
    
    return(results_df)

# %%
#create function to train and test random forest model 
def RF(model_name, X_vars, y_var, cv_folds, RF_results_df, params):
    
    for idx in range(len(params)):
    
        n_est = params['n_estimators'][idx]
        min_samp_lf = params['min_samples_leaf'][idx]
        max_f = params['max_features'][idx]
        m_name = model_name+"|"+str(n_est)+"-"+str(min_samp_lf)+"-"+str(max_f)
        
        for i in range(len(cv_folds)):

            cv_fold = cv_folds.loc[i]
            fold = cv_fold['fold']
            train_df = sample_dfs[cv_fold['train_df']]
            test_df = sample_dfs[cv_fold['test_df']]

            #identify and drop columns with over 75% of data missing in training dataset
            drop_cols = train_df.isna().sum().divide(len(train_df)).sort_values(ascending=False).reset_index().rename(columns={'index':'col',0:'missing'})
            #print(drop_cols.to_string())
            drop_cols['drop'] = np.where(drop_cols['missing'] > .70, "drop", "keep")
            drop_cols = list(drop_cols[drop_cols['drop'] == 'drop'].col)
            train_df = train_df.drop(columns=drop_cols)
            test_df = test_df.drop(columns=drop_cols)
            X_cols_rf = [col for col in X_vars if col not in drop_cols]

            #define training set
            train_df = train_df.dropna()
            X = train_df[X_cols_rf[7:]]
            y = train_df[y_var]

            #define test data
            test_df = test_df.dropna()
            X_test = test_df[X_cols_rf[7:]]
            y_test = test_df[y_var]

            rf_model = RandomForestRegressor(n_estimators=n_est, 
                                             min_samples_leaf=params['min_samples_leaf'][idx],
                                             max_features=params['max_features'][idx],
                                             n_jobs=-1, 
                                             random_state=42)
            rf_model.fit(X, y)
            
            RF_results_df = model_predict(rf_model, RF_results_df, train_df, "train", X_cols_rf[7:], y_var, m_name, fold)
            RF_results_df = model_predict(rf_model, RF_results_df, test_df, "test", X_cols_rf[7:], y_var, m_name, fold)

    return(RF_results_df)

# %%
#set parameter ranges for tuning RF model
random.seed(42)

k=10
n_estimators_rdm = np.array(random.choices(range(10,101),k=k))
min_samples_leaf_rdm = np.array(random.choices(range(20,101),k=k))
max_features_rdm = np.array(random.choices(['sqrt','log2',None],k=k))

RF_params_df = pd.DataFrame({'n_estimators':n_estimators_rdm,
                             'min_samples_leaf':min_samples_leaf_rdm,
                             'max_features':max_features_rdm})

# %%
#test with all X columns
start_time = time.time()
RF_results_df = pd.DataFrame()

RF_results_df = RF(model_name='RF|x0', X_vars=X_cols, y_var=y_var, cv_folds=cv_folds, RF_results_df=RF_results_df, params=RF_params_df)

mean_df = RF_results_df.groupby(['model','y','dataset'])[RF_results_df.select_dtypes(include=np.number).columns.tolist()].mean().reset_index()
mean_df['cv_fold'] = 'mean'
RF_results_df = pd.concat([RF_results_df, mean_df], ignore_index=True)
RF_results_df = RF_results_df.sort_values(['y','cv_fold','dataset']).drop_duplicates(subset=['cv_fold','y','dataset','model']).reset_index().drop(columns='index')

compare_df = pd.concat([compare_df, 
                        RF_results_df[(RF_results_df['cv_fold'] == 'mean') & 
                                      (RF_results_df['dataset'] == 'test')]],
                       axis=0)

end_time = time.time()
execution_duration = end_time - start_time
print(f"Execution time: {execution_duration:.2f} seconds")

RF_results_df.head(k)
# Out:
# Execution time: 401.45 seconds
#               model cv_fold                             y dataset       mae  \
# 0  RF|x0|12-20-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002407
# 1  RF|x0|12-60-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002030
# 2  RF|x0|17-67-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002319
# 3  RF|x0|30-36-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002188
# 4  RF|x0|35-22-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002299
# 5  RF|x0|48-85-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.001962
# 6  RF|x0|68-37-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002086
# 7  RF|x0|71-64-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002370
# 8  RF|x0|77-72-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.001986
# 9  RF|x0|91-37-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002198
#
#    accuracy  precision    recall        F1  specificity           tp  \
# 0  0.864504   0.498854  0.702542  0.579672     0.889198  1672.333333
# 1  0.865088   0.667235  0.668596  0.661811     0.922164  2313.333333
# 2  0.872005   0.517684  0.718851  0.601729     0.894786  1790.000000
# 3  0.878411   0.544560  0.739178  0.627091     0.899915  1884.333333
# 4  0.874514   0.511035  0.733188  0.601541     0.895035  1765.666667
# 5  0.872909   0.676513  0.687774  0.676805     0.924860  2347.333333
# 6  0.857395   0.672716  0.638258  0.650102     0.921777  2337.000000
# 7  0.867645   0.444269  0.748263  0.556616     0.881904  1522.333333
# 8  0.868135   0.670340  0.679747  0.668378     0.923176  2328.666667
# 9  0.880479   0.551304  0.745618  0.633754     0.901621  1909.000000
#
#             fp           fn            tn
# 0  1769.333333   702.000000  14865.000000
# 1  1128.333333  1270.666667  14296.333333
# 2  1651.666667   676.000000  14891.000000
# 3  1557.333333   654.333333  14912.666667
# 4  1676.000000   628.666667  14938.333333
# 5  1094.333333  1168.000000  14399.000000
# 6  1104.666667  1450.000000  14117.000000
# 7  1919.333333   496.000000  15071.000000
# 8  1113.000000  1229.333333  14337.666667
# 9  1532.666667   643.666667  14923.333333

# %%
RF_results_df.sort_values(by=['dataset','model','cv_fold']).head(k*4)
# Out:
#                model cv_fold                             y dataset       mae  \
# 0   RF|x0|12-20-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002407
# 29  RF|x0|12-20-log2  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002621
# 49  RF|x0|12-20-log2  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.002274
# 69  RF|x0|12-20-log2  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.002327
# 1   RF|x0|12-60-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002030
# 21  RF|x0|12-60-None  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002464
# 41  RF|x0|12-60-None  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.
mean_df = RF_results_df.groupby(['model','y','dataset'])[RF_results_df.select_dtypes(include=np.number).columns.tolist()].mean().reset_index()
mean_df['cv_fold'] = 'mean'
RF_results_df = pd.concat([RF_results_df, mean_df], ignore_index=True)
RF_results_df = RF_results_df.sort_values(['y','cv_fold','dataset']).drop_duplicates(subset=['cv_fold','y','dataset','model']).reset_index().drop(columns='index')

compare_df = pd.concat([compare_df, 
                        RF_results_df[(RF_results_df['cv_fold'] == 'mean') & 
                                      (RF_results_df['dataset'] == 'test')]],
                       axis=0)

end_time = time.time()
execution_duration = end_time - start_time
print(f"Execution time: {execution_duration:.2f} seconds")

RF_results_df.head(k)
# Out:
# Execution time: 169.09 seconds
#               model cv_fold                             y dataset       mae  \
# 0  RF|x1|12-20-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002146
# 1  RF|x1|12-60-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002191
# 2  RF|x1|17-67-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002189
# 3  RF|x1|30-36-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002140
# 4  RF|x1|35-22-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002168
# 5  RF|x1|48-85-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002128
# 6  RF|x1|68-37-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002203
# 7  RF|x1|71-64-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002191
# 8  RF|x1|77-72-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002162
# 9  RF|x1|91-37-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002113
#
#    accuracy  precision    recall        F1  specificity           tp  \
# 0  0.877048   0.636085  0.692261  0.661123     0.917367  2212.000000
# 1  0.831251   0.707301  0.546618  0.612448     0.925612  2461.000000
# 2  0.879782   0.578141  0.724549  0.641843     0.907181  2017.333333
# 3  0.883828   0.611310  0.728866  0.662669     0.912998  2137.000000
# 4  0.883160   0.598500  0.731698  0.656669     0.911030  2088.666667
# 5  0.859263   0.694038  0.630542  0.654909     0.925955  2424.333333
# 6  0.836741   0.706550  0.558322  0.622489     0.925153  2443.000000
# 7  0.882644   0.558208  0.753879  0.637809     0.905119  1958.333333
# 8  0.843990   0.694705  0.594419  0.630962     0.924723  2432.333333
# 9  0.885685   0.621749  0.731200  0.669675     0.915481  2177.666667
#
#             fp           fn            tn
# 0  1229.666667  1022.000000  14545.000000
# 1   980.666667  2219.333333  13347.666667
# 2  1424.333333   774.000000  14793.000000
# 3  1304.666667   830.666667  14736.333333
# 4  1353.000000   791.000000  14776.000000
# 5  1017.333333  1580.000000  13987.000000
# 6   998.666667  2017.000000  13550.000000
# 7  1483.333333   655.333333  14911.666667
# 8  1009.333333  1938.000000  13629.000000
# 9  1264.000000   828.666667  14738.333333

# %%
RF_results_df.sort_values(by=['dataset','model','cv_fold']).head(k*4)
# Out:
#                model cv_fold                             y dataset       mae  \
# 0   RF|x1|12-20-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002146
# 29  RF|x1|12-20-log2  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002336
# 49  RF|x1|12-20-log2  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.002048
# 69  RF|x1|12-20-log2  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.002053
# 1   RF|x1|12-60-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002191
# 21  RF|x1|12-60-None  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002520
# 41  RF|x1|12-60-None  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.001906
# 61  RF|x1|12-60-None  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.002147
# 2   RF|x1|17-67-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002189
# 27  RF|x1|17-67-sqrt  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002304
# 47  RF|x1|17-67-sqrt  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.002055
# 67  RF|x1|17-67-sqrt  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.002209
# 3   RF|x1|30-36-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002140
# 23  RF|x1|30-36-sqrt  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002253
# 43  RF|x1|30-36-sqrt  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.002009
# 63  RF|x1|30-36-sqrt  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.002157
# 4   RF|x1|35-22-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002168
# 22  RF|x1|35-22-log2  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.
# 65  0.906858   0.558515  0.775441  0.649340     0.923302  2286.000000
# 8   0.843990   0.694705  0.594419  0.630962     0.924723  2432.333333
# 24  0.782004   0.713302  0.547488  0.619491     0.894470  2692.000000
# 44  0.902072   0.615134  0.730788  0.667992     0.928760  1512.000000
# 64  0.847895   0.755680  0.504980  0.605402     0.950940  3093.000000
# 9   0.885685   0.621749  0.731200  0.669675     0.915481  2177.666667
# 26  0.850165   0.656598  0.717221  0.685572     0.889373  2478.000000
# 46  0.900182   0.545566  0.763667  0.636450     0.917819  1341.000000
# 66  0.906707   0.663083  0.712710  0.687002     0.939251  2714.000000
#
#              fp           fn            tn
# 0   1229.666667  1022.000000  14545.000000
# 29  1211.000000  1335.000000  10061.000000
# 49  1018.000000   522.000000  12368.000000
# 69  1460.000000  1209.000000  21206.000000
# 1    980.666667  2219.333333  13347.666667
# 21  1096.000000  2240.000000   9156.000000
# 41   841.000000   983.000000  11907.000000
# 61  1005.000000  3435.000000  18980.000000
# 2   1424.333333   774.000000  14793.000000
# 27  1413.000000   954.000000  10442.000000
# 47  1184.000000   461.000000  12429.000000
# 67  1676.000000   907.000000  21508.000000
# 3   1304.666667   830.666667  14736.333333
# 23  1377.000000   934.000000  10462.000000
# 43  1116.000000   404.000000  12486.000000
# 63  1421.000000  1154.000000  21261.000000
# 4   1353.000000   791.000000  14776.000000
# 22  1365.000000   958.000000  10438.000000
# 42  1136.000000   409.000000  12481.000000
# 62  1558.000000  1006.000000  21409.000000
# 5   1017.333333  1580.000000  13987.000000
# 28  1076.000000  2041.000000   9355.000000
# 48   923.000000   549.000000  12341.000000
# 68  1053.000000  2150.000000  20265.000000
# 6    998.666667  2017.000000  13550.000000
# 20  1125.000000  2359.000000   9037.000000
# 40   770.000000  1062.000000  11828.000000
# 60  1101.000000  2630.000000  19785.000000
# 7   1483.333333   655.333333  14911.666667
# 25  1349.000000   953.000000  10443.000000
# 45  1294.000000   351.000000  12539.000000
# 65  1807.000000   662.000000  21753.000000
# 8   1009.333333  1938.000000  13629.000000
# 24  1082.000000  2225.000000   9171.000000
# 44   946.000000   557.000000  12333.000000
# 64  1000.000000  3032.000000  19383.000000
# 9   1264.000000   828.666667  14738.333333
# 26  1296.000000   977.000000  10419.000000
# 46  1117.000000   415.000000  12475.000000
# 66  1379.000000  1094.000000  21321.000000

# %%
#test with second subset of X columns
start_time = time.time()
RF_results_df = pd.DataFrame()

RF_results_df = RF(model_name='RF|x2', X_vars=X_cols_2, y_var=y_var, cv_folds=cv_folds, RF_results_df=RF_results_df, params=RF_params_df)

mean_df = RF_results_df.groupby(['model','y','dataset'])[RF_results_df.select_dtypes(include=np.number).columns.tolist()].mean().reset_index()
mean_df['cv_fold'] = 'mean'
RF_results_df = pd.concat([RF_results_df, mean_df], ignore_index=True)
RF_results_df = RF_results_df.sort_values(['y','cv_fold','dataset']).drop_duplicates(subset=['cv_fold','y','dataset','model']).reset_index().drop(columns='index')

compare_df = pd.concat([compare_df, 
                        RF_results_df[(RF_results_df['cv_fold'] == 'mean') & 
                                      (RF_results_df['dataset'] == 'test')]],
                       axis=0)

end_time = time.time()
execution_duration = end_time - start_time
print(f"Execution time: {execution_duration:.2f} seconds")

RF_results_df.head(k)
# Out:
# Execution time: 188.84 seconds
#               model cv_fold                             y dataset       mae  \
# 0  RF|x2|12-20-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002191
# 1  RF|x2|12-60-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002029
# 2  RF|x2|17-67-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002113
# 3  RF|x2|30-36-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002090
# 4  RF|x2|35-22-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002127
# 5  RF|x2|48-85-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.001969
# 6  RF|x2|68-37-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002087
# 7  RF|x2|71-64-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002153
# 8  RF|x2|77-72-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.001993
# 9  RF|x2|91-37-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002094
#
#    accuracy  precision    recall        F1  specificity           tp  \
# 0  0.872054   0.605586  0.689470  0.641932     0.911695  2105.333333
# 1  0.864882   0.669876  0.666969  0.662276     0.922771  2322.333333
# 2  0.880863   0.599633  0.723224  0.653692     0.911684  2073.666667
# 3  0.881252   0.614300  0.720897  0.660236     0.913657  2154.000000
# 4  0.879135   0.606569  0.712830  0.652316     0.912462  2128.666667
# 5  0.873211   0.677756  0.688601  0.677647     0.925274  2352.000000
# 6  0.858681   0.673396  0.641890  0.652183     0.922148  2340.666667
# 7  0.880939   0.576952  0.733981  0.644014     0.907672  2008.333333
# 8  0.869143   0.669968  0.680951  0.669009     0.923344  2328.333333
# 9  0.883223   0.611686  0.728453  0.662817     0.913618  2137.333333
#
#             fp           fn            tn
# 0  1336.333333   976.333333  14590.666667
# 1  1119.333333  1282.666667  14284.333333
# 2  1368.000000   807.666667  14759.333333
# 3  1287.666667   871.333333  14695.666667
# 4  1313.000000   887.333333  14679.666667
# 5  1089.666667  1169.333333  14397.666667
# 6  1101.000000  1432.666667  14134.333333
# 7  1433.333333   737.666667  14829.333333
# 8  1113.333333  1216.000000  14351.000000
# 9  1304.333333   820.333333  14746.666667

# %%
RF_results_df.sort_values(by=['dataset','model','cv_fold']).head(k*4)
# Out:
#                model cv_fold                             y dataset       mae  \
# 0   RF|x2|12-20-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002191
# 29  RF|x2|12-20-log2  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002426
# 49  RF|x2|12-20-log2  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.002052
# 69  RF|x2|12-20-log2  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.002096
# 1   RF|x2|12-60-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002029
# 21  RF|x2|12-60-None  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002458
# 41  RF|x2|12-60-None  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.001803
# 61  RF|x2|12-60-None  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.001826
# 2   RF|x2|17-67-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002113
# 27  RF|x2|17-67-sqrt  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002277
# 47  RF|x2|17-67-sqrt  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.001999
# 67  RF|x2|17-67-sqrt  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.002064
# 3   RF|x2|30-36-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002090
# 23  RF|x2|30-36-sqrt  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002278
# 43  RF|x2|30-36-sqrt  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.002000
# 63  RF|x2|30-36-sqrt  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.001992
# 4   RF|x2|35-22-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002127
# 22  RF|x2|35-22-log2  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002276
# 42  RF|x2|35-22-log2  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.002038
# 62  RF|x2|35-22-log2  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.002067
# 5   RF|x2|48-85-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.001969
# 28  RF|x2|48-85-None  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002402
# 48  RF|x2|48-85-None  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.001765
# 68  RF|x2|48-85-None  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0.001741
# 6   RF|x2|68-37-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002087
# 20  RF|x2|68-37-None  samp_1  frwd01_mon_metro_hvi_pct_chg    test  0.002532
# 40  RF|x2|68-37-None  samp_2  frwd01_mon_metro_hvi_pct_chg    test  0.001829
# 60  RF|x2|68-37-None  samp_3  frwd01_mon_metro_hvi_pct_chg    test  0
# 44  0.905199   0.616355  0.747410  0.675585     0.929210  1515.000000
# 64  0.910404   0.660640  0.732791  0.694848     0.939127  2704.000000
# 9   0.883223   0.611686  0.728453  0.662817     0.913618  2137.333333
# 26  0.842650   0.658983  0.693337  0.675723     0.888889  2487.000000
# 46  0.898879   0.543531  0.756512  0.632576     0.917391  1336.000000
# 66  0.908141   0.632543  0.735511  0.680152     0.934575  2589.000000
#
#              fp           fn            tn
# 0   1336.333333   976.333333  14590.666667
# 29  1242.000000  1465.000000   9931.000000
# 49  1096.000000   573.000000  12317.000000
# 69  1671.000000   891.000000  21524.000000
# 1   1119.333333  1282.666667  14284.333333
# 21  1013.000000  2259.000000   9137.000000
# 41   917.000000   587.000000  12303.000000
# 61  1428.000000  1002.000000  21413.000000
# 2   1368.000000   807.666667  14759.333333
# 27  1274.000000  1141.000000  10255.000000
# 47  1059.000000   512.000000  12378.000000
# 67  1771.000000   770.000000  21645.000000
# 3   1287.666667   871.333333  14695.666667
# 23  1302.000000  1155.000000  10241.000000
# 43  1147.000000   407.000000  12483.000000
# 63  1414.000000  1052.000000  21363.000000
# 4   1313.000000   887.333333  14679.666667
# 22  1282.000000  1175.000000  10221.000000
# 42  1178.000000   437.000000  12453.000000
# 62  1479.000000  1050.000000  21365.000000
# 5   1089.666667  1169.333333  14397.666667
# 28   992.000000  2034.000000   9362.000000
# 48   908.000000   528.000000  12362.000000
# 68  1369.000000   946.000000  21469.000000
# 6   1101.000000  1432.666667  14134.333333
# 20  1058.000000  2320.000000   9076.000000
# 40   929.000000   601.000000  12289.000000
# 60  1316.000000  1377.000000  21038.000000
# 7   1433.333333   737.666667  14829.333333
# 25  1345.000000  1029.000000  10367.000000
# 45  1174.000000   450.000000  12440.000000
# 65  1781.000000   734.000000  21681.000000
# 8   1113.333333  1216.000000  14351.000000
# 24  1008.000000  2150.000000   9246.000000
# 44   943.000000   512.000000  12378.000000
# 64  1389.000000   986.000000  21429.000000
# 9   1304.333333   820.333333  14746.666667
# 26  1287.000000  1100.000000  10296.000000
# 46  1122.000000   430.000000  12460.000000
# 66  1504.000000   931.000000  21484.000000

# %% [markdown]
# Summary of cross validation results for Random Forest Model

# %%
compare_df[['tp','fp','fn','tn']] = compare_df[['tp','fp','fn','tn']].astype(int)
compare_df[compare_df.model.str.contains("RF")].sort_values('recall', ascending=False).drop(columns=['y'])
# Out:
#               model cv_fold dataset       mae  accuracy  precision    recall  \
# 7  RF|x1|71-64-log2    mean    test  0.002191  0.882644   0.558208  0.753879
# 7  RF|x0|71-64-log2    mean    test  0.002370  0.867645   0.444269  0.748263
# 9  RF|x0|91-37-sqrt    mean    test  0.002198  0.880479   0.551304  0.745618
# 3  RF|x0|30-36-sqrt    mean    test  0.002188  0.878411   0.544560  0.739178
# 7  RF|x2|71-64-log2    mean    test  0.002153  0.880939   0.576952  0.733981
# 4  RF|x0|35-22-log2    mean    test  0.002299  0.874514   0.511035  0.733188
# 4  RF|x1|35-22-log2    mean    test  0.002168  0.883160   0.598500  0.731698
# 1  0.662276     0.922771  2322  1119  1282  14284
# 6  0.652183     0.922148  2340  1101  1432  14134
# 6  0.650102     0.921777  2337  1104  1450  14117
# 5  0.654909     0.925955  2424  1017  1580  13987
# 8  0.630962     0.924723  2432  1009  1938  13629
# 6  0.622489     0.925153  2443   998  2017  13550
# 1  0.612448     0.925612  2461   980  2219  13347

# %% [markdown]
# *****
# **Final comparison**
# *****
# Identify which model optimizes for recall

# %%
compare_df = compare_df.sort_values('recall', ascending=False).reset_index().drop(columns='index')
compare_df[['tp','fp','fn','tn']] = compare_df[['tp','fp','fn','tn']].astype(int)
compare_df.head(25)
# Out:
#                   model cv_fold                             y dataset  \
# 0      RF|x1|71-64-log2    mean  frwd01_mon_metro_hvi_pct_chg    test
# 1      RF|x0|71-64-log2    mean  frwd01_mon_metro_hvi_pct_chg    test
# 2      RF|x0|91-37-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test
# 3      RF|x0|30-36-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test
# 4    HGBR|x1|0.02-159-6    mean  frwd01_mon_metro_hvi_pct_chg    test
# 5    HGBR|x2|0.02-159-6    mean  frwd01_mon_metro_hvi_pct_chg    test
# 6    HGBR|x0|0.02-159-6    mean  frwd01_mon_metro_hvi_pct_chg    test
# 7      RF|x2|71-64-log2    mean  frwd01_mon_metro_hvi_pct_chg    test
# 8      RF|x0|35-22-log2    mean  frwd01_mon_metro_hvi_pct_chg    test
# 9   HGBR|x0|0.07-181-18    mean  frwd01_mon_metro_hvi_pct_chg    test
# 10   HGBR|x2|0.04-120-7    mean  frwd01_mon_metro_hvi_pct_chg    test
# 11     RF|x1|35-22-log2    mean  frwd01_mon_metro_hvi_pct_chg    test
# 12     RF|x1|91-37-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test
# 13  HGBR|x2|0.07-181-18    mean  frwd01_mon_metro_hvi_pct_chg    test
# 14     RF|x1|30-36-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test
# 15     RF|x2|91-37-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test
# 16  HGBR|x1|0.05-102-10    mean  frwd01_mon_metro_hvi_pct_chg    test
# 17  HGBR|x1|0.07-181-18    mean  frwd01_mon_metro_hvi_pct_chg    test
# 18     RF|x1|17-67-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test
# 19     RF|x2|17-67-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test
# 20   HGBR|x1|0.04-120-7    mean  frwd01_mon_metro_hvi_pct_chg    test
# 21   HGBR|x0|0.04-120-7    mean  frwd01_mon_metro_hvi_pct_chg    test
# 22     RF|x2|30-36-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test
# 23     RF|x0|17-67-sqrt    mean  frwd01_mon_metro_hvi_pct_chg    test
# 24  HGBR|x0|0.05-102-10    mean  frwd01_mon_metro_hvi_pct_chg    test
#
#          mae  accuracy  precision    recall        F1  specificity    tp  \
# 0   0.002191  0.882644   0.558208  0.753879  0.637809     0.905119  1958
# 1   0.002370  0.867645   0.444269  0.748263  0.556616     0.881904  1522
# 2   0.002198  0.880479   0.551304  0.745618  0.633754     0.901621  1909
# 3   0.002188  0.878411   0.544560  0.739178  0.627091     0.899915  1884
# 4   0.002519  0.790946   0.462651  0.734987  0.565600     0.804238  2562
# 5   0.002478  0.794020   0.472557  0.734321  0.571796     0.807743  2558
# 6   0.002475  0.794638   0.473873  0.734303  0.572662     0.808568  2556
# 7   0.002153  0.880939   0.576952  0.733981  0.644014     0.907672  2008
# 8   0.002299  0.874514   0.511035  0.733188  0.601541     0.895035  1765
# 9   0.002432  0.800359   0.477358  0.733019  0.576322     0.815277  2580
# 10  0.002460  0.799319   0.474738  0.732812  0.575205     0.813957  2571
# 11  0.002168  0.883160   0.598500  0.731698  0.656669     0.911030  2088
# 12  0.002113  0.885685   0.621749  0.731200  0.669675     0.915481  2177
# 13  0.002480  0.785902   0.454628  0.730101  0.557348     0.798742  2569
# 14  0.002140  0.883828   0.611310  0.728866  0.662669     0.912998  2137
# 15  0.002094  0.883223   0.611686  0.728453  0.662817     0.913618  2137
# 16  0.002425  0.821525   0.520265  0.726953  0.606013     0.841318  2553
# 17  0.002492  0.814111   0.502865  0.724706  0.593537     0.833376  2541
# 18  0.002189  0.879782   0.578141  0.724549  0.641843     0.907181  2017
# 19  0.002113  0.880863   0.599633  0.723224  0.653692     0.911684  2073
# 20  0.002459  0.818082   0.513262  0.722239  0.599951     0.838714  2525
# 21  0.002461  0.803003   0.481359  0.721689  0.577099     0.820290  2534
# 22  0.002090  0.881252   0.614300  0.720897  0.660236     0.913657  2154
# 23  0.002319  0.872005   0.517684  0.718851  0.601729     0.894786  1790
# 24  0.002409  0.817962   0.511574  0.715940  0.595756     0.839880  2519
#
#       fp   fn     tn
# 0   1483  655  14911
# 1   1919  496  15071
# 2   1532  643  14923
# 3   1557  654  14912
# 4   2965  927  12669
# 5   2812  931  12822
# 6   2796  933  12838
# 7   1433  737  14829
# 8   1676  628  14938
# 9   2899  909  12734
# 10  2851  918  12782
# 11  1353  791  14776
# 12  1264  828  14738
# 13  3213  920  12420
# 14  1304  830  14736
# 15  1304  820  14746
# 16  2385  936  13248
# 17  2478  948  13156
# 18  1424  774  14793
# 19  1368  807  14759
# 20  2360  964  13273
# 21  2720  955  12913
# 22  1287  871  14695
# 23  1651  676  14891
# 24  2456  970  13178

# %%
compare_df.head(1)
# Out:
#               model cv_fold                             y dataset       mae  \
# 0  RF|x1|71-64-log2    mean  frwd01_mon_metro_hvi_pct_chg    test  0.002191
#
#    accuracy  precision    recall        F1  specificity    tp    fp   fn  \
# 0  0.882644   0.558208  0.753879  0.637809     0.905119  1958  1483  655
#
#       tn
# 0  14911

# %% [markdown]
# Identify which model optimizes for mean absolute error

# %%
compare_df.sort_values('mae', ascending=False).head(5)
# Out:
#                   model cv_fold                             y dataset  \
# 60        baseline_mean    mean  frwd01_mon_metro_hvi_pct_chg    test
# 52  HGBR|x1|0.01-100-14    mean  frwd01_mon_metro_hvi_pct_chg    test
# 51  HGBR|x1|0.01-151-16    mean  frwd01_mon_metro_hvi_pct_chg    test
# 56  HGBR|x2|0.01-100-14    mean  frwd01_mon_metro_hvi_pct_chg    test
# 57  HGBR|x0|0.01-100-14    mean  frwd01_mon_metro_hvi_pct_chg    test
#
#          mae  accuracy  precision    recall        F1  specificity    tp  \
# 60  0.004159  0.724844   0.218602  0.241648  0.228088     0.821684   758
# 52  0.002621  0.831488   0.593792  0.605165  0.583880     0.878639  2105
# 51  0.002602  0.833657   0.595026  0.610870  0.588151     0.880401  2123
# 56  0.002590  0.832526   0.599066  0.591531  0.580178     0.883339  2060
# 3   0.878411   0.544560  0.739178  0.627091     0.899915  1884  1557   654
# 58  0.836741   0.706550  0.558322  0.622489     0.925153  2443   998  2017
#
#        tn
# 41  14397
# 42  14399
# 12  14738
# 43  14351
# 44  14337
# 15  14746
# 14  14736
# 47  14284
# 46  14296
# 37  14545
# 22  14695
# 11  14776
# 50  13987
# 19  14759
# 26  14679
# 48  14134
# 49  14117
# 7   14829
# 39  14590
# 18  14793
# 0   14911
# 2   14923
# 55  13629
# 3   14912
# 58  13550

# %%
#model with best F1 score will be used

# %%
compare_df.head(1)
# Out:
#                model cv_fold                             y dataset       mae  \
# 41  RF|x2|48-85-None    mean  frwd01_mon_metro_hvi_pct_chg    test  0.001969
#
#     accuracy  precision    recall        F1  specificity    tp    fp    fn  \
# 41  0.873211   0.677756  0.688601  0.677647     0.925274  2352  1089  1169
#
#        tn
# 41  14397

# %% [markdown]
# *****
# **Train and test selected model with validation set**
# *****
# Selected model details
#
# Estimator: Random Forest
#
# Set of predictor variables: Set 2 (all pct change lag and normalized amounts for current period)
#
# Parameters:
#
#     n_estimators = 48
#
#     min_samples_leaf = 85
#
#     max_features = None

# %%
#test best model with validation dataset
start_time = time.time()
val_results_df = pd.DataFrame()
val_params_df = pd.DataFrame({'n_estimators':[48],
                             'min_samples_leaf':[85],
                             'max_features':[None]})

val_results_df = RF(model_name='RF|x2', X_vars=X_cols_2, y_var=y_var, cv_folds=val, RF_results_df=val_results_df, params=val_params_df)

end_time = time.time()
execution_duration = end_time - start_time
print(f"Execution time: {execution_duration:.2f} seconds")

val_results_df
# Out:
# Execution time: 23.55 seconds
#               model cv_fold                             y dataset       mae  \
# 0  RF|x2|48-85-None     val  frwd01_mon_metro_hvi_pct_chg   train  0.001657
# 1  RF|x2|48-85-None     val  frwd01_mon_metro_hvi_pct_chg    test  0.002568
#
#    accuracy  precision    recall        F1  specificity     tp    fp    fn  \
# 0  0.895860   0.744298  0.822133  0.781282     0.917417  14717  5056  3184
# 1  0.919113   0.643914  0.805758  0.715801     0.935517   5094  2817  1228
#
#       tn
# 0  56167
# 1  40869

# %%
print("training y | mean:",format(sample_dfs[val['train_df'][0]][y_var].mean(),".5%"),
      "  std:",format(sample_dfs[val['train_df'][0]][y_var].std(),".5%"),
      "  mae:",format(val_results_df['mae'][0]/(sample_dfs[val['test_df'][0]][y_var].std()),".0%"),"of std")
print("test y | mean:",format(sample_dfs[val['test_df'][0]][y_var].mean(),".5%"),
      "  std:",format(sample_dfs[val['test_df'][0]][y_var].std(),".5%"),
      "  mae:",format(val_results_df['mae'][1]/(sample_dfs[val['test_df'][0]][y_var].std()),".0%"),"of std")
# Out:
# training y | mean: 0.22401%   std: 0.65472%   mae: 21% of std
# test y | mean: 0.62979%   std: 0.77989%   mae: 33% of std

# %% [markdown]
# **Validation test results**
#  - Out of the 6,322 periods where home value declined, the model correctly predicted a decline 80.5% of the time (recall).
#  - Out of the 7,911 periods where the model predicted a decline, only 64.4% of the time did a decline actually occur (precision).
#  - The model was able to predict the percentage of home value change within 1/3 of the standard deviation of the actual home value change for the test period.
